# %%
import pandas as pd
import numpy as np
import pyspi
from pyspi.calculator import Calculator
import os
from copy import deepcopy
import glob
import mne_connectivity
import mne

# %%
# Initialise a base calculator
calc = Calculator(subset='fast')
# Out:
# Loading configuration file: /headnode1/abry4213/.conda/envs/pyspi/lib/python3.9/site-packages/pyspi/fast_config.yaml
# *** Importing module .statistics.basic
# [0] Adding SPI .statistics.basic.Covariance(x,y,{'estimator': 'EmpiricalCovariance'})...
# Succesfully initialised SPI with identifier "cov_EmpiricalCovariance" and labels ['basic', 'unordered', 'linear', 'undirected', 'signed']
# [1] Adding SPI .statistics.basic.Covariance(x,y,{'estimator': 'GraphicalLasso'})...
# Succesfully initialised SPI with identifier "cov_GraphicalLasso" and labels ['basic', 'unordered', 'linear', 'undirected', 'signed']
# [2] Adding SPI .statistics.basic.Covariance(x,y,{'estimator': 'GraphicalLassoCV'})...
# Succesfully initialised SPI with identifier "cov_GraphicalLassoCV" and labels ['basic', 'unordered', 'linear', 'undirected', 'signed']
# [3] Adding SPI .statistics.basic.Covariance(x,y,{'estimator': 'LedoitWolf'})...
# Succesfully initialised SPI with identifier "cov_LedoitWolf" and labels ['basic', 'unordered', 'linear', 'undirected', 'signed']
# [4] Adding SPI .statistics.basic.Covariance(x,y,{'estimator': 'OAS'})...
# Succesfully initialised SPI with identifier "cov_OAS" and labels ['basic', 'unordered', 'linear', 'undirected', 'signed']
# [5] Adding SPI .statistics.basic.Covariance(x,y,{'estimator': 'ShrunkCovariance'})...
# Succesfully initialised SPI with identifier "cov_ShrunkCovariance" and labels ['basic', 'unordered', 'linear', 'undirected', 'signed']
# [6] Adding SPI .statistics.basic.Covariance(x,y,{'estimator': 'EmpiricalCovariance', 'squared': True})...
# Succesfully initialised SPI with identifier "cov-sq_EmpiricalCovariance" and labels ['basic', 'unordered', 'linear', 'undirected', 'unsigned']
# [7] Adding SPI .statistics.basic.Covariance(x,y,{'estimator': 'GraphicalLasso', 'squared': True})...
# Succesfully initialised SPI with identifier "cov-sq_GraphicalLasso" and labels ['basic', 'unordered', 'linear', 'undirected', 'unsigned']
# [8] Adding SPI .statistics.basic.Covariance(x,y,{'estimator': 'LedoitWolf', 'squared': True})...
# Succesfully initialised SPI with identifier "cov-sq_LedoitWolf" and labels ['basic', 'unordered', 'linear', 'undirected', 'unsigned']
# [9] Adding SPI .statistics.basic.Covariance(x,y,{'estimator': 'OAS', 'squared': True})...
# Succesfully initialised SPI with identifier "cov-sq_OAS" and labels ['basic', 'unordered', 'linear', 'undirected', 'unsigned']
# [10] Adding SPI .statistics.basic.Covariance(x,y,{'estimator': 'ShrunkCovariance', 'squared': True})...
# Succesfully initialised SPI with identifier "cov-sq_ShrunkCovariance" and labels ['basic', 'unordered', 'linear', 'undirected', 'unsigned']
# [11] Adding SPI .statistics.basic.Precision(x,y,{'estimator': 'EmpiricalCovariance'})...
# Succesfully initialised SPI with identifier "prec_EmpiricalCovariance" and labels ['basic', 'unordered', 'linear', 'undirected', 'signed']
# [12] Adding SPI .statistics.basic.Precision(x,y,{'estimator': 'GraphicalLasso'})...
# Succesfully initialised SPI with identifier "prec_GraphicalLasso" and labels ['basic', 'unordered', 'linear', 'undirected', 'signed']
# [13] Adding SPI .statistics.basic.Precision(x,y,{'estimator': 'LedoitWolf'})...
# Succesfully initialised SPI with identifier "prec_LedoitWolf" and labels ['basic', 'unordered', 'linear', 'undirected', 'signed']
# [14] Adding SPI .statistics.basic.Precision(x,y,{'estimator': 'OAS'})...
# Succesfully initialised SPI with identifier "prec_OAS" and labels ['basic', 'unordered', 'linear', 'undirected', 'signed']
# [15] Adding SPI .statistics.basic.Precision(x,y,{'estimator': 'ShrunkCovariance'})...
# Succesfully initialised SPI with identifier "prec_ShrunkCovariance" and labels ['basic', 'unordered', 'linear', 'undirected', 'signed']
# [16] Adding SPI .statistics.basic.Precision(x,y,{'estimator': 'EmpiricalCovariance', 'squared': True})...
# Succesfully initialised SPI with identifier "prec-sq_EmpiricalCovariance" and labels ['basic', 'unordered', 'linear', 'undirected', 'unsigned']
# [17] Adding SPI .statistics.basic.Precision(x,y,{'estimator': 'GraphicalLasso', 'squared': True})...
# Succesfully initialised SPI with identifier "prec-sq_GraphicalLasso" and labels ['basic', 'unordered', 'linear', 'undirected', 'unsigned']
# [18] Adding SPI .statistics.basic.Precision(x,y,{'estimator': 'LedoitWolf', 'squared': True})...
# Succesfully initialised SPI with identifier "prec-sq_LedoitWolf" and labels ['basic', 'unordered', 'linear', 'undirected', 'unsigned']
# [19] Adding SPI .statistics.basic.Precision(x,y,{'estimator': 'OAS', 'squared': True})...
# Succesfully initialised SPI with identifier "prec-sq_OAS" and labels ['basic', 'unordered', 'linear', 'undirected', 'unsigned']
# [20] Adding SPI .statistics.basic.Precision(x,y,{'estimator': 'ShrunkCovariance', 'squared': True})...
# Succesfully initialised SPI with identifier "prec-sq_ShrunkCovariance" and labels ['basic', 'unordered', 'linear', 'undirected', 'unsigned']
# [21] Adding SPI .statistics.basic.SpearmanR(x,y,{'squared': True})...
# Succesfully initialised SPI with identifier "spearmanr-sq" and labels ['basic', 'unordered', 'rank', 'linear', 'undirected', 'unsigned', 'signed', 'unsigned']
# [22] Adding SPI .statistics.basic.SpearmanR(x,y,{'squared': False})...
# Succesfully initialised SPI with identifier "spearmanr" and labels ['basic', 'unordered', 'rank', 'linear', 'undirected', 'unsigned', 'signed', 'unsigned', 'signed']
# [23] Adding SPI .statistics.basic.KendallTau(x,y,{'squared': True})...
# Succesfully initialised SPI with identifier "kendalltau-sq" and labels ['basic', 'unordered', 'rank', 'linear', 'undirected', 'unsigned', 'signed', 'unsigned']
# [24] Adding SPI .statistics.basic.KendallTau(x,y,{'squared': False})...
# Succesfully initialised SPI with identifier "kendalltau" and labels ['basic', 'unordered', 'rank', 'linear', 'undirected', 'unsigned', 'signed', 'unsigned', 'signed']
# [25] Adding SPI .statistics.basic.CrossCorrelation(x,y,{'statistic': 'max'})...
# Succesfully initialised SPI with identifier "xcorr_max_sig-True" and labels ['basic', 'linear', 'undirected', 'temporal', 'signed']
# [26] Adding SPI .statistics.basic.CrossCorrelation(x,y,{'statistic': 'max', 'squared': True})...
# Succesfully initialised SPI with identifier "xcorr-sq_max_sig-True" and labels ['basic', 'linear', 'undirected', 'temporal', 'unsigned']
# [27] Adding SPI .statistics.basic.CrossCorrelation(x,y,{'statistic': 'mean'})...
# Succesfully initialised SPI with identifier "xcorr_mean_sig-True" and labels ['basic', 'linear', 'undirected', 'temporal', 'signed']
# [28] Adding SPI .statistics.basic.CrossCorrelation(x,y,{'statistic': 'mean', 'squared': True})...
# Succesfully initialised SPI with identifier "xcorr-sq_mean_sig-True" and labels ['basic', 'linear', 'undirected', 'temporal', 'unsigned']
# [29] Adding SPI .statistics.basic.CrossCorrelation(x,y,{'statistic': 'mean', 'sigonly': False})...
# Succesfully initialised SPI with identifier "xcorr_mean_sig-False" and labels ['basic', 'linear', 'undirected', 'temporal', 'signed']
# [30] Adding SPI .statistics.basic.CrossCorrelation(x,y,{'statistic': 'mean', 'squared': True, 'sigonly': False})...
# Succesfully initialised SPI with identifier "xcorr-sq_mean_sig-False" and labels ['basic', 'linear', 'undirected', 'temporal', 'unsigned']
# *** Importing module .statistics.distance
# [31] Adding SPI .statistics.distance.PairwiseDistance(x,y,{'metric': 'euclidean'})...
# Succesfully initialised SPI with identifier "pdist_euclidean" and labels ['unsigned', 'distance', 'unordered', 'nonlinear', 'undirected']
# [32] Adding SPI .statistics.distance.PairwiseDistance(x,y,{'metric': 'cityblock'})...
# Succesfully initialised SPI with identifier "pdist_cityblock" and labels ['unsigned', 'distance', 'unordered', 'nonlinear', 'undirected']
# [33] Adding SPI .statistics.distance.PairwiseDistance(x,y,{'metric': 'cosine'})...
# Succesfully initialised SPI with identifier "pdist_cosine" and labels ['unsigned', 'distance', 'unordered', 'nonlinear', 'undirected']
# [34] Adding SPI .statistics.distance.PairwiseDistance(x,y,{'metric': 'chebyshev'})...
# Succesfully initialised SPI with identifier "pdist_chebyshev" and labels ['unsigned', 'distance', 'unordered', 'nonlinear', 'undirected']
# [35] Adding SPI .statistics.distance.PairwiseDistance(x,y,{'metric': 'canberra'})...
# Succesfully initialised SPI with identifier "pdist_canberra" and labels ['unsigned', 'distance', 'unordered', 'nonlinear', 'undirected']
# [36] Adding SPI .statistics.distance.PairwiseDistance(x,y,{'metric': 'braycurtis'})...
# Succesfully initialised SPI with identifier "pdist_braycurtis" and labels ['unsigned', 'distance', 'unordered', 'nonlinear', 'undirected']
# [37] Adding SPI .statistics.distance.DistanceCorrelation(x,y,{'biased': False})...
# Succesfully initialised SPI with identifier "dcorr" and labels ['unsigned', 'distance', 'unordered', 'nonlinear', 'undirected']
# [38] Adding SPI .statistics.distance.DistanceCorrelation(x,y,{'biased': True})...
# Succesfully initialised SPI with identifier "dcorr_biased" and labels ['unsigned', 'distance', 'unordered', 'nonlinear', 'undirected']
# [39] Adding SPI .statistics.distance.HilbertSchmidtIndependenceCriterion(x,y,{'biased': False})...
# Succesfully initialised SPI with identifier "hsic" and labels ['unsigned', 'distance', 'unordered', 'nonlinear', 'undirected']
# [40] Adding SPI .statistics.distance.HilbertSchmidtIndependenceCriterion(x,y,{'biased': True})...
# Succesfully initialised SPI with identifier "hsic_biased" and labels ['unsigned', 'distance', 'unordered', 'nonlinear', 'undirected']
# [41] Adding SPI .statistics.distance.Barycenter(x,y,{'mode': 'euclidean', 'statistic': 'mean'})...
# Succesfully initialised SPI with identifier "bary_euclidean_mean" and labels ['distance', 'signed', 'undirected', 'temporal', 'nonlinear']
# [42] Adding SPI .statistics.distance.Barycenter(x,y,{'mode': 'euclidean', 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "bary_euclidean_max" and labels ['distance', 'signed', 'undirected', 'temporal', 'nonlinear']
# [43] Adding SPI .statistics.distance.Barycenter(x,y,{'mode': 'euclidean', 'statistic': 'mean', 'squared': True})...
# Succesfully initialised SPI with identifier "bary-sq_euclidean_mean" and labels ['distance', 'signed', 'undirected', 'temporal', 'nonlinear']
# [44] Adding SPI .statistics.distance.Barycenter(x,y,{'mode': 'euclidean', 'statistic': 'max', 'squared': True})...
# Succesfully initialised SPI with identifier "bary-sq_euclidean_max" and labels ['distance', 'signed', 'undirected', 'temporal', 'nonlinear']
# *** Importing module .statistics.causal
# [45] Adding SPI .statistics.causal.AdditiveNoiseModel(x,y)...
# Succesfully initialised SPI with identifier "anm" and labels ['unsigned', 'causal', 'unordered', 'linear', 'directed']
# [46] Adding SPI .statistics.causal.ConditionalDistributionSimilarity(x,y)...
# Succesfully initialised SPI with identifier "cds" and labels ['unsigned', 'causal', 'unordered', 'nonlinear', 'directed']
# [47] Adding SPI .statistics.causal.RegressionErrorCausalInference(x,y)...
# Succesfully initialised SPI with identifier "reci" and labels ['unsigned', 'causal', 'unordered', 'nonlinear', 'directed']
# [48] Adding SPI .statistics.causal.InformationGeometricConditionalIndependence(x,y)...
# Succesfully initialised SPI with identifier "igci" and labels ['causal', 'directed', 'nonlinear', 'unsigned', 'unordered']
# *** Importing module .statistics.infotheory
# [49] Adding SPI .statistics.infotheory.JointEntropy(x,y,{'estimator': 'gaussian'})...
# Succesfully initialised SPI with identifier "je_gaussian" and labels ['unsigned', 'infotheory', 'unordered', 'undirected', 'linear']
# [50] Adding SPI .statistics.infotheory.JointEntropy(x,y,{'estimator': 'kozachenko'})...
# Succesfully initialised SPI with identifier "je_kozachenko" and labels ['unsigned', 'infotheory', 'unordered', 'undirected', 'linear']
# [51] Adding SPI .statistics.infotheory.JointEntropy(x,y,{'estimator': 'kernel'})...
# Succesfully initialised SPI with identifier "je_kernel_W-0.5" and labels ['unsigned', 'infotheory', 'unordered', 'undirected', 'nonlinear']
# [52] Adding SPI .statistics.infotheory.ConditionalEntropy(x,y,{'estimator': 'gaussian'})...
# Succesfully initialised SPI with identifier "ce_gaussian" and labels ['unsigned', 'infotheory', 'unordered', 'directed', 'linear']
# [53] Adding SPI .statistics.infotheory.ConditionalEntropy(x,y,{'estimator': 'kernel'})...
# Succesfully initialised SPI with identifier "ce_kernel_W-0.5" and labels ['unsigned', 'infotheory', 'unordered', 'directed', 'nonlinear']
# [54] Adding SPI .statistics.infotheory.CrossmapEntropy(x,y,{'estimator': 'gaussian', 'history_length': 1})...
# Succesfully initialised SPI with identifier "xme_gaussian_k1" and labels ['unsigned', 'infotheory', 'temporal', 'directed', 'linear']
# [55] Adding SPI .statistics.infotheory.CrossmapEntropy(x,y,{'estimator': 'kozachenko', 'history_length': 1})...
# Succesfully initialised SPI with identifier "xme_kozachenko_k1" and labels ['unsigned', 'infotheory', 'temporal', 'directed', 'linear']
# [56] Adding SPI .statistics.infotheory.CrossmapEntropy(x,y,{'estimator': 'kernel', 'history_length': 1})...
# Succesfully initialised SPI with identifier "xme_kernel_W-0.5_k1" and labels ['unsigned', 'infotheory', 'temporal', 'directed', 'nonlinear']
# [57] Adding SPI .statistics.infotheory.CrossmapEntropy(x,y,{'estimator': 'gaussian', 'history_length': 10})...
# Succesfully initialised SPI with identifier "xme_gaussian_k10" and labels ['unsigned', 'infotheory', 'temporal', 'directed', 'linear']
# [58] Adding SPI .statistics.infotheory.CrossmapEntropy(x,y,{'estimator': 'kozachenko', 'history_length': 10})...
# Succesfully initialised SPI with identifier "xme_kozachenko_k10" and labels ['unsigned', 'infotheory', 'temporal', 'directed', 'linear']
# [59] Adding SPI .statistics.infotheory.CrossmapEntropy(x,y,{'estimator': 'kernel', 'history_length': 10})...
# Succesfully initialised SPI with identifier "xme_kernel_W-0.5_k10" and labels ['unsigned', 'infotheory', 'temporal', 'directed', 'nonlinear']
# [60] Adding SPI .statistics.infotheory.StochasticInteraction(x,y,{'estimator': 'gaussian'})...
# Succesfully initialised SPI with identifier "si_gaussian_k-1" and labels ['unsigned', 'infotheory', 'temporal', 'undirected', 'linear']
# [61] Adding SPI .statistics.infotheory.StochasticInteraction(x,y,{'estimator': 'kozachenko'})...
# Succesfully initialised SPI with identifier "si_kozachenko_k-1" and labels ['unsigned', 'infotheory', 'temporal', 'undirected', 'linear']
# [62] Adding SPI .statistics.infotheory.StochasticInteraction(x,y,{'estimator': 'kernel'})...
# Succesfully initialised SPI with identifier "si_kernel_W-0.5_k-1" and labels ['unsigned', 'infotheory', 'temporal', 'undirected', 'nonlinear']
# [63] Adding SPI .statistics.infotheory.MutualInfo(x,y,{'estimator': 'gaussian'})...
# Succesfully initialised SPI with identifier "mi_gaussian" and labels ['unsigned', 'infotheory', 'unordered', 'undirected', 'linear']
# [64] Adding SPI .statistics.infotheory.MutualInfo(x,y,{'estimator': 'kraskov', 'prop_k': 4})...
# Succesfully initialised SPI with identifier "mi_kraskov_NN-4" and labels ['unsigned', 'infotheory', 'unordered', 'undirected', 'nonlinear']
# [65] Adding SPI .statistics.infotheory.MutualInfo(x,y,{'estimator': 'kraskov', 'prop_k': 4, 'dyn_corr_excl': 'AUTO'})...
# Succesfully initialised SPI with identifier "mi_kraskov_NN-4_DCE" and labels ['unsigned', 'infotheory', 'unordered', 'undirected', 'nonlinear']
# [66] Adding SPI .statistics.infotheory.MutualInfo(x,y,{'estimator': 'kernel', 'kernel_width': 0.25})...
# Succesfully initialised SPI with identifier "mi_kernel_W-0.25" and labels ['unsigned', 'infotheory', 'unordered', 'undirected', 'nonlinear']
# [67] Adding SPI .statistics.infotheory.TimeLaggedMutualInfo(x,y,{'estimator': 'gaussian'})...
# Succesfully initialised SPI with identifier "tlmi_gaussian" and labels ['unsigned', 'infotheory', 'temporal', 'undirected', 'linear']
# [68] Adding SPI .statistics.infotheory.TimeLaggedMutualInfo(x,y,{'estimator': 'kraskov', 'prop_k': 4})...
# Succesfully initialised SPI with identifier "tlmi_kraskov_NN-4" and labels ['unsigned', 'infotheory', 'temporal', 'undirected', 'nonlinear']
# [69] Adding SPI .statistics.infotheory.TimeLaggedMutualInfo(x,y,{'estimator': 'kraskov', 'prop_k': 4, 'dyn_corr_excl': 'AUTO'})...
# Succesfully initialised SPI with identifier "tlmi_kraskov_NN-4_DCE" and labels ['unsigned', 'infotheory', 'temporal', 'undirected', 'nonlinear']
# [70] Adding SPI .statistics.infotheory.TimeLaggedMutualInfo(x,y,{'estimator': 'kernel', 'kernel_width': 0.25})...
# Succesfully initialised SPI with identifier "tlmi_kernel_W-0.25" and labels ['unsigned', 'infotheory', 'temporal', 'undirected', 'nonlinear']
# [71] Adding SPI .statistics.infotheory.TransferEntropy(x,y,{'estimator': 'kraskov', 'prop_k': 4, 'k_history': 1, 'l_history': 1, 'dyn_corr_excl': 'AUTO'})...
# Succesfully initialised SPI with identifier "te_kraskov_NN-4_DCE_k-1_kt-1_l-1_lt-1" and labels ['unsigned', 'embedding', 'infotheory', 'temporal', 'directed', 'nonlinear']
# [72] Adding SPI .statistics.infotheory.TransferEntropy(x,y,{'estimator': 'gaussian', 'k_history': 1, 'l_history': 1})...
# Succesfully initialised SPI with identifier "gc_gaussian_k-1_kt-1_l-1_lt-1" and labels ['unsigned', 'embedding', 'infotheory', 'temporal', 'directed', 'linear']
# *** Importing module .statistics.spectral
# [73] Adding SPI .statistics.spectral.CoherencePhase(x,y,{'fs': 1})...
# Succesfully initialised SPI with identifier "phase_multitaper_mean_fs-1_fmin-0_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [74] Adding SPI .statistics.spectral.CoherencePhase(x,y,{'fmin': 0, 'fmax': 0.25})...
# Succesfully initialised SPI with identifier "phase_multitaper_mean_fs-1_fmin-0_fmax-0-25" and labels ['unsigned', 'spectral', 'undirected']
# [75] Adding SPI .statistics.spectral.CoherencePhase(x,y,{'fmin': 0.25, 'fmax': 0.5})...
# Succesfully initialised SPI with identifier "phase_multitaper_mean_fs-1_fmin-0-25_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [76] Adding SPI .statistics.spectral.CoherencePhase(x,y,{'fs': 1, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "phase_multitaper_max_fs-1_fmin-0_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [77] Adding SPI .statistics.spectral.CoherencePhase(x,y,{'fmin': 0, 'fmax': 0.25, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "phase_multitaper_max_fs-1_fmin-0_fmax-0-25" and labels ['unsigned', 'spectral', 'undirected']
# [78] Adding SPI .statistics.spectral.CoherencePhase(x,y,{'fmin': 0.25, 'fmax': 0.5, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "phase_multitaper_max_fs-1_fmin-0-25_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [79] Adding SPI .statistics.spectral.CoherenceMagnitude(x,y,{'fs': 1})...
# Succesfully initialised SPI with identifier "cohmag_multitaper_mean_fs-1_fmin-0_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [80] Adding SPI .statistics.spectral.CoherenceMagnitude(x,y,{'fmin': 0, 'fmax': 0.25})...
# Succesfully initialised SPI with identifier "cohmag_multitaper_mean_fs-1_fmin-0_fmax-0-25" and labels ['unsigned', 'spectral', 'undirected']
# [81] Adding SPI .statistics.spectral.CoherenceMagnitude(x,y,{'fmin': 0.25, 'fmax': 0.5})...
# Succesfully initialised SPI with identifier "cohmag_multitaper_mean_fs-1_fmin-0-25_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [82] Adding SPI .statistics.spectral.CoherenceMagnitude(x,y,{'fs': 1, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "cohmag_multitaper_max_fs-1_fmin-0_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [83] Adding SPI .statistics.spectral.CoherenceMagnitude(x,y,{'fmin': 0, 'fmax': 0.25, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "cohmag_multitaper_max_fs-1_fmin-0_fmax-0-25" and labels ['unsigned', 'spectral', 'undirected']
# [84] Adding SPI .statistics.spectral.CoherenceMagnitude(x,y,{'fmin': 0.25, 'fmax': 0.5, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "cohmag_multitaper_max_fs-1_fmin-0-25_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [85] Adding SPI .statistics.spectral.ImaginaryCoherence(x,y,{'fs': 1})...
# Succesfully initialised SPI with identifier "icoh_multitaper_mean_fs-1_fmin-0_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [86] Adding SPI .statistics.spectral.ImaginaryCoherence(x,y,{'fmin': 0, 'fmax': 0.25})...
# Succesfully initialised SPI with identifier "icoh_multitaper_mean_fs-1_fmin-0_fmax-0-25" and labels ['unsigned', 'spectral', 'undirected']
# [87] Adding SPI .statistics.spectral.ImaginaryCoherence(x,y,{'fmin': 0.25, 'fmax': 0.5})...
# Succesfully initialised SPI with identifier "icoh_multitaper_mean_fs-1_fmin-0-25_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [88] Adding SPI .statistics.spectral.ImaginaryCoherence(x,y,{'fs': 1, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "icoh_multitaper_max_fs-1_fmin-0_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [89] Adding SPI .statistics.spectral.ImaginaryCoherence(x,y,{'fmin': 0, 'fmax': 0.25, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "icoh_multitaper_max_fs-1_fmin-0_fmax-0-25" and labels ['unsigned', 'spectral', 'undirected']
# [90] Adding SPI .statistics.spectral.ImaginaryCoherence(x,y,{'fmin': 0.25, 'fmax': 0.5, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "icoh_multitaper_max_fs-1_fmin-0-25_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [91] Adding SPI .statistics.spectral.PhaseSlopeIndex(x,y,{'fmin': 0, 'fmax': 0.5})...
# Succesfully initialised SPI with identifier "psi_multitaper_mean_fs-1_fmin-0_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [92] Adding SPI .statistics.spectral.PhaseSlopeIndex(x,y,{'fmin': 0, 'fmax': 0.25})...
# Succesfully initialised SPI with identifier "psi_multitaper_mean_fs-1_fmin-0_fmax-0-25" and labels ['unsigned', 'spectral', 'undirected']
# [93] Adding SPI .statistics.spectral.PhaseSlopeIndex(x,y,{'fmin': 0.25, 'fmax': 0.5})...
# Succesfully initialised SPI with identifier "psi_multitaper_mean_fs-1_fmin-0-25_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [94] Adding SPI .statistics.spectral.PhaseLockingValue(x,y,{'fs': 1})...
# Succesfully initialised SPI with identifier "plv_multitaper_mean_fs-1_fmin-0_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [95] Adding SPI .statistics.spectral.PhaseLockingValue(x,y,{'fmin': 0, 'fmax': 0.25})...
# Succesfully initialised SPI with identifier "plv_multitaper_mean_fs-1_fmin-0_fmax-0-25" and labels ['unsigned', 'spectral', 'undirected']
# [96] Adding SPI .statistics.spectral.PhaseLockingValue(x,y,{'fmin': 0.25, 'fmax': 0.5})...
# Succesfully initialised SPI with identifier "plv_multitaper_mean_fs-1_fmin-0-25_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [97] Adding SPI .statistics.spectral.PhaseLockingValue(x,y,{'fs': 1, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "plv_multitaper_max_fs-1_fmin-0_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [98] Adding SPI .statistics.spectral.PhaseLockingValue(x,y,{'fmin': 0, 'fmax': 0.25, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "plv_multitaper_max_fs-1_fmin-0_fmax-0-25" and labels ['unsigned', 'spectral', 'undirected']
# [99] Adding SPI .statistics.spectral.PhaseLockingValue(x,y,{'fmin': 0.25, 'fmax': 0.5, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "plv_multitaper_max_fs-1_fmin-0-25_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [100] Adding SPI .statistics.spectral.PhaseLagIndex(x,y,{'fs': 1})...
# Succesfully initialised SPI with identifier "pli_multitaper_mean_fs-1_fmin-0_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [101] Adding SPI .statistics.spectral.PhaseLagIndex(x,y,{'fmin': 0, 'fmax': 0.25})...
# Succesfully initialised SPI with identifier "pli_multitaper_mean_fs-1_fmin-0_fmax-0-25" and labels ['unsigned', 'spectral', 'undirected']
# [102] Adding SPI .statistics.spectral.PhaseLagIndex(x,y,{'fmin': 0.25, 'fmax': 0.5})...
# Succesfully initialised SPI with identifier "pli_multitaper_mean_fs-1_fmin-0-25_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [103] Adding SPI .statistics.spectral.PhaseLagIndex(x,y,{'fs': 1, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "pli_multitaper_max_fs-1_fmin-0_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [104] Adding SPI .statistics.spectral.PhaseLagIndex(x,y,{'fmin': 0, 'fmax': 0.25, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "pli_multitaper_max_fs-1_fmin-0_fmax-0-25" and labels ['unsigned', 'spectral', 'undirected']
# [105] Adding SPI .statistics.spectral.PhaseLagIndex(x,y,{'fmin': 0.25, 'fmax': 0.5, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "pli_multitaper_max_fs-1_fmin-0-25_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [106] Adding SPI .statistics.spectral.WeightedPhaseLagIndex(x,y,{'fs': 1})...
# Succesfully initialised SPI with identifier "wpli_multitaper_mean_fs-1_fmin-0_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [107] Adding SPI .statistics.spectral.WeightedPhaseLagIndex(x,y,{'fmin': 0, 'fmax': 0.25})...
# Succesfully initialised SPI with identifier "wpli_multitaper_mean_fs-1_fmin-0_fmax-0-25" and labels ['unsigned', 'spectral', 'undirected']
# [108] Adding SPI .statistics.spectral.WeightedPhaseLagIndex(x,y,{'fmin': 0.25, 'fmax': 0.5})...
# Succesfully initialised SPI with identifier "wpli_multitaper_mean_fs-1_fmin-0-25_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [109] Adding SPI .statistics.spectral.WeightedPhaseLagIndex(x,y,{'fs': 1, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "wpli_multitaper_max_fs-1_fmin-0_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [110] Adding SPI .statistics.spectral.WeightedPhaseLagIndex(x,y,{'fmin': 0, 'fmax': 0.25, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "wpli_multitaper_max_fs-1_fmin-0_fmax-0-25" and labels ['unsigned', 'spectral', 'undirected']
# [111] Adding SPI .statistics.spectral.WeightedPhaseLagIndex(x,y,{'fmin': 0.25, 'fmax': 0.5, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "wpli_multitaper_max_fs-1_fmin-0-25_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [112] Adding SPI .statistics.spectral.DebiasedSquaredPhaseLagIndex(x,y,{'fs': 1})...
# Succesfully initialised SPI with identifier "dspli_multitaper_mean_fs-1_fmin-0_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [113] Adding SPI .statistics.spectral.DebiasedSquaredPhaseLagIndex(x,y,{'fmin': 0, 'fmax': 0.25})...
# Succesfully initialised SPI with identifier "dspli_multitaper_mean_fs-1_fmin-0_fmax-0-25" and labels ['unsigned', 'spectral', 'undirected']
# [114] Adding SPI .statistics.spectral.DebiasedSquaredPhaseLagIndex(x,y,{'fmin': 0.25, 'fmax': 0.5})...
# Succesfully initialised SPI with identifier "dspli_multitaper_mean_fs-1_fmin-0-25_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [115] Adding SPI .statistics.spectral.DebiasedSquaredPhaseLagIndex(x,y,{'fs': 1, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "dspli_multitaper_max_fs-1_fmin-0_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [116] Adding SPI .statistics.spectral.DebiasedSquaredPhaseLagIndex(x,y,{'fmin': 0, 'fmax': 0.25, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "dspli_multitaper_max_fs-1_fmin-0_fmax-0-25" and labels ['unsigned', 'spectral', 'undirected']
# [117] Adding SPI .statistics.spectral.DebiasedSquaredPhaseLagIndex(x,y,{'fmin': 0.25, 'fmax': 0.5, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "dspli_multitaper_max_fs-1_fmin-0-25_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [118] Adding SPI .statistics.spectral.DebiasedSquaredWeightedPhaseLagIndex(x,y,{'fs': 1})...
# Succesfully initialised SPI with identifier "dswpli_multitaper_mean_fs-1_fmin-0_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [119] Adding SPI .statistics.spectral.DebiasedSquaredWeightedPhaseLagIndex(x,y,{'fmin': 0, 'fmax': 0.25})...
# Succesfully initialised SPI with identifier "dswpli_multitaper_mean_fs-1_fmin-0_fmax-0-25" and labels ['unsigned', 'spectral', 'undirected']
# [120] Adding SPI .statistics.spectral.DebiasedSquaredWeightedPhaseLagIndex(x,y,{'fmin': 0.25, 'fmax': 0.5})...
# Succesfully initialised SPI with identifier "dswpli_multitaper_mean_fs-1_fmin-0-25_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [121] Adding SPI .statistics.spectral.DebiasedSquaredWeightedPhaseLagIndex(x,y,{'fs': 1, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "dswpli_multitaper_max_fs-1_fmin-0_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [122] Adding SPI .statistics.spectral.DebiasedSquaredWeightedPhaseLagIndex(x,y,{'fmin': 0, 'fmax': 0.25, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "dswpli_multitaper_max_fs-1_fmin-0_fmax-0-25" and labels ['unsigned', 'spectral', 'undirected']
# [123] Adding SPI .statistics.spectral.DebiasedSquaredWeightedPhaseLagIndex(x,y,{'fmin': 0.25, 'fmax': 0.5, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "dswpli_multitaper_max_fs-1_fmin-0-25_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [124] Adding SPI .statistics.spectral.PairwisePhaseConsistency(x,y,{'fs': 1})...
# Succesfully initialised SPI with identifier "ppc_multitaper_mean_fs-1_fmin-0_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [125] Adding SPI .statistics.spectral.PairwisePhaseConsistency(x,y,{'fmin': 0, 'fmax': 0.25})...
# Succesfully initialised SPI with identifier "ppc_multitaper_mean_fs-1_fmin-0_fmax-0-25" and labels ['unsigned', 'spectral', 'undirected']
# [126] Adding SPI .statistics.spectral.PairwisePhaseConsistency(x,y,{'fmin': 0.25, 'fmax': 0.5})...
# Succesfully initialised SPI with identifier "ppc_multitaper_mean_fs-1_fmin-0-25_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [127] Adding SPI .statistics.spectral.PairwisePhaseConsistency(x,y,{'fs': 1, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "ppc_multitaper_max_fs-1_fmin-0_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [128] Adding SPI .statistics.spectral.PairwisePhaseConsistency(x,y,{'fmin': 0, 'fmax': 0.25, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "ppc_multitaper_max_fs-1_fmin-0_fmax-0-25" and labels ['unsigned', 'spectral', 'undirected']
# [129] Adding SPI .statistics.spectral.PairwisePhaseConsistency(x,y,{'fmin': 0.25, 'fmax': 0.5, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "ppc_multitaper_max_fs-1_fmin-0-25_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [130] Adding SPI .statistics.spectral.DirectedTransferFunction(x,y,{'fs': 1})...
# Succesfully initialised SPI with identifier "dtf_multitaper_mean_fs-1_fmin-0_fmax-0-5" and labels ['unsigned', 'spectral', 'directed', 'lagged']
# [131] Adding SPI .statistics.spectral.DirectedTransferFunction(x,y,{'fmin': 0, 'fmax': 0.25})...
# Succesfully initialised SPI with identifier "dtf_multitaper_mean_fs-1_fmin-0_fmax-0-25" and labels ['unsigned', 'spectral', 'directed', 'lagged']
# [132] Adding SPI .statistics.spectral.DirectedTransferFunction(x,y,{'fmin': 0.25, 'fmax': 0.5})...
# Succesfully initialised SPI with identifier "dtf_multitaper_mean_fs-1_fmin-0-25_fmax-0-5" and labels ['unsigned', 'spectral', 'directed', 'lagged']
# [133] Adding SPI .statistics.spectral.DirectedTransferFunction(x,y,{'fs': 1, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "dtf_multitaper_max_fs-1_fmin-0_fmax-0-5" and labels ['unsigned', 'spectral', 'directed', 'lagged']
# [134] Adding SPI .statistics.spectral.DirectedTransferFunction(x,y,{'fmin': 0, 'fmax': 0.25, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "dtf_multitaper_max_fs-1_fmin-0_fmax-0-25" and labels ['unsigned', 'spectral', 'directed', 'lagged']
# [135] Adding SPI .statistics.spectral.DirectedTransferFunction(x,y,{'fmin': 0.25, 'fmax': 0.5, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "dtf_multitaper_max_fs-1_fmin-0-25_fmax-0-5" and labels ['unsigned', 'spectral', 'directed', 'lagged']
# [136] Adding SPI .statistics.spectral.DirectedCoherence(x,y,{'fs': 1})...
# Succesfully initialised SPI with identifier "dcoh_multitaper_mean_fs-1_fmin-0_fmax-0-5" and labels ['unsigned', 'spectral', 'directed']
# [137] Adding SPI .statistics.spectral.DirectedCoherence(x,y,{'fmin': 0, 'fmax': 0.25})...
# Succesfully initialised SPI with identifier "dcoh_multitaper_mean_fs-1_fmin-0_fmax-0-25" and labels ['unsigned', 'spectral', 'directed']
# [138] Adding SPI .statistics.spectral.DirectedCoherence(x,y,{'fmin': 0.25, 'fmax': 0.5})...
# Succesfully initialised SPI with identifier "dcoh_multitaper_mean_fs-1_fmin-0-25_fmax-0-5" and labels ['unsigned', 'spectral', 'directed']
# [139] Adding SPI .statistics.spectral.DirectedCoherence(x,y,{'fs': 1, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "dcoh_multitaper_max_fs-1_fmin-0_fmax-0-5" and labels ['unsigned', 'spectral', 'directed']
# [140] Adding SPI .statistics.spectral.DirectedCoherence(x,y,{'fmin': 0, 'fmax': 0.25, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "dcoh_multitaper_max_fs-1_fmin-0_fmax-0-25" and labels ['unsigned', 'spectral', 'directed']
# [141] Adding SPI .statistics.spectral.DirectedCoherence(x,y,{'fmin': 0.25, 'fmax': 0.5, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "dcoh_multitaper_max_fs-1_fmin-0-25_fmax-0-5" and labels ['unsigned', 'spectral', 'directed']
# [142] Adding SPI .statistics.spectral.PartialDirectedCoherence(x,y,{'fs': 1})...
# Succesfully initialised SPI with identifier "pdcoh_multitaper_mean_fs-1_fmin-0_fmax-0-5" and labels ['unsigned', 'spectral', 'directed']
# [143] Adding SPI .statistics.spectral.PartialDirectedCoherence(x,y,{'fmin': 0, 'fmax': 0.25})...
# Succesfully initialised SPI with identifier "pdcoh_multitaper_mean_fs-1_fmin-0_fmax-0-25" and labels ['unsigned', 'spectral', 'directed']
# [144] Adding SPI .statistics.spectral.PartialDirectedCoherence(x,y,{'fmin': 0.25, 'fmax': 0.5})...
# Succesfully initialised SPI with identifier "pdcoh_multitaper_mean_fs-1_fmin-0-25_fmax-0-5" and labels ['unsigned', 'spectral', 'directed']
# [145] Adding SPI .statistics.spectral.PartialDirectedCoherence(x,y,{'fs': 1, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "pdcoh_multitaper_max_fs-1_fmin-0_fmax-0-5" and labels ['unsigned', 'spectral', 'directed']
# [146] Adding SPI .statistics.spectral.PartialDirectedCoherence(x,y,{'fmin': 0, 'fmax': 0.25, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "pdcoh_multitaper_max_fs-1_fmin-0_fmax-0-25" and labels ['unsigned', 'spectral', 'directed']
# [147] Adding SPI .statistics.spectral.PartialDirectedCoherence(x,y,{'fmin': 0.25, 'fmax': 0.5, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "pdcoh_multitaper_max_fs-1_fmin-0-25_fmax-0-5" and labels ['unsigned', 'spectral', 'directed']
# [148] Adding SPI .statistics.spectral.GeneralizedPartialDirectedCoherence(x,y,{'fs': 1})...
# Succesfully initialised SPI with identifier "gpdcoh_multitaper_mean_fs-1_fmin-0_fmax-0-5" and labels ['unsigned', 'spectral', 'directed']
# [149] Adding SPI .statistics.spectral.GeneralizedPartialDirectedCoherence(x,y,{'fmin': 0, 'fmax': 0.25})...
# Succesfully initialised SPI with identifier "gpdcoh_multitaper_mean_fs-1_fmin-0_fmax-0-25" and labels ['unsigned', 'spectral', 'directed']
# [150] Adding SPI .statistics.spectral.GeneralizedPartialDirectedCoherence(x,y,{'fmin': 0.25, 'fmax': 0.5})...
# Succesfully initialised SPI with identifier "gpdcoh_multitaper_mean_fs-1_fmin-0-25_fmax-0-5" and labels ['unsigned', 'spectral', 'directed']
# [151] Adding SPI .statistics.spectral.GeneralizedPartialDirectedCoherence(x,y,{'fs': 1, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "gpdcoh_multitaper_max_fs-1_fmin-0_fmax-0-5" and labels ['unsigned', 'spectral', 'directed']
# [152] Adding SPI .statistics.spectral.GeneralizedPartialDirectedCoherence(x,y,{'fmin': 0, 'fmax': 0.25, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "gpdcoh_multitaper_max_fs-1_fmin-0_fmax-0-25" and labels ['unsigned', 'spectral', 'directed']
# [153] Adding SPI .statistics.spectral.GeneralizedPartialDirectedCoherence(x,y,{'fmin': 0.25, 'fmax': 0.5, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "gpdcoh_multitaper_max_fs-1_fmin-0-25_fmax-0-5" and labels ['unsigned', 'spectral', 'directed']
# [154] Adding SPI .statistics.spectral.DirectDirectedTransferFunction(x,y,{'fs': 1})...
# Succesfully initialised SPI with identifier "ddtf_multitaper_mean_fs-1_fmin-0_fmax-0-5" and labels ['unsigned', 'spectral', 'directed', 'lagged']
# [155] Adding SPI .statistics.spectral.DirectDirectedTransferFunction(x,y,{'fmin': 0, 'fmax': 0.25})...
# Succesfully initialised SPI with identifier "ddtf_multitaper_mean_fs-1_fmin-0_fmax-0-25" and labels ['unsigned', 'spectral', 'directed', 'lagged']
# [156] Adding SPI .statistics.spectral.DirectDirectedTransferFunction(x,y,{'fmin': 0.25, 'fmax': 0.5})...
# Succesfully initialised SPI with identifier "ddtf_multitaper_mean_fs-1_fmin-0-25_fmax-0-5" and labels ['unsigned', 'spectral', 'directed', 'lagged']
# [157] Adding SPI .statistics.spectral.DirectDirectedTransferFunction(x,y,{'fs': 1, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "ddtf_multitaper_max_fs-1_fmin-0_fmax-0-5" and labels ['unsigned', 'spectral', 'directed', 'lagged']
# [158] Adding SPI .statistics.spectral.DirectDirectedTransferFunction(x,y,{'fmin': 0, 'fmax': 0.25, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "ddtf_multitaper_max_fs-1_fmin-0_fmax-0-25" and labels ['unsigned', 'spectral', 'directed', 'lagged']
# [159] Adding SPI .statistics.spectral.DirectDirectedTransferFunction(x,y,{'fmin': 0.25, 'fmax': 0.5, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "ddtf_multitaper_max_fs-1_fmin-0-25_fmax-0-5" and labels ['unsigned', 'spectral', 'directed', 'lagged']
# [160] Adding SPI .statistics.spectral.GroupDelay(x,y,{'fmin': 0, 'fmax': 0.5, 'statistic': 'delay'})...
# Succesfully initialised SPI with identifier "gd_multitaper_delay_fs-1_fmin-0_fmax-0-5" and labels ['unsigned', 'spectral', 'directed', 'lagged']
# [161] Adding SPI .statistics.spectral.GroupDelay(x,y,{'fmin': 0, 'fmax': 0.25, 'statistic': 'delay'})...
# Succesfully initialised SPI with identifier "gd_multitaper_delay_fs-1_fmin-0_fmax-0-25" and labels ['unsigned', 'spectral', 'directed', 'lagged']
# [162] Adding SPI .statistics.spectral.GroupDelay(x,y,{'fmin': 0.25, 'fmax': 0.5, 'statistic': 'delay'})...
# Succesfully initialised SPI with identifier "gd_multitaper_delay_fs-1_fmin-0-25_fmax-0-5" and labels ['unsigned', 'spectral', 'directed', 'lagged']
# [163] Adding SPI .statistics.spectral.SpectralGrangerCausality(x,y,{'method': 'nonparametric', 'fmin': 0, 'fmax': 0.5, 'statistic': 'mean'})...
# Succesfully initialised SPI with identifier "sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5" and labels ['unsigned', 'embedding', 'spectral', 'directed', 'lagged']
# [164] Adding SPI .statistics.spectral.SpectralGrangerCausality(x,y,{'method': 'nonparametric', 'fmin': 0, 'fmax': 0.25, 'statistic': 'mean'})...
# Succesfully initialised SPI with identifier "sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-25" and labels ['unsigned', 'embedding', 'spectral', 'directed', 'lagged']
# [165] Adding SPI .statistics.spectral.SpectralGrangerCausality(x,y,{'method': 'nonparametric', 'fmin': 0.25, 'fmax': 0.5, 'statistic': 'mean'})...
# Succesfully initialised SPI with identifier "sgc_nonparametric_mean_fs-1_fmin-0-25_fmax-0-5" and labels ['unsigned', 'embedding', 'spectral', 'directed', 'lagged']
# [166] Adding SPI .statistics.spectral.SpectralGrangerCausality(x,y,{'method': 'nonparametric', 'fmin': 0, 'fmax': 0.5, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5" and labels ['unsigned', 'embedding', 'spectral', 'directed', 'lagged']
# [167] Adding SPI .statistics.spectral.SpectralGrangerCausality(x,y,{'method': 'nonparametric', 'fmin': 0, 'fmax': 0.25, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "sgc_nonparametric_max_fs-1_fmin-0_fmax-0-25" and labels ['unsigned', 'embedding', 'spectral', 'directed', 'lagged']
# [168] Adding SPI .statistics.spectral.SpectralGrangerCausality(x,y,{'method': 'nonparametric', 'fmin': 0.25, 'fmax': 0.5, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "sgc_nonparametric_max_fs-1_fmin-0-25_fmax-0-5" and labels ['unsigned', 'embedding', 'spectral', 'directed', 'lagged']
# [169] Adding SPI .statistics.spectral.SpectralGrangerCausality(x,y,{'method': 'parametric', 'fmin': 0, 'fmax': 0.5, 'statistic': 'mean'})...
# Succesfully initialised SPI with identifier "sgc_parametric_mean_fs-1_fmin-0_fmax-0-5_order-None" and labels ['unsigned', 'embedding', 'spectral', 'directed', 'lagged']
# [170] Adding SPI .statistics.spectral.SpectralGrangerCausality(x,y,{'method': 'parametric', 'fmin': 0, 'fmax': 0.25, 'statistic': 'mean'})...
# Succesfully initialised SPI with identifier "sgc_parametric_mean_fs-1_fmin-0_fmax-0-25_order-None" and labels ['unsigned', 'embedding', 'spectral', 'directed', 'lagged']
# [171] Adding SPI .statistics.spectral.SpectralGrangerCausality(x,y,{'fmin': 0.25, 'fmax': 0.5, 'method': 'parametric', 'statistic': 'mean'})...
# Succesfully initialised SPI with identifier "sgc_parametric_mean_fs-1_fmin-0-25_fmax-0-5_order-None" and labels ['unsigned', 'embedding', 'spectral', 'directed', 'lagged']
# [172] Adding SPI .statistics.spectral.SpectralGrangerCausality(x,y,{'fs': 1, 'order': 1, 'method': 'parametric', 'statistic': 'mean'})...
# Succesfully initialised SPI with identifier "sgc_parametric_mean_fs-1_fmin-1e-05_fmax-0-5_order-1" and labels ['unsigned', 'embedding', 'spectral', 'directed', 'lagged']
# [173] Adding SPI .statistics.spectral.SpectralGrangerCausality(x,y,{'fmin': 0, 'fmax': 0.25, 'order': 1, 'method': 'parametric', 'statistic': 'mean'})...
# Succesfully initialised SPI with identifier "sgc_parametric_mean_fs-1_fmin-0_fmax-0-25_order-1" and labels ['unsigned', 'embedding', 'spectral', 'directed', 'lagged']
# [174] Adding SPI .statistics.spectral.SpectralGrangerCausality(x,y,{'fmin': 0.25, 'fmax': 0.5, 'order': 1, 'method': 'parametric', 'statistic': 'mean'})...
# Succesfully initialised SPI with identifier "sgc_parametric_mean_fs-1_fmin-0-25_fmax-0-5_order-1" and labels ['unsigned', 'embedding', 'spectral', 'directed', 'lagged']
# [175] Adding SPI .statistics.spectral.SpectralGrangerCausality(x,y,{'fs': 1, 'order': 20, 'method': 'parametric', 'statistic': 'mean'})...
# Succesfully initialised SPI with identifier "sgc_parametric_mean_fs-1_fmin-1e-05_fmax-0-5_order-20" and labels ['unsigned', 'embedding', 'spectral', 'directed', 'lagged']
# [176] Adding SPI .statistics.spectral.SpectralGrangerCausality(x,y,{'fmin': 0, 'fmax': 0.25, 'order': 20, 'method': 'parametric', 'statistic': 'mean'})...
# Succesfully initialised SPI with identifier "sgc_parametric_mean_fs-1_fmin-0_fmax-0-25_order-20" and labels ['unsigned', 'embedding', 'spectral', 'directed', 'lagged']
# [177] Adding SPI .statistics.spectral.SpectralGrangerCausality(x,y,{'fmin': 0.25, 'fmax': 0.5, 'order': 20, 'method': 'parametric', 'statistic': 'mean'})...
# Succesfully initialised SPI with identifier "sgc_parametric_mean_fs-1_fmin-0-25_fmax-0-5_order-20" and labels ['unsigned', 'embedding', 'spectral', 'directed', 'lagged']
# [178] Adding SPI .statistics.spectral.SpectralGrangerCausality(x,y,{'fs': 1, 'method': 'parametric', 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "sgc_parametric_max_fs-1_fmin-1e-05_fmax-0-5_order-None" and labels ['unsigned', 'embedding', 'spectral', 'directed', 'lagged']
# [179] Adding SPI .statistics.spectral.SpectralGrangerCausality(x,y,{'fmin': 0, 'fmax': 0.25, 'method': 'parametric', 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "sgc_parametric_max_fs-1_fmin-0_fmax-0-25_order-None" and labels ['unsigned', 'embedding', 'spectral', 'directed', 'lagged']
# [180] Adding SPI .statistics.spectral.SpectralGrangerCausality(x,y,{'fmin': 0.25, 'fmax': 0.5, 'method': 'parametric', 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "sgc_parametric_max_fs-1_fmin-0-25_fmax-0-5_order-None" and labels ['unsigned', 'embedding', 'spectral', 'directed', 'lagged']
# [181] Adding SPI .statistics.spectral.SpectralGrangerCausality(x,y,{'fs': 1, 'order': 1, 'method': 'parametric', 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "sgc_parametric_max_fs-1_fmin-1e-05_fmax-0-5_order-1" and labels ['unsigned', 'embedding', 'spectral', 'directed', 'lagged']
# [182] Adding SPI .statistics.spectral.SpectralGrangerCausality(x,y,{'fmin': 0, 'fmax': 0.25, 'order': 1, 'method': 'parametric', 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "sgc_parametric_max_fs-1_fmin-0_fmax-0-25_order-1" and labels ['unsigned', 'embedding', 'spectral', 'directed', 'lagged']
# [183] Adding SPI .statistics.spectral.SpectralGrangerCausality(x,y,{'fmin': 0.25, 'fmax': 0.5, 'order': 1, 'method': 'parametric', 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "sgc_parametric_max_fs-1_fmin-0-25_fmax-0-5_order-1" and labels ['unsigned', 'embedding', 'spectral', 'directed', 'lagged']
# [184] Adding SPI .statistics.spectral.SpectralGrangerCausality(x,y,{'fs': 1, 'order': 20, 'method': 'parametric', 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "sgc_parametric_max_fs-1_fmin-1e-05_fmax-0-5_order-20" and labels ['unsigned', 'embedding', 'spectral', 'directed', 'lagged']
# [185] Adding SPI .statistics.spectral.SpectralGrangerCausality(x,y,{'fmin': 0, 'fmax': 0.25, 'order': 20, 'method': 'parametric', 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "sgc_parametric_max_fs-1_fmin-0_fmax-0-25_order-20" and labels ['unsigned', 'embedding', 'spectral', 'directed', 'lagged']
# [186] Adding SPI .statistics.spectral.SpectralGrangerCausality(x,y,{'fmin': 0.25, 'fmax': 0.5, 'order': 20, 'method': 'parametric', 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "sgc_parametric_max_fs-1_fmin-0-25_fmax-0-5_order-20" and labels ['unsigned', 'embedding', 'spectral', 'directed', 'lagged']
# *** Importing module .statistics.wavelet
# [187] Adding SPI .statistics.wavelet.PhaseSlopeIndex(x,y,{'fs': 1})...
# Succesfully initialised SPI with identifier "psi_wavelet_mean_fs-1_fmin-0_fmax-0-5_mean" and labels ['unsigned', 'wavelet', 'undirected']
# [188] Adding SPI .statistics.wavelet.PhaseSlopeIndex(x,y,{'fmin': 0, 'fmax': 0.25})...
# Succesfully initialised SPI with identifier "psi_wavelet_mean_fs-1_fmin-0_fmax-0-25_mean" and labels ['unsigned', 'wavelet', 'undirected']
# [189] Adding SPI .statistics.wavelet.PhaseSlopeIndex(x,y,{'fmin': 0.25, 'fmax': 0.5})...
# Succesfully initialised SPI with identifier "psi_wavelet_mean_fs-1_fmin-0-25_fmax-0-5_mean" and labels ['unsigned', 'wavelet', 'undirected']
# [190] Adding SPI .statistics.wavelet.PhaseSlopeIndex(x,y,{'fmin': 0, 'fmax': 0.5, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "psi_wavelet_max_fs-1_fmin-0_fmax-0-5_max" and labels ['unsigned', 'wavelet', 'undirected']
# [191] Adding SPI .statistics.wavelet.PhaseSlopeIndex(x,y,{'fmin': 0, 'fmax': 0.25, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "psi_wavelet_max_fs-1_fmin-0_fmax-0-25_max" and labels ['unsigned', 'wavelet', 'undirected']
# [192] Adding SPI .statistics.wavelet.PhaseSlopeIndex(x,y,{'fmin': 0.25, 'fmax': 0.5, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "psi_wavelet_max_fs-1_fmin-0-25_fmax-0-5_max" and labels ['unsigned', 'wavelet', 'undirected']
# *** Importing module .statistics.misc
# [193] Adding SPI .statistics.misc.LinearModel(x,y,{'model': 'Ridge'})...
# Succesfully initialised SPI with identifier "lmfit_Ridge" and labels ['misc', 'unsigned', 'unordered', 'normal', 'linear', 'directed']
# [194] Adding SPI .statistics.misc.LinearModel(x,y,{'model': 'Lasso'})...
# Succesfully initialised SPI with identifier "lmfit_Lasso" and labels ['misc', 'unsigned', 'unordered', 'normal', 'linear', 'directed']
# [195] Adding SPI .statistics.misc.LinearModel(x,y,{'model': 'SGDRegressor'})...
# Succesfully initialised SPI with identifier "lmfit_SGDRegressor" and labels ['misc', 'unsigned', 'unordered', 'normal', 'linear', 'directed']
# [196] Adding SPI .statistics.misc.LinearModel(x,y,{'model': 'ElasticNet'})...
# Succesfully initialised SPI with identifier "lmfit_ElasticNet" and labels ['misc', 'unsigned', 'unordered', 'normal', 'linear', 'directed']
# [197] Adding SPI .statistics.misc.LinearModel(x,y,{'model': 'BayesianRidge'})...
# Succesfully initialised SPI with identifier "lmfit_BayesianRidge" and labels ['misc', 'unsigned', 'unordered', 'normal', 'linear', 'directed']
# [198] Adding SPI .statistics.misc.Cointegration(x,y,{'method': 'johansen', 'statistic': 'max_eig_stat', 'det_order': 0, 'k_ar_diff': 10})...
# Succesfully initialised SPI with identifier "coint_johansen_max_eig_stat_order-0_ardiff-10" and labels ['misc', 'unsigned', 'temporal', 'undirected', 'nonlinear']
# [199] Adding SPI .statistics.misc.Cointegration(x,y,{'method': 'johansen', 'statistic': 'trace_stat', 'det_order': 0, 'k_ar_diff': 10})...
# Succesfully initialised SPI with identifier "coint_johansen_trace_stat_order-0_ardiff-10" and labels ['misc', 'unsigned', 'temporal', 'undirected', 'nonlinear']
# [200] Adding SPI .statistics.misc.Cointegration(x,y,{'method': 'johansen', 'statistic': 'max_eig_stat', 'det_order': 0, 'k_ar_diff': 1})...
# Succesfully initialised SPI with identifier "coint_johansen_max_eig_stat_order-0_ardiff-1" and labels ['misc', 'unsigned', 'temporal', 'undirected', 'nonlinear']
# [201] Adding SPI .statistics.misc.Cointegration(x,y,{'method': 'johansen', 'statistic': 'trace_stat', 'det_order': 0, 'k_ar_diff': 1})...
# Succesfully initialised SPI with identifier "coint_johansen_trace_stat_order-0_ardiff-1" and labels ['misc', 'unsigned', 'temporal', 'undirected', 'nonlinear']
# [202] Adding SPI .statistics.misc.Cointegration(x,y,{'method': 'johansen', 'statistic': 'max_eig_stat', 'det_order': 1, 'k_ar_diff': 10})...
# Succesfully initialised SPI with identifier "coint_johansen_max_eig_stat_order-1_ardiff-10" and labels ['misc', 'unsigned', 'temporal', 'undirected', 'nonlinear']
# [203] Adding SPI .statistics.misc.Cointegration(x,y,{'method': 'johansen', 'statistic': 'trace_stat', 'det_order': 1, 'k_ar_diff': 10})...
# Succesfully initialised SPI with identifier "coint_johansen_trace_stat_order-1_ardiff-10" and labels ['misc', 'unsigned', 'temporal', 'undirected', 'nonlinear']
# [204] Adding SPI .statistics.misc.Cointegration(x,y,{'method': 'johansen', 'statistic': 'max_eig_stat', 'det_order': 1, 'k_ar_diff': 1})...
# Succesfully initialised SPI with identifier "coint_johansen_max_eig_stat_order-1_ardiff-1" and labels ['misc', 'unsigned', 'temporal', 'undirected', 'nonlinear']
# [205] Adding SPI .statistics.misc.Cointegration(x,y,{'method': 'johansen', 'statistic': 'trace_stat', 'det_order': 1, 'k_ar_diff': 1})...
# Succesfully initialised SPI with identifier "coint_johansen_trace_stat_order-1_ardiff-1" and labels ['misc', 'unsigned', 'temporal', 'undirected', 'nonlinear']
# [206] Adding SPI .statistics.misc.Cointegration(x,y,{'method': 'aeg', 'statistic': 'tstat', 'autolag': 'aic', 'maxlag': 10, 'trend': 'c'})...
# Succesfully initialised SPI with identifier "coint_aeg_tstat_trend-c_autolag-aic_maxlag-10" and labels ['misc', 'unsigned', 'temporal', 'undirected', 'nonlinear']
# [207] Adding SPI .statistics.misc.Cointegration(x,y,{'method': 'aeg', 'statistic': 'tstat', 'autolag': 'aic', 'maxlag': 10, 'trend': 'ct'})...
# Succesfully initialised SPI with identifier "coint_aeg_tstat_trend-ct_autolag-aic_maxlag-10" and labels ['misc', 'unsigned', 'temporal', 'undirected', 'nonlinear']
# [208] Adding SPI .statistics.misc.Cointegration(x,y,{'method': 'aeg', 'statistic': 'tstat', 'autolag': 'bic', 'maxlag': 10, 'trend': 'ct'})...
# Succesfully initialised SPI with identifier "coint_aeg_tstat_trend-ct_autolag-bic_maxlag-10" and labels ['misc', 'unsigned', 'temporal', 'undirected', 'nonlinear']
# [209] Adding SPI .statistics.misc.PowerEnvelopeCorrelation(x,y,{'orth': False, 'log': False, 'absolute': False})...
# Succesfully initialised SPI with identifier "pec" and labels ['unsigned', 'misc', 'undirected']
# [210] Adding SPI .statistics.misc.PowerEnvelopeCorrelation(x,y,{'orth': True, 'log': False, 'absolute': False})...
# Succesfully initialised SPI with identifier "pec_orth" and labels ['unsigned', 'misc', 'undirected']
# [211] Adding SPI .statistics.misc.PowerEnvelopeCorrelation(x,y,{'orth': False, 'log': True, 'absolute': False})...
# Succesfully initialised SPI with identifier "pec_log" and labels ['unsigned', 'misc', 'undirected']
# [212] Adding SPI .statistics.misc.PowerEnvelopeCorrelation(x,y,{'orth': True, 'log': True, 'absolute': False})...
# Succesfully initialised SPI with identifier "pec_orth_log" and labels ['unsigned', 'misc', 'undirected']
# [213] Adding SPI .statistics.misc.PowerEnvelopeCorrelation(x,y,{'orth': True, 'log': False, 'absolute': True})...
# Succesfully initialised SPI with identifier "pec_orth_abs" and labels ['unsigned', 'misc', 'undirected']
# [214] Adding SPI .statistics.misc.PowerEnvelopeCorrelation(x,y,{'orth': True, 'log': True, 'absolute': True})...
# Succesfully initialised SPI with identifier "pec_orth_log_abs" and labels ['unsigned', 'misc', 'undirected']
# Number of SPIs: 215
# Frequency minimum set to 0; overriding to 1e-5.

# %%
data_path="/headnode1/abry4213/data/Cogitate_MEG_challenge/derivatives/MEG_time_series/"

subject_id = "sub-CB042"
sub_CA103_test_data=pd.read_csv(f"{data_path}/{subject_id}_ses-1_meg_1000ms_all_time_series.csv")
sub_CA103_test_data['duration'] = sub_CA103_test_data['duration'].str.replace('ms', '').astype(int)
sub_CA103_test_data['times'] = np.round(sub_CA103_test_data['times']*1000)
sub_CA103_test_data['times'] = sub_CA103_test_data['times'].astype(int)

# %%
ROI_lookup = {"proc-0": "Category_Selective",
              "proc-1": "GNWT",
              "proc-2": "IIT"}

# %%
# Filter times to the duration range
sample_TS_data_onset = sub_CA103_test_data.query('times >= 0 and times < @sub_CA103_test_data.duration')
sample_TS_data_offset = sub_CA103_test_data.query('times >= @sub_CA103_test_data.duration')

# Create list of dataframes for each stimulus_type, relevance_type, duration, and frequency_band
on_sample_TS_data_list = []
off_sample_TS_data_list = []

for stimulus_type in sample_TS_data_onset['stimulus_type'].unique():
    for relevance_type in sample_TS_data_onset['relevance_type'].unique():
        for duration in [1000]:
        # for duration in sample_TS_data_onset['duration'].unique():
            TS_data_on = sample_TS_data_onset.query('stimulus_type == @stimulus_type and relevance_type == @relevance_type and duration == @duration')
            if TS_data_on.empty:
                print(f"Missing data for {stimulus_type}, {relevance_type}, {duration}")
            on_sample_TS_data_list.append(TS_data_on)
            TS_data_off = sample_TS_data_offset.query('stimulus_type == @stimulus_type and relevance_type == @relevance_type and duration == @duration')
            off_sample_TS_data_list.append(TS_data_off)
# Out:
# Missing data for face, Relevant target, 1000

# %%
def run_pyspi_for_df(subject_id, df, calc):
        # Make deepcopy of calc 
        calc_copy = deepcopy(calc)

        # Pivot so that the columns are meta_ROI and the rows are data
        df_wide = (df.filter(items=['times', 'Category_Selective', 'GNWT', 'IIT'])
                     .melt(id_vars='times', var_name='meta_ROI', value_name='data')
                     .reset_index()
                     .pivot(index='meta_ROI', columns='times', values='data'))

        # Convert to numpy array
        TS_array = df_wide.to_numpy()

        # Load data 
        calc_copy.load_dataset(TS_array)
        calc_copy.compute()

        SPI_res = deepcopy(calc_copy.table)

        # Iterate over each SPI
        SPI_res.columns = SPI_res.columns.to_flat_index()

        SPI_res = SPI_res.rename(columns='__'.join).assign(meta_ROI_from = lambda x: x.index)
        SPI_res_long = SPI_res.melt(id_vars='meta_ROI_from', var_name='SPI__meta_ROI_to', value_name='value')

        SPI_res_long["SPI"] = SPI_res_long["SPI__meta_ROI_to"].str.split("__").str[0]
        SPI_res_long["meta_ROI_to"] = SPI_res_long["SPI__meta_ROI_to"].str.split("__").str[1]

        SPI_res_long = (SPI_res_long
                        .drop(columns='SPI__meta_ROI_to')
                        .query('meta_ROI_from != meta_ROI_to')
                        .assign(meta_ROI_from = lambda x: x['meta_ROI_from'].map(ROI_lookup),
                                meta_ROI_to = lambda x: x['meta_ROI_to'].map(ROI_lookup))
                        .filter(items=['SPI', 'meta_ROI_from', 'meta_ROI_to', 'value'])
                        .assign(stimulus_type = df['stimulus_type'].unique()[0],
                                relevance_type = df['relevance_type'].unique()[0],
                                duration = df['duration'].unique()[0],
                                subject_ID = subject_id)
        )

        return SPI_res_long

# %%
# Initialise an empty list for the results
on_data_pyspi_list = []
off_data_pyspi_list = []

# Run for "on" data
for on_data in on_sample_TS_data_list[0:1]:
    on_data_pyspi = run_pyspi_for_df(subject_id, on_data, calc).assign(stimulus = "on")
    on_data_pyspi_list.append(on_data_pyspi)
on_data_pyspi_res = pd.concat(on_data_pyspi_list)
# Out:
# Processing [None: cov_GraphicalLassoCV]:   0%|          | 0/215 [00:00<?, ?it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 72/215 [00:07<00:20,  6.84it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 72/215 [00:07<00:20,  6.84it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  72%|███████▏  | 155/215 [00:13<00:10,  5.57it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:13<00:07,  6.80it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:14<00:00, 15.10it/s]

# %%
# Run for "off" data
for off_data in off_sample_TS_data_list:
    off_data_pyspi = run_pyspi_for_df(off_data, calc).assign(stimulus = "off")
    off_data_pyspi_list.append(off_data_pyspi)
off_data_pyspi_res = pd.concat(off_data_pyspi_list)
