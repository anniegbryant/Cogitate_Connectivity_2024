# %%
import pandas as pd
import numpy as np

import pyspi
from pyspi.calculator import Calculator

import os
from copy import deepcopy

# %%
data_path="/headnode1/abry4213/data/Cogitate_MEG_challenge"

TS_data_path=f"{data_path}/derivatives/MEG_time_series/sub-CB050/ses-1/meg"

# %%
ROI_lookup = {"proc-0": "Category_Selective",
              "proc-1": "GNWT",
              "proc-2": "IIT"}

# %%
sample_TS_data_list = []

for TS_file in os.listdir(TS_data_path):
    subject_ID = TS_file.split("_")[0]
    stimulus_type = TS_file.split("desc-")[1].split("_")[0]
    relevance_type = TS_file.split(f"{stimulus_type}_")[1].split("_")[0]
    duration = TS_file.split(f"{relevance_type}_")[1].split("_")[0]
    meta_ROI = TS_file.split(f"{duration}_")[1].split("_meta")[0]
    frequency_band = TS_file.split("freq_")[1].split("_TS")[0]

    TS_data = (pd.read_csv(f"{TS_data_path}/{TS_file}")
               .assign(subject_ID=subject_ID,
                       stimulus_type=stimulus_type,
                       relevance_type=relevance_type,
                       duration=duration,
                       meta_ROI=meta_ROI,
                       frequency_band=frequency_band))

    sample_TS_data_list.append(TS_data)

sample_TS_data = pd.concat(sample_TS_data_list)
sample_TS_data['duration'] = sample_TS_data['duration'].str.replace('ms', '').astype(int)/1000
sample_TS_data.head()
# Out:
#    times      data subject_ID stimulus_type relevance_type  duration meta_ROI  \
# 0 -0.500  0.549058  sub-CB050         false     Irrelevant       1.0      IIT
# 1 -0.499  0.563103  sub-CB050         false     Irrelevant       1.0      IIT
# 2 -0.498  0.577039  sub-CB050         false     Irrelevant       1.0      IIT
# 3 -0.497  0.590849  sub-CB050         false     Irrelevant       1.0      IIT
# 4 -0.496  0.604514  sub-CB050         false     Irrelevant       1.0      IIT
#
#   frequency_band
# 0           beta
# 1           beta
# 2           beta
# 3           beta
# 4           beta

# %%
# Filter times to the duration range
sample_TS_data = sample_TS_data.query('times >= 0.0 and times <= @sample_TS_data.duration')

# Create list of dataframes for each stimulus_type, relevance_type, duration, and frequency_band
sample_TS_data_list = []

for stimulus_type in sample_TS_data['stimulus_type'].unique():
    for relevance_type in sample_TS_data['relevance_type'].unique():
        for duration in sample_TS_data['duration'].unique():
            for frequency_band in sample_TS_data['frequency_band'].unique():
                TS_data = sample_TS_data.query('stimulus_type == @stimulus_type and relevance_type == @relevance_type and duration == @duration and frequency_band == @frequency_band')
                sample_TS_data_list.append(TS_data)

# %%
def run_pyspi_for_df(df):
    # Pivot so that the columns are meta_ROI and the rows are data
    df_wide = df.pivot(index='meta_ROI', columns='times', values='data')

    # Convert to numpy array
    TS_array = df_wide.to_numpy()

    calc = Calculator(dataset=TS_array, subset='sonnet')
    calc.compute()

    SPI_res = deepcopy(calc.table)

    # Iterate over each SPI
    SPI_res.columns = SPI_res.columns.to_flat_index()

    SPI_res = SPI_res.rename(columns='__'.join).assign(meta_ROI_from = lambda x: x.index)
    SPI_res_long = SPI_res.melt(id_vars='meta_ROI_from', var_name='SPI__meta_ROI_to', value_name='value')

    SPI_res_long["SPI"] = SPI_res_long["SPI__meta_ROI_to"].str.split("__").str[0]
    SPI_res_long["meta_ROI_to"] = SPI_res_long["SPI__meta_ROI_to"].str.split("__").str[1]

    SPI_res_long = (SPI_res_long
                    .drop(columns='SPI__meta_ROI_to')
                    .query('meta_ROI_from != meta_ROI_to')
                    .assign(meta_ROI_from = lambda x: x['meta_ROI_from'].map(ROI_lookup),
                            meta_ROI_to = lambda x: x['meta_ROI_to'].map(ROI_lookup))
                    .filter(items=['SPI', 'meta_ROI_from', 'meta_ROI_to', 'value'])
    )

    return SPI_res_long

# %%
example_df = sample_TS_data_list[0]

# Pivot so that the columns are meta_ROI and the rows are data
df_wide = example_df.pivot(index='times', columns='meta_ROI', values='data')

test_pyspi_res.to_csv("sub-CB050__face_stimulus__relevant__1000ms__alpha_pyspi_res.csv")

# %%
test_pyspi_res = run_pyspi_for_df(sample_TS_data_list[0])
# Out:
# Frequency minimum set to 0; overriding to 1e-5.
# Processing [None: bary_dtw_mean]:  14%|█▍        | 2/14 [00:00<00:00, 15.48it/s]
# Loading configuration file: /headnode1/abry4213/.conda/envs/pyspi/lib/python3.9/site-packages/pyspi/sonnet_config.yaml
# *** Importing module .statistics.basic
# [0] Adding SPI .statistics.basic.Covariance(x,y,{'estimator': 'EmpiricalCovariance'})...
# Succesfully initialised SPI with identifier "cov_EmpiricalCovariance" and labels ['basic', 'unordered', 'linear', 'undirected', 'signed']
# *** Importing module .statistics.distance
# [1] Adding SPI .statistics.distance.DynamicTimeWarping(x,y,{'global_constraint': 'itakura'})...
# Succesfully initialised SPI with identifier "dtw_constraint-itakura" and labels ['unsigned', 'distance', 'temporal', 'undirected', 'nonlinear']
# [2] Adding SPI .statistics.distance.Barycenter(x,y,{'mode': 'dtw', 'statistic': 'mean'})...
# Succesfully initialised SPI with identifier "bary_dtw_mean" and labels ['distance', 'signed', 'undirected', 'temporal', 'nonlinear']
# *** Importing module .statistics.causal
# [3] Adding SPI .statistics.causal.AdditiveNoiseModel(x,y)...
# Succesfully initialised SPI with identifier "anm" and labels ['unsigned', 'causal', 'unordered', 'linear', 'directed']
# *** Importing module .statistics.infotheory
# [4] Adding SPI .statistics.infotheory.DirectedInfo(x,y,{'estimator': 'gaussian'})...
# Succesfully initialised SPI with identifier "di_gaussian" and labels ['unsigned', 'infotheory', 'temporal', 'directed', 'linear']
# [5] Adding SPI .statistics.infotheory.TransferEntropy(x,y,{'estimator': 'kraskov', 'prop_k': 4, 'auto_embed_method': 'MAX_CORR_AIS', 'k_search_max': 10, 'tau_search_max': 4, 'dyn_corr_excl': 'AUTO'})...
# Succesfully initialised SPI with identifier "te_kraskov_NN-4_DCE_k-max-10_tau-max-4" and labels ['unsigned', 'embedding', 'infotheory', 'temporal', 'directed', 'nonlinear']
# [6] Adding SPI .statistics.infotheory.IntegratedInformation(x,y,{'phitype': 'star'})...
# Succesfully initialised SPI with identifier "phi_star_t-1_norm-0" and labels ['linear', 'unsigned', 'infotheory', 'temporal', 'undirected']
# *** Importing module .statistics.spectral
# [7] Adding SPI .statistics.spectral.CoherenceMagnitude(x,y,{'fs': 1})...
# Succesfully initialised SPI with identifier "cohmag_multitaper_mean_fs-1_fmin-0_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [8] Adding SPI .statistics.spectral.PhaseSlopeIndex(x,y,{'fmin': 0, 'fmax': 0.5})...
# Succesfully initialised SPI with identifier "psi_multitaper_mean_fs-1_fmin-0_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [9] Adding SPI .statistics.spectral.PhaseLagIndex(x,y,{'fs': 1, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "pli_multitaper_max_fs-1_fmin-0_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [10] Adding SPI .statistics.spectral.SpectralGrangerCausality(x,y,{'method': 'nonparametric', 'fmin': 0, 'fmax': 0.5, 'statistic': 'mean'})...
# Succesfully initialised SPI with identifier "sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5" and labels ['unsigned', 'embedding', 'spectral', 'directed', 'lagged']
# *** Importing module .statistics.wavelet
# [11] Adding SPI .statistics.wavelet.PhaseSlopeIndex(x,y,{'fs': 1})...
# Succesfully initialised SPI with identifier "psi_wavelet_mean_fs-1_fmin-0_fmax-0-5_mean" and labels ['unsigned', 'wavelet', 'undirected']
# *** Importing module .statistics.misc
# [12] Adding SPI .statistics.misc.Cointegration(x,y,{'method': 'aeg', 'statistic': 'tstat', 'autolag': 'aic', 'maxlag': 10, 'trend': 'ct'})...
# Succesfully initialised SPI with identifier "coint_aeg_tstat_trend-ct_autolag-aic_maxlag-10" and labels ['misc', 'unsigned', 'temporal', 'undirected', 'nonlinear']
# [13] Adding SPI .statistics.misc.PowerEnvelopeCorrelation(x,y,{'orth': False, 'log': False, 'absolute': False})...
# Succesfully initialised SPI with identifier "pec" and labels ['unsigned', 'misc', 'undirected']
# Number of SPIs: 14
# Processing [None: cohmag_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  50%|█████     | 7/14 [00:09<00:08,  1.22s/it]Mean of empty slice
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  50%|█████     | 7/14 [00:09<00:08,  1.22s/it]Mean of empty slice
# Processing [None: pec]: 100%|██████████| 14/14 [00:10<00:00,  1.32it/s]

# %%
# Separate out: 
# stimulus_type is face
# relevance_type is Relevant non-target
# duration is 0.5 
# meta_ROI is IIT 
# frequency_band is alpha

example_TS_data = sample_TS_data.query('stimulus_type == "face" & relevance_type == "Relevant non-target" and duration == 0.5 and frequency_band == "alpha"')

# Pivot so that the columns are meta_ROI and the rows are data
example_TS_data = example_TS_data.pivot(index='meta_ROI', columns='times', values='data')

# Convert to numpy array
example_TS_array = example_TS_data.to_numpy()

# %%
np.save("example_array.npy", TS_array)

# %%
calc = Calculator(dataset=example_TS_array)
calc.compute()
# Out:
# Loading configuration file: /headnode1/abry4213/.conda/envs/pyspi_new/lib/python3.10/site-packages/pyspi/config.yaml
# Frequency minimum set to 0; overriding to 1e-5.
# *** Importing module .statistics.basic
# [0] Adding SPI .statistics.basic.Covariance(x,y,{'estimator': 'EmpiricalCovariance'})
# Succesfully initialised SPI with identifier "cov_EmpiricalCovariance" and labels ['basic', 'unordered', 'linear', 'undirected', 'signed']
# [1] Adding SPI .statistics.basic.Covariance(x,y,{'estimator': 'EllipticEnvelope'})
# Succesfully initialised SPI with identifier "cov_EllipticEnvelope" and labels ['basic', 'unordered', 'linear', 'undirected', 'signed']
# [2] Adding SPI .statistics.basic.Covariance(x,y,{'estimator': 'GraphicalLasso'})
# Succesfully initialised SPI with identifier "cov_GraphicalLasso" and labels ['basic', 'unordered', 'linear', 'undirected', 'signed']
# [3] Adding SPI .statistics.basic.Covariance(x,y,{'estimator': 'GraphicalLassoCV'})
# Succesfully initialised SPI with identifier "cov_GraphicalLassoCV" and labels ['basic', 'unordered', 'linear', 'undirected', 'signed']
# [4] Adding SPI .statistics.basic.Covariance(x,y,{'estimator': 'LedoitWolf'})
# Succesfully initialised SPI with identifier "cov_LedoitWolf" and labels ['basic', 'unordered', 'linear', 'undirected', 'signed']
# [5] Adding SPI .statistics.basic.Covariance(x,y,{'estimator': 'MinCovDet'})
# Succesfully initialised SPI with identifier "cov_MinCovDet" and labels ['basic', 'unordered', 'linear', 'undirected', 'signed']
# [6] Adding SPI .statistics.basic.Covariance(x,y,{'estimator': 'OAS'})
# Succesfully initialised SPI with identifier "cov_OAS" and labels ['basic', 'unordered', 'linear', 'undirected', 'signed']
# [7] Adding SPI .statistics.basic.Covariance(x,y,{'estimator': 'ShrunkCovariance'})
# Succesfully initialised SPI with identifier "cov_ShrunkCovariance" and labels ['basic', 'unordered', 'linear', 'undirected', 'signed']
# [8] Adding SPI .statistics.basic.Covariance(x,y,{'estimator': 'EmpiricalCovariance', 'squared': True})
# Succesfully initialised SPI with identifier "cov-sq_EmpiricalCovariance" and labels ['basic', 'unordered', 'linear', 'undirected', 'unsigned']
# [9] Adding SPI .statistics.basic.Covariance(x,y,{'estimator': 'EllipticEnvelope', 'squared': True})
# Succesfully initialised SPI with identifier "cov-sq_EllipticEnvelope" and labels ['basic', 'unordered', 'linear', 'undirected', 'unsigned']
# [10] Adding SPI .statistics.basic.Covariance(x,y,{'estimator': 'GraphicalLasso', 'squared': True})
# Succesfully initialised SPI with identifier "cov-sq_GraphicalLasso" and labels ['basic', 'unordered', 'linear', 'undirected', 'unsigned']
# [11] Adding SPI .statistics.basic.Covariance(x,y,{'estimator': 'GraphicalLassoCV', 'squared': True})
# Succesfully initialised SPI with identifier "cov-sq_GraphicalLassoCV" and labels ['basic', 'unordered', 'linear', 'undirected', 'unsigned']
# [12] Adding SPI .statistics.basic.Covariance(x,y,{'estimator': 'LedoitWolf', 'squared': True})
# Succesfully initialised SPI with identifier "cov-sq_LedoitWolf" and labels ['basic', 'unordered', 'linear', 'undirected', 'unsigned']
# [13] Adding SPI .statistics.basic.Covariance(x,y,{'estimator': 'MinCovDet', 'squared': True})
# Succesfully initialised SPI with identifier "cov-sq_MinCovDet" and labels ['basic', 'unordered', 'linear', 'undirected', 'unsigned']
# [14] Adding SPI .statistics.basic.Covariance(x,y,{'estimator': 'OAS', 'squared': True})
# Succesfully initialised SPI with identifier "cov-sq_OAS" and labels ['basic', 'unordered', 'linear', 'undirected', 'unsigned']
# [15] Adding SPI .statistics.basic.Covariance(x,y,{'estimator': 'ShrunkCovariance', 'squared': True})
# Succesfully initialised SPI with identifier "cov-sq_ShrunkCovariance" and labels ['basic', 'unordered', 'linear', 'undirected', 'unsigned']
# [16] Adding SPI .statistics.basic.Precision(x,y,{'estimator': 'EmpiricalCovariance'})
# Succesfully initialised SPI with identifier "prec_EmpiricalCovariance" and labels ['basic', 'unordered', 'linear', 'undirected', 'signed']
# [17] Adding SPI .statistics.basic.Precision(x,y,{'estimator': 'EllipticEnvelope'})
# Succesfully initialised SPI with identifier "prec_EllipticEnvelope" and labels ['basic', 'unordered', 'linear', 'undirected', 'signed']
# [18] Adding SPI .statistics.basic.Precision(x,y,{'estimator': 'GraphicalLasso'})
# Succesfully initialised SPI with identifier "prec_GraphicalLasso" and labels ['basic', 'unordered', 'linear', 'undirected', 'signed']
# [19] Adding SPI .statistics.basic.Precision(x,y,{'estimator': 'GraphicalLassoCV'})
# Succesfully initialised SPI with identifier "prec_GraphicalLassoCV" and labels ['basic', 'unordered', 'linear', 'undirected', 'signed']
# [20] Adding SPI .statistics.basic.Precision(x,y,{'estimator': 'LedoitWolf'})
# Succesfully initialised SPI with identifier "prec_LedoitWolf" and labels ['basic', 'unordered', 'linear', 'undirected', 'signed']
# [21] Adding SPI .statistics.basic.Precision(x,y,{'estimator': 'MinCovDet'})
# Succesfully initialised SPI with identifier "prec_MinCovDet" and labels ['basic', 'unordered', 'linear', 'undirected', 'signed']
# [22] Adding SPI .statistics.basic.Precision(x,y,{'estimator': 'OAS'})
# Succesfully initialised SPI with identifier "prec_OAS" and labels ['basic', 'unordered', 'linear', 'undirected', 'signed']
# [23] Adding SPI .statistics.basic.Precision(x,y,{'estimator': 'ShrunkCovariance'})
# Succesfully initialised SPI with identifier "prec_ShrunkCovariance" and labels ['basic', 'unordered', 'linear', 'undirected', 'signed']
# [24] Adding SPI .statistics.basic.Precision(x,y,{'estimator': 'EmpiricalCovariance', 'squared': True})
# Succesfully initialised SPI with identifier "prec-sq_EmpiricalCovariance" and labels ['basic', 'unordered', 'linear', 'undirected', 'unsigned']
# [25] Adding SPI .statistics.basic.Precision(x,y,{'estimator': 'EllipticEnvelope', 'squared': True})
# Succesfully initialised SPI with identifier "prec-sq_EllipticEnvelope" and labels ['basic', 'unordered', 'linear', 'undirected', 'unsigned']
# [26] Adding SPI .statistics.basic.Precision(x,y,{'estimator': 'GraphicalLasso', 'squared': True})
# Succesfully initialised SPI with identifier "prec-sq_GraphicalLasso" and labels ['basic', 'unordered', 'linear', 'undirected', 'unsigned']
# [27] Adding SPI .statistics.basic.Precision(x,y,{'estimator': 'GraphicalLassoCV', 'squared': True})
# Succesfully initialised SPI with identifier "prec-sq_GraphicalLassoCV" and labels ['basic', 'unordered', 'linear', 'undirected', 'unsigned']
# [28] Adding SPI .statistics.basic.Precision(x,y,{'estimator': 'LedoitWolf', 'squared': True})
# Succesfully initialised SPI with identifier "prec-sq_LedoitWolf" and labels ['basic', 'unordered', 'linear', 'undirected', 'unsigned']
# [29] Adding SPI .statistics.basic.Precision(x,y,{'estimator': 'MinCovDet', 'squared': True})
# Succesfully initialised SPI with identifier "prec-sq_MinCovDet" and labels ['basic', 'unordered', 'linear', 'undirected', 'unsigned']
# [30] Adding SPI .statistics.basic.Precision(x,y,{'estimator': 'OAS', 'squared': True})
# Succesfully initialised SPI with identifier "prec-sq_OAS" and labels ['basic', 'unordered', 'linear', 'undirected', 'unsigned']
# [31] Adding SPI .statistics.basic.Precision(x,y,{'estimator': 'ShrunkCovariance', 'squared': True})
# Succesfully initialised SPI with identifier "prec-sq_ShrunkCovariance" and labels ['basic', 'unordered', 'linear', 'undirected', 'unsigned']
# [32] Adding SPI .statistics.basic.SpearmanR(x,y,{'squared': True})
# Succesfully initialised SPI with identifier "spearmanr-sq" and labels ['basic', 'unordered', 'rank', 'linear', 'undirected', 'unsigned', 'signed', 'unsigned']
# [33] Adding SPI .statistics.basic.SpearmanR(x,y,{'squared': False})
# Succesfully initialised SPI with identifier "spearmanr" and labels ['basic', 'unordered', 'rank', 'linear', 'undirected', 'unsigned', 'signed', 'unsigned', 'signed']
# [34] Adding SPI .statistics.basic.KendallTau(x,y,{'squared': True})
# Succesfully initialised SPI with identifier "kendalltau-sq" and labels ['basic', 'unordered', 'rank', 'linear', 'undirected', 'unsigned', 'signed', 'unsigned']
# [35] Adding SPI .statistics.basic.KendallTau(x,y,{'squared': False})
# Succesfully initialised SPI with identifier "kendalltau" and labels ['basic', 'unordered', 'rank', 'linear', 'undirected', 'unsigned', 'signed', 'unsigned', 'signed']
# [36] Adding SPI .statistics.basic.CrossCorrelation(x,y,{'statistic': 'max'})
# Succesfully initialised SPI with identifier "xcorr_max_sig-True" and labels ['basic', 'linear', 'undirected', 'temporal', 'signed']
# [37] Adding SPI .statistics.basic.CrossCorrelation(x,y,{'statistic': 'max', 'squared': True})
# Succesfully initialised SPI with identifier "xcorr-sq_max_sig-True" and labels ['basic', 'linear', 'undirected', 'temporal', 'unsigned']
# [38] Adding SPI .statistics.basic.CrossCorrelation(x,y,{'statistic': 'mean'})
# Succesfully initialised SPI with identifier "xcorr_mean_sig-True" and labels ['basic', 'linear', 'undirected', 'temporal', 'signed']
# [39] Adding SPI .statistics.basic.CrossCorrelation(x,y,{'statistic': 'mean', 'squared': True})
# Succesfully initialised SPI with identifier "xcorr-sq_mean_sig-True" and labels ['basic', 'linear', 'undirected', 'temporal', 'unsigned']
# [40] Adding SPI .statistics.basic.CrossCorrelation(x,y,{'statistic': 'mean', 'sigonly': False})
# Succesfully initialised SPI with identifier "xcorr_mean_sig-False" and labels ['basic', 'linear', 'undirected', 'temporal', 'signed']
# [41] Adding SPI .statistics.basic.CrossCorrelation(x,y,{'statistic': 'mean', 'squared': True, 'sigonly': False})
# Succesfully initialised SPI with identifier "xcorr-sq_mean_sig-False" and labels ['basic', 'linear', 'undirected', 'temporal', 'unsigned']
# *** Importing module .statistics.distance
# [42] Adding SPI .statistics.distance.PairwiseDistance(x,y,{'metric': 'euclidean'})
# Succesfully initialised SPI with identifier "pdist_euclidean" and labels ['unsigned', 'distance', 'unordered', 'nonlinear', 'undirected']
# [43] Adding SPI .statistics.distance.PairwiseDistance(x,y,{'metric': 'cityblock'})
# Succesfully initialised SPI with identifier "pdist_cityblock" and labels ['unsigned', 'distance', 'unordered', 'nonlinear', 'undirected']
# [44] Adding SPI .statistics.distance.PairwiseDistance(x,y,{'metric': 'cosine'})
# Succesfully initialised SPI with identifier "pdist_cosine" and labels ['unsigned', 'distance', 'unordered', 'nonlinear', 'undirected']
# [45] Adding SPI .statistics.distance.PairwiseDistance(x,y,{'metric': 'chebyshev'})
# Succesfully initialised SPI with identifier "pdist_chebyshev" and labels ['unsigned', 'distance', 'unordered', 'nonlinear', 'undirected']
# [46] Adding SPI .statistics.distance.PairwiseDistance(x,y,{'metric': 'canberra'})
# Succesfully initialised SPI with identifier "pdist_canberra" and labels ['unsigned', 'distance', 'unordered', 'nonlinear', 'undirected']
# [47] Adding SPI .statistics.distance.PairwiseDistance(x,y,{'metric': 'braycurtis'})
# Succesfully initialised SPI with identifier "pdist_braycurtis" and labels ['unsigned', 'distance', 'unordered', 'nonlinear', 'undirected']
# [48] Adding SPI .statistics.distance.DistanceCorrelation(x,y,{'biased': False})
# Succesfully initialised SPI with identifier "dcorr" and labels ['unsigned', 'distance', 'unordered', 'nonlinear', 'undirected']
# [49] Adding SPI .statistics.distance.DistanceCorrelation(x,y,{'biased': True})
# Succesfully initialised SPI with identifier "dcorr_biased" and labels ['unsigned', 'distance', 'unordered', 'nonlinear', 'undirected']
# [50] Adding SPI .statistics.distance.MultiscaleGraphCorrelation(x,y)...
# Succesfully initialised SPI with identifier "mgc" and labels ['distance', 'unsigned', 'unordered', 'nonlinear', 'undirected']
# [51] Adding SPI .statistics.distance.HilbertSchmidtIndependenceCriterion(x,y,{'biased': False})
# Succesfully initialised SPI with identifier "hsic" and labels ['unsigned', 'distance', 'unordered', 'nonlinear', 'undirected']
# [52] Adding SPI .statistics.distance.HilbertSchmidtIndependenceCriterion(x,y,{'biased': True})
# Succesfully initialised SPI with identifier "hsic_biased" and labels ['unsigned', 'distance', 'unordered', 'nonlinear', 'undirected']
# [53] Adding SPI .statistics.distance.HellerHellerGorfine(x,y)...
# Succesfully initialised SPI with identifier "hhg" and labels ['unsigned', 'distance', 'unordered', 'nonlinear', 'directed']
# [54] Adding SPI .statistics.distance.CrossMultiscaleGraphCorrelation(x,y,{'max_lag': 1})
# Succesfully initialised SPI with identifier "mgcx_maxlag-1" and labels ['unsigned', 'distance', 'temporal', 'directed', 'nonlinear']
# [55] Adding SPI .statistics.distance.CrossMultiscaleGraphCorrelation(x,y,{'max_lag': 10})
# Succesfully initialised SPI with identifier "mgcx_maxlag-10" and labels ['unsigned', 'distance', 'temporal', 'directed', 'nonlinear']
# [56] Adding SPI .statistics.distance.CrossDistanceCorrelation(x,y,{'max_lag': 1})
# Succesfully initialised SPI with identifier "dcorrx_maxlag-1" and labels ['distance', 'unsigned', 'temporal', 'directed', 'nonlinear']
# [57] Adding SPI .statistics.distance.CrossDistanceCorrelation(x,y,{'max_lag': 10})
# Succesfully initialised SPI with identifier "dcorrx_maxlag-10" and labels ['distance', 'unsigned', 'temporal', 'directed', 'nonlinear']
# [58] Adding SPI .statistics.distance.DynamicTimeWarping(x,y,{'global_constraint': None})
# Succesfully initialised SPI with identifier "dtw" and labels ['unsigned', 'distance', 'temporal', 'undirected', 'nonlinear']
# [59] Adding SPI .statistics.distance.DynamicTimeWarping(x,y,{'global_constraint': 'itakura'})
# Succesfully initialised SPI with identifier "dtw_constraint-itakura" and labels ['unsigned', 'distance', 'temporal', 'undirected', 'nonlinear']
# [60] Adding SPI .statistics.distance.DynamicTimeWarping(x,y,{'global_constraint': 'sakoe_chiba'})
# Succesfully initialised SPI with identifier "dtw_constraint-sakoe-chiba" and labels ['unsigned', 'distance', 'temporal', 'undirected', 'nonlinear']
# [61] Adding SPI .statistics.distance.SoftDynamicTimeWarping(x,y,{'global_constraint': None})
# Succesfully initialised SPI with identifier "softdtw" and labels ['unsigned', 'distance', 'temporal', 'undirected', 'nonlinear']
# [62] Adding SPI .statistics.distance.SoftDynamicTimeWarping(x,y,{'global_constraint': 'itakura'})
# Succesfully initialised SPI with identifier "softdtw_constraint-itakura" and labels ['unsigned', 'distance', 'temporal', 'undirected', 'nonlinear']
# [63] Adding SPI .statistics.distance.SoftDynamicTimeWarping(x,y,{'global_constraint': 'sakoe_chiba'})
# Succesfully initialised SPI with identifier "softdtw_constraint-sakoe-chiba" and labels ['unsigned', 'distance', 'temporal', 'undirected', 'nonlinear']
# [64] Adding SPI .statistics.distance.LongestCommonSubsequence(x,y,{'global_constraint': None})
# Succesfully initialised SPI with identifier "lcss" and labels ['unsigned', 'distance', 'temporal', 'undirected', 'nonlinear']
# [65] Adding SPI .statistics.distance.LongestCommonSubsequence(x,y,{'global_constraint': 'itakura'})
# Succesfully initialised SPI with identifier "lcss_constraint-itakura" and labels ['unsigned', 'distance', 'temporal', 'undirected', 'nonlinear']
# [66] Adding SPI .statistics.distance.LongestCommonSubsequence(x,y,{'global_constraint': 'sakoe_chiba'})
# Succesfully initialised SPI with identifier "lcss_constraint-sakoe-chiba" and labels ['unsigned', 'distance', 'temporal', 'undirected', 'nonlinear']
# [67] Adding SPI .statistics.distance.Barycenter(x,y,{'mode': 'euclidean', 'statistic': 'mean'})
# Succesfully initialised SPI with identifier "bary_euclidean_mean" and labels ['distance', 'signed', 'undirected', 'temporal', 'nonlinear']
# [68] Adding SPI .statistics.distance.Barycenter(x,y,{'mode': 'euclidean', 'statistic': 'max'})
# Succesfully initialised SPI with identifier "bary_euclidean_max" and labels ['distance', 'signed', 'undirected', 'temporal', 'nonlinear']
# [69] Adding SPI .statistics.distance.Barycenter(x,y,{'mode': 'dtw', 'statistic': 'mean'})
# Succesfully initialised SPI with identifier "bary_dtw_mean" and labels ['distance', 'signed', 'undirected', 'temporal', 'nonlinear']
# [70] Adding SPI .statistics.distance.Barycenter(x,y,{'mode': 'dtw', 'statistic': 'max'})
# Succesfully initialised SPI with identifier "bary_dtw_max" and labels ['distance', 'signed', 'undirected', 'temporal', 'nonlinear']
# [71] Adding SPI .statistics.distance.Barycenter(x,y,{'mode': 'sgddtw', 'statistic': 'mean'})
# Succesfully initialised SPI with identifier "bary_sgddtw_mean" and labels ['distance', 'signed', 'undirected', 'temporal', 'nonlinear']
# [72] Adding SPI .statistics.distance.Barycenter(x,y,{'mode': 'sgddtw', 'statistic': 'max'})
# Succesfully initialised SPI with identifier "bary_sgddtw_max" and labels ['distance', 'signed', 'undirected', 'temporal', 'nonlinear']
# [73] Adding SPI .statistics.distance.Barycenter(x,y,{'mode': 'softdtw', 'statistic': 'mean'})
# Succesfully initialised SPI with identifier "bary_softdtw_mean" and labels ['distance', 'signed', 'undirected', 'temporal', 'nonlinear']
# [74] Adding SPI .statistics.distance.Barycenter(x,y,{'mode': 'softdtw', 'statistic': 'max'})
# Succesfully initialised SPI with identifier "bary_softdtw_max" and labels ['distance', 'signed', 'undirected', 'temporal', 'nonlinear']
# [75] Adding SPI .statistics.distance.Barycenter(x,y,{'mode': 'euclidean', 'statistic': 'mean', 'squared': True})
# Succesfully initialised SPI with identifier "bary-sq_euclidean_mean" and labels ['distance', 'signed', 'undirected', 'temporal', 'nonlinear']
# [76] Adding SPI .statistics.distance.Barycenter(x,y,{'mode': 'euclidean', 'statistic': 'max', 'squared': True})
# Succesfully initialised SPI with identifier "bary-sq_euclidean_max" and labels ['distance', 'signed', 'undirected', 'temporal', 'nonlinear']
# [77] Adding SPI .statistics.distance.Barycenter(x,y,{'mode': 'dtw', 'statistic': 'mean', 'squared': True})
# Succesfully initialised SPI with identifier "bary-sq_dtw_mean" and labels ['distance', 'signed', 'undirected', 'temporal', 'nonlinear']
# [78] Adding SPI .statistics.distance.Barycenter(x,y,{'mode': 'dtw', 'statistic': 'max', 'squared': True})
# Succesfully initialised SPI with identifier "bary-sq_dtw_max" and labels ['distance', 'signed', 'undirected', 'temporal', 'nonlinear']
# [79] Adding SPI .statistics.distance.Barycenter(x,y,{'mode': 'sgddtw', 'statistic': 'mean', 'squared': True})
# Succesfully initialised SPI with identifier "bary-sq_sgddtw_mean" and labels ['distance', 'signed', 'undirected', 'temporal', 'nonlinear']
# [80] Adding SPI .statistics.distance.Barycenter(x,y,{'mode': 'sgddtw', 'statistic': 'max', 'squared': True})
# Succesfully initialised SPI with identifier "bary-sq_sgddtw_max" and labels ['distance', 'signed', 'undirected', 'temporal', 'nonlinear']
# [81] Adding SPI .statistics.distance.Barycenter(x,y,{'mode': 'softdtw', 'statistic': 'mean', 'squared': True})
# Succesfully initialised SPI with identifier "bary-sq_softdtw_mean" and labels ['distance', 'signed', 'undirected', 'temporal', 'nonlinear']
# [82] Adding SPI .statistics.distance.Barycenter(x,y,{'mode': 'softdtw', 'statistic': 'max', 'squared': True})
# Succesfully initialised SPI with identifier "bary-sq_softdtw_max" and labels ['distance', 'signed', 'undirected', 'temporal', 'nonlinear']
# [83] Adding SPI .statistics.distance.GromovWasserstainTau(x,y)...
# Succesfully initialised SPI with identifier "gwtau" and labels ['unsigned', 'distance', 'unordered', 'nonlinear', 'undirected']
# *** Importing module .statistics.causal
# [84] Adding SPI .statistics.causal.AdditiveNoiseModel(x,y)...
# Succesfully initialised SPI with identifier "anm" and labels ['unsigned', 'causal', 'unordered', 'linear', 'directed']
# [85] Adding SPI .statistics.causal.ConditionalDistributionSimilarity(x,y)...
# Succesfully initialised SPI with identifier "cds" and labels ['unsigned', 'causal', 'unordered', 'nonlinear', 'directed']
# [86] Adding SPI .statistics.causal.RegressionErrorCausalInference(x,y)...
# Succesfully initialised SPI with identifier "reci" and labels ['unsigned', 'causal', 'unordered', 'nonlinear', 'directed']
# [87] Adding SPI .statistics.causal.InformationGeometricConditionalIndependence(x,y)...
# Succesfully initialised SPI with identifier "igci" and labels ['causal', 'directed', 'nonlinear', 'unsigned', 'unordered']
# [88] Adding SPI .statistics.causal.ConvergentCrossMapping(x,y,{'statistic': 'mean'})
# Succesfully initialised SPI with identifier "ccm_E-None_mean" and labels ['causal', 'directed', 'nonlinear', 'temporal', 'signed']
# [89] Adding SPI .statistics.causal.ConvergentCrossMapping(x,y,{'statistic': 'max'})
# Succesfully initialised SPI with identifier "ccm_E-None_max" and labels ['causal', 'directed', 'nonlinear', 'temporal', 'signed']
# [90] Adding SPI .statistics.causal.ConvergentCrossMapping(x,y,{'statistic': 'diff'})
# Succesfully initialised SPI with identifier "ccm_E-None_diff" and labels ['causal', 'directed', 'nonlinear', 'temporal', 'signed']
# [91] Adding SPI .statistics.causal.ConvergentCrossMapping(x,y,{'statistic': 'mean', 'embedding_dimension': 1})
# Succesfully initialised SPI with identifier "ccm_E-1_mean" and labels ['causal', 'directed', 'nonlinear', 'temporal', 'signed']
# [92] Adding SPI .statistics.causal.ConvergentCrossMapping(x,y,{'statistic': 'max', 'embedding_dimension': 1})
# Succesfully initialised SPI with identifier "ccm_E-1_max" and labels ['causal', 'directed', 'nonlinear', 'temporal', 'signed']
# [93] Adding SPI .statistics.causal.ConvergentCrossMapping(x,y,{'statistic': 'diff', 'embedding_dimension': 1})
# Succesfully initialised SPI with identifier "ccm_E-1_diff" and labels ['causal', 'directed', 'nonlinear', 'temporal', 'signed']
# [94] Adding SPI .statistics.causal.ConvergentCrossMapping(x,y,{'statistic': 'mean', 'embedding_dimension': 10})
# Succesfully initialised SPI with identifier "ccm_E-10_mean" and labels ['causal', 'directed', 'nonlinear', 'temporal', 'signed']
# [95] Adding SPI .statistics.causal.ConvergentCrossMapping(x,y,{'statistic': 'max', 'embedding_dimension': 10})
# Succesfully initialised SPI with identifier "ccm_E-10_max" and labels ['causal', 'directed', 'nonlinear', 'temporal', 'signed']
# [96] Adding SPI .statistics.causal.ConvergentCrossMapping(x,y,{'statistic': 'diff', 'embedding_dimension': 10})
# Succesfully initialised SPI with identifier "ccm_E-10_diff" and labels ['causal', 'directed', 'nonlinear', 'temporal', 'signed']
# *** Importing module .statistics.infotheory
# [97] Adding SPI .statistics.infotheory.JointEntropy(x,y,{'estimator': 'gaussian'})
# Succesfully initialised SPI with identifier "je_gaussian" and labels ['unsigned', 'infotheory', 'unordered', 'undirected', 'linear']
# [98] Adding SPI .statistics.infotheory.JointEntropy(x,y,{'estimator': 'kozachenko'})
# Succesfully initialised SPI with identifier "je_kozachenko" and labels ['unsigned', 'infotheory', 'unordered', 'undirected', 'linear']
# [99] Adding SPI .statistics.infotheory.JointEntropy(x,y,{'estimator': 'kernel'})
# Succesfully initialised SPI with identifier "je_kernel_W-0.5" and labels ['unsigned', 'infotheory', 'unordered', 'undirected', 'nonlinear']
# [100] Adding SPI .statistics.infotheory.ConditionalEntropy(x,y,{'estimator': 'gaussian'})
# Succesfully initialised SPI with identifier "ce_gaussian" and labels ['unsigned', 'infotheory', 'unordered', 'directed', 'linear']
# [101] Adding SPI .statistics.infotheory.ConditionalEntropy(x,y,{'estimator': 'kozachenko'})
# Succesfully initialised SPI with identifier "ce_kozachenko" and labels ['unsigned', 'infotheory', 'unordered', 'directed', 'linear']
# [102] Adding SPI .statistics.infotheory.ConditionalEntropy(x,y,{'estimator': 'kernel'})
# Succesfully initialised SPI with identifier "ce_kernel_W-0.5" and labels ['unsigned', 'infotheory', 'unordered', 'directed', 'nonlinear']
# [103] Adding SPI .statistics.infotheory.CausalEntropy(x,y,{'estimator': 'gaussian'})
# Succesfully initialised SPI with identifier "cce_gaussian" and labels ['unsigned', 'infotheory', 'temporal', 'directed', 'linear']
# [104] Adding SPI .statistics.infotheory.CausalEntropy(x,y,{'estimator': 'kozachenko'})
# Succesfully initialised SPI with identifier "cce_kozachenko" and labels ['unsigned', 'infotheory', 'temporal', 'directed', 'linear']
# [105] Adding SPI .statistics.infotheory.CausalEntropy(x,y,{'estimator': 'kernel'})
# Succesfully initialised SPI with identifier "cce_kernel_W-0.5" and labels ['unsigned', 'infotheory', 'temporal', 'directed', 'nonlinear']
# [106] Adding SPI .statistics.infotheory.CrossmapEntropy(x,y,{'estimator': 'gaussian', 'history_length': 1})
# Succesfully initialised SPI with identifier "xme_gaussian_k1" and labels ['unsigned', 'infotheory', 'temporal', 'directed', 'linear']
# [107] Adding SPI .statistics.infotheory.CrossmapEntropy(x,y,{'estimator': 'kozachenko', 'history_length': 1})
# Succesfully initialised SPI with identifier "xme_kozachenko_k1" and labels ['unsigned', 'infotheory', 'temporal', 'directed', 'linear']
# [108] Adding SPI .statistics.infotheory.CrossmapEntropy(x,y,{'estimator': 'kernel', 'history_length': 1})
# Succesfully initialised SPI with identifier "xme_kernel_W-0.5_k1" and labels ['unsigned', 'infotheory', 'temporal', 'directed', 'nonlinear']
# [109] Adding SPI .statistics.infotheory.CrossmapEntropy(x,y,{'estimator': 'gaussian', 'history_length': 10})
# Succesfully initialised SPI with identifier "xme_gaussian_k10" and labels ['unsigned', 'infotheory', 'temporal', 'directed', 'linear']
# [110] Adding SPI .statistics.infotheory.CrossmapEntropy(x,y,{'estimator': 'kozachenko', 'history_length': 10})
# Succesfully initialised SPI with identifier "xme_kozachenko_k10" and labels ['unsigned', 'infotheory', 'temporal', 'directed', 'linear']
# [111] Adding SPI .statistics.infotheory.CrossmapEntropy(x,y,{'estimator': 'kernel', 'history_length': 10})
# Succesfully initialised SPI with identifier "xme_kernel_W-0.5_k10" and labels ['unsigned', 'infotheory', 'temporal', 'directed', 'nonlinear']
# [112] Adding SPI .statistics.infotheory.DirectedInfo(x,y,{'estimator': 'gaussian'})
# Succesfully initialised SPI with identifier "di_gaussian" and labels ['unsigned', 'infotheory', 'temporal', 'directed', 'linear']
# [113] Adding SPI .statistics.infotheory.DirectedInfo(x,y,{'estimator': 'kozachenko'})
# Succesfully initialised SPI with identifier "di_kozachenko" and labels ['unsigned', 'infotheory', 'temporal', 'directed', 'linear']
# [114] Adding SPI .statistics.infotheory.DirectedInfo(x,y,{'estimator': 'kernel'})
# Succesfully initialised SPI with identifier "di_kernel_W-0.5" and labels ['unsigned', 'infotheory', 'temporal', 'directed', 'nonlinear']
# [115] Adding SPI .statistics.infotheory.StochasticInteraction(x,y,{'estimator': 'gaussian'})
# Succesfully initialised SPI with identifier "si_gaussian_k-1" and labels ['unsigned', 'infotheory', 'temporal', 'undirected', 'linear']
# [116] Adding SPI .statistics.infotheory.StochasticInteraction(x,y,{'estimator': 'kozachenko'})
# Succesfully initialised SPI with identifier "si_kozachenko_k-1" and labels ['unsigned', 'infotheory', 'temporal', 'undirected', 'linear']
# [117] Adding SPI .statistics.infotheory.StochasticInteraction(x,y,{'estimator': 'kernel'})
# Succesfully initialised SPI with identifier "si_kernel_W-0.5_k-1" and labels ['unsigned', 'infotheory', 'temporal', 'undirected', 'nonlinear']
# [118] Adding SPI .statistics.infotheory.MutualInfo(x,y,{'estimator': 'gaussian'})
# Succesfully initialised SPI with identifier "mi_gaussian" and labels ['unsigned', 'infotheory', 'unordered', 'undirected', 'linear']
# [119] Adding SPI .statistics.infotheory.MutualInfo(x,y,{'estimator': 'kraskov', 'prop_k': 4})
# Succesfully initialised SPI with identifier "mi_kraskov_NN-4" and labels ['unsigned', 'infotheory', 'unordered', 'undirected', 'nonlinear']
# [120] Adding SPI .statistics.infotheory.MutualInfo(x,y,{'estimator': 'kraskov', 'prop_k': 4, 'dyn_corr_excl': 'AUTO'})
# Succesfully initialised SPI with identifier "mi_kraskov_NN-4_DCE" and labels ['unsigned', 'infotheory', 'unordered', 'undirected', 'nonlinear']
# [121] Adding SPI .statistics.infotheory.MutualInfo(x,y,{'estimator': 'kernel', 'kernel_width': 0.25})
# Succesfully initialised SPI with identifier "mi_kernel_W-0.25" and labels ['unsigned', 'infotheory', 'unordered', 'undirected', 'nonlinear']
# [122] Adding SPI .statistics.infotheory.TimeLaggedMutualInfo(x,y,{'estimator': 'gaussian'})
# Succesfully initialised SPI with identifier "tlmi_gaussian" and labels ['unsigned', 'infotheory', 'temporal', 'undirected', 'linear']
# [123] Adding SPI .statistics.infotheory.TimeLaggedMutualInfo(x,y,{'estimator': 'kraskov', 'prop_k': 4})
# Succesfully initialised SPI with identifier "tlmi_kraskov_NN-4" and labels ['unsigned', 'infotheory', 'temporal', 'undirected', 'nonlinear']
# [124] Adding SPI .statistics.infotheory.TimeLaggedMutualInfo(x,y,{'estimator': 'kraskov', 'prop_k': 4, 'dyn_corr_excl': 'AUTO'})
# Succesfully initialised SPI with identifier "tlmi_kraskov_NN-4_DCE" and labels ['unsigned', 'infotheory', 'temporal', 'undirected', 'nonlinear']
# [125] Adding SPI .statistics.infotheory.TimeLaggedMutualInfo(x,y,{'estimator': 'kernel', 'kernel_width': 0.25})
# Succesfully initialised SPI with identifier "tlmi_kernel_W-0.25" and labels ['unsigned', 'infotheory', 'temporal', 'undirected', 'nonlinear']
# [126] Adding SPI .statistics.infotheory.TransferEntropy(x,y,{'estimator': 'kraskov', 'prop_k': 4, 'auto_embed_method': 'MAX_CORR_AIS', 'k_search_max': 10, 'tau_search_max': 4})
# Succesfully initialised SPI with identifier "te_kraskov_NN-4_k-max-10_tau-max-4" and labels ['unsigned', 'embedding', 'infotheory', 'temporal', 'directed', 'nonlinear']
# [127] Adding SPI .statistics.infotheory.TransferEntropy(x,y,{'estimator': 'kraskov', 'prop_k': 4, 'auto_embed_method': 'MAX_CORR_AIS', 'k_search_max': 10, 'tau_search_max': 4, 'dyn_corr_excl': 'AUTO'})
# Succesfully initialised SPI with identifier "te_kraskov_NN-4_DCE_k-max-10_tau-max-4" and labels ['unsigned', 'embedding', 'infotheory', 'temporal', 'directed', 'nonlinear']
# [128] Adding SPI .statistics.infotheory.TransferEntropy(x,y,{'estimator': 'kraskov', 'prop_k': 4, 'k_history': 2, 'l_history': 1, 'dyn_corr_excl': 'AUTO'})
# Succesfully initialised SPI with identifier "te_kraskov_NN-4_DCE_k-2_kt-1_l-1_lt-1" and labels ['unsigned', 'embedding', 'infotheory', 'temporal', 'directed', 'nonlinear']
# [129] Adding SPI .statistics.infotheory.TransferEntropy(x,y,{'estimator': 'kraskov', 'prop_k': 4, 'k_history': 1, 'l_history': 1, 'dyn_corr_excl': 'AUTO'})
# Succesfully initialised SPI with identifier "te_kraskov_NN-4_DCE_k-1_kt-1_l-1_lt-1" and labels ['unsigned', 'embedding', 'infotheory', 'temporal', 'directed', 'nonlinear']
# [130] Adding SPI .statistics.infotheory.TransferEntropy(x,y,{'estimator': 'kraskov', 'prop_k': 4, 'k_history': 1, 'l_history': 1})
# Succesfully initialised SPI with identifier "te_kraskov_NN-4_k-1_kt-1_l-1_lt-1" and labels ['unsigned', 'embedding', 'infotheory', 'temporal', 'directed', 'nonlinear']
# [131] Adding SPI .statistics.infotheory.TransferEntropy(x,y,{'estimator': 'kernel', 'kernel_width': 0.25, 'k_history': 1, 'l_history': 1})
# Succesfully initialised SPI with identifier "te_kernel_W-0.25_k-1" and labels ['unsigned', 'embedding', 'infotheory', 'temporal', 'directed', 'nonlinear']
# [132] Adding SPI .statistics.infotheory.TransferEntropy(x,y,{'estimator': 'gaussian', 'auto_embed_method': 'MAX_CORR_AIS', 'k_search_max': 10, 'tau_search_max': 2})
# Succesfully initialised SPI with identifier "gc_gaussian_k-max-10_tau-max-2" and labels ['unsigned', 'embedding', 'infotheory', 'temporal', 'directed', 'linear']
# [133] Adding SPI .statistics.infotheory.TransferEntropy(x,y,{'estimator': 'gaussian', 'k_history': 1, 'l_history': 1})
# Succesfully initialised SPI with identifier "gc_gaussian_k-1_kt-1_l-1_lt-1" and labels ['unsigned', 'embedding', 'infotheory', 'temporal', 'directed', 'linear']
# [134] Adding SPI .statistics.infotheory.TransferEntropy(x,y,{'estimator': 'symbolic', 'k_history': 1, 'l_history': 1})
# Succesfully initialised SPI with identifier "te_symbolic_k-1_kt-1_l-1_lt-1" and labels ['unsigned', 'embedding', 'infotheory', 'temporal', 'directed', 'symbolic']
# [135] Adding SPI .statistics.infotheory.TransferEntropy(x,y,{'estimator': 'symbolic', 'k_history': 10, 'l_history': 1})
# Succesfully initialised SPI with identifier "te_symbolic_k-10_kt-1_l-1_lt-1" and labels ['unsigned', 'embedding', 'infotheory', 'temporal', 'directed', 'symbolic']
# [136] Adding SPI .statistics.infotheory.IntegratedInformation(x,y,{'phitype': 'star'})
# Succesfully initialised SPI with identifier "phi_star_t-1_norm-0" and labels ['linear', 'unsigned', 'infotheory', 'temporal', 'undirected']
# [137] Adding SPI .statistics.infotheory.IntegratedInformation(x,y,{'phitype': 'star', 'normalization': 1})
# Succesfully initialised SPI with identifier "phi_star_t-1_norm-1" and labels ['linear', 'unsigned', 'infotheory', 'temporal', 'undirected']
# [138] Adding SPI .statistics.infotheory.IntegratedInformation(x,y,{'phitype': 'Geo'})
# Succesfully initialised SPI with identifier "phi_Geo_t-1_norm-0" and labels ['linear', 'unsigned', 'infotheory', 'temporal', 'undirected']
# [139] Adding SPI .statistics.infotheory.IntegratedInformation(x,y,{'phitype': 'Geo', 'normalization': 1})
# Succesfully initialised SPI with identifier "phi_Geo_t-1_norm-1" and labels ['linear', 'unsigned', 'infotheory', 'temporal', 'undirected']
# *** Importing module .statistics.spectral
# [140] Adding SPI .statistics.spectral.CoherencePhase(x,y,{'fs': 1})
# Succesfully initialised SPI with identifier "phase_multitaper_mean_fs-1_fmin-0_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [141] Adding SPI .statistics.spectral.CoherencePhase(x,y,{'fmin': 0, 'fmax': 0.25})
# Succesfully initialised SPI with identifier "phase_multitaper_mean_fs-1_fmin-0_fmax-0-25" and labels ['unsigned', 'spectral', 'undirected']
# [142] Adding SPI .statistics.spectral.CoherencePhase(x,y,{'fmin': 0.25, 'fmax': 0.5})
# Succesfully initialised SPI with identifier "phase_multitaper_mean_fs-1_fmin-0-25_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [143] Adding SPI .statistics.spectral.CoherencePhase(x,y,{'fs': 1, 'statistic': 'max'})
# Succesfully initialised SPI with identifier "phase_multitaper_max_fs-1_fmin-0_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [144] Adding SPI .statistics.spectral.CoherencePhase(x,y,{'fmin': 0, 'fmax': 0.25, 'statistic': 'max'})
# Succesfully initialised SPI with identifier "phase_multitaper_max_fs-1_fmin-0_fmax-0-25" and labels ['unsigned', 'spectral', 'undirected']
# [145] Adding SPI .statistics.spectral.CoherencePhase(x,y,{'fmin': 0.25, 'fmax': 0.5, 'statistic': 'max'})
# Succesfully initialised SPI with identifier "phase_multitaper_max_fs-1_fmin-0-25_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [146] Adding SPI .statistics.spectral.CoherenceMagnitude(x,y,{'fs': 1})
# Succesfully initialised SPI with identifier "cohmag_multitaper_mean_fs-1_fmin-0_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [147] Adding SPI .statistics.spectral.CoherenceMagnitude(x,y,{'fmin': 0, 'fmax': 0.25})
# Succesfully initialised SPI with identifier "cohmag_multitaper_mean_fs-1_fmin-0_fmax-0-25" and labels ['unsigned', 'spectral', 'undirected']
# [148] Adding SPI .statistics.spectral.CoherenceMagnitude(x,y,{'fmin': 0.25, 'fmax': 0.5})
# Succesfully initialised SPI with identifier "cohmag_multitaper_mean_fs-1_fmin-0-25_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [149] Adding SPI .statistics.spectral.CoherenceMagnitude(x,y,{'fs': 1, 'statistic': 'max'})
# Succesfully initialised SPI with identifier "cohmag_multitaper_max_fs-1_fmin-0_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [150] Adding SPI .statistics.spectral.CoherenceMagnitude(x,y,{'fmin': 0, 'fmax': 0.25, 'statistic': 'max'})
# Succesfully initialised SPI with identifier "cohmag_multitaper_max_fs-1_fmin-0_fmax-0-25" and labels ['unsigned', 'spectral', 'undirected']
# [151] Adding SPI .statistics.spectral.CoherenceMagnitude(x,y,{'fmin': 0.25, 'fmax': 0.5, 'statistic': 'max'})
# Succesfully initialised SPI with identifier "cohmag_multitaper_max_fs-1_fmin-0-25_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [152] Adding SPI .statistics.spectral.ImaginaryCoherence(x,y,{'fs': 1})
# Succesfully initialised SPI with identifier "icoh_multitaper_mean_fs-1_fmin-0_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [153] Adding SPI .statistics.spectral.ImaginaryCoherence(x,y,{'fmin': 0, 'fmax': 0.25})
# Succesfully initialised SPI with identifier "icoh_multitaper_mean_fs-1_fmin-0_fmax-0-25" and labels ['unsigned', 'spectral', 'undirected']
# [154] Adding SPI .statistics.spectral.ImaginaryCoherence(x,y,{'fmin': 0.25, 'fmax': 0.5})
# Succesfully initialised SPI with identifier "icoh_multitaper_mean_fs-1_fmin-0-25_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [155] Adding SPI .statistics.spectral.ImaginaryCoherence(x,y,{'fs': 1, 'statistic': 'max'})
# Succesfully initialised SPI with identifier "icoh_multitaper_max_fs-1_fmin-0_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [156] Adding SPI .statistics.spectral.ImaginaryCoherence(x,y,{'fmin': 0, 'fmax': 0.25, 'statistic': 'max'})
# Succesfully initialised SPI with identifier "icoh_multitaper_max_fs-1_fmin-0_fmax-0-25" and labels ['unsigned', 'spectral', 'undirected']
# [157] Adding SPI .statistics.spectral.ImaginaryCoherence(x,y,{'fmin': 0.25, 'fmax': 0.5, 'statistic': 'max'})
# Succesfully initialised SPI with identifier "icoh_multitaper_max_fs-1_fmin-0-25_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [158] Adding SPI .statistics.spectral.PhaseSlopeIndex(x,y,{'fmin': 0, 'fmax': 0.5})
# Succesfully initialised SPI with identifier "psi_multitaper_mean_fs-1_fmin-0_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [159] Adding SPI .statistics.spectral.PhaseSlopeIndex(x,y,{'fmin': 0, 'fmax': 0.25})
# Succesfully initialised SPI with identifier "psi_multitaper_mean_fs-1_fmin-0_fmax-0-25" and labels ['unsigned', 'spectral', 'undirected']
# [160] Adding SPI .statistics.spectral.PhaseSlopeIndex(x,y,{'fmin': 0.25, 'fmax': 0.5})
# Succesfully initialised SPI with identifier "psi_multitaper_mean_fs-1_fmin-0-25_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [161] Adding SPI .statistics.spectral.PhaseLockingValue(x,y,{'fs': 1})
# Succesfully initialised SPI with identifier "plv_multitaper_mean_fs-1_fmin-0_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [162] Adding SPI .statistics.spectral.PhaseLockingValue(x,y,{'fmin': 0, 'fmax': 0.25})
# Succesfully initialised SPI with identifier "plv_multitaper_mean_fs-1_fmin-0_fmax-0-25" and labels ['unsigned', 'spectral', 'undirected']
# [163] Adding SPI .statistics.spectral.PhaseLockingValue(x,y,{'fmin': 0.25, 'fmax': 0.5})
# Succesfully initialised SPI with identifier "plv_multitaper_mean_fs-1_fmin-0-25_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [164] Adding SPI .statistics.spectral.PhaseLockingValue(x,y,{'fs': 1, 'statistic': 'max'})
# Succesfully initialised SPI with identifier "plv_multitaper_max_fs-1_fmin-0_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [165] Adding SPI .statistics.spectral.PhaseLockingValue(x,y,{'fmin': 0, 'fmax': 0.25, 'statistic': 'max'})
# Succesfully initialised SPI with identifier "plv_multitaper_max_fs-1_fmin-0_fmax-0-25" and labels ['unsigned', 'spectral', 'undirected']
# [166] Adding SPI .statistics.spectral.PhaseLockingValue(x,y,{'fmin': 0.25, 'fmax': 0.5, 'statistic': 'max'})
# Succesfully initialised SPI with identifier "plv_multitaper_max_fs-1_fmin-0-25_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [167] Adding SPI .statistics.spectral.PhaseLagIndex(x,y,{'fs': 1})
# Succesfully initialised SPI with identifier "pli_multitaper_mean_fs-1_fmin-0_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [168] Adding SPI .statistics.spectral.PhaseLagIndex(x,y,{'fmin': 0, 'fmax': 0.25})
# Succesfully initialised SPI with identifier "pli_multitaper_mean_fs-1_fmin-0_fmax-0-25" and labels ['unsigned', 'spectral', 'undirected']
# [169] Adding SPI .statistics.spectral.PhaseLagIndex(x,y,{'fmin': 0.25, 'fmax': 0.5})
# Succesfully initialised SPI with identifier "pli_multitaper_mean_fs-1_fmin-0-25_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [170] Adding SPI .statistics.spectral.PhaseLagIndex(x,y,{'fs': 1, 'statistic': 'max'})
# Succesfully initialised SPI with identifier "pli_multitaper_max_fs-1_fmin-0_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [171] Adding SPI .statistics.spectral.PhaseLagIndex(x,y,{'fmin': 0, 'fmax': 0.25, 'statistic': 'max'})
# Succesfully initialised SPI with identifier "pli_multitaper_max_fs-1_fmin-0_fmax-0-25" and labels ['unsigned', 'spectral', 'undirected']
# [172] Adding SPI .statistics.spectral.PhaseLagIndex(x,y,{'fmin': 0.25, 'fmax': 0.5, 'statistic': 'max'})
# Succesfully initialised SPI with identifier "pli_multitaper_max_fs-1_fmin-0-25_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [173] Adding SPI .statistics.spectral.WeightedPhaseLagIndex(x,y,{'fs': 1})
# Succesfully initialised SPI with identifier "wpli_multitaper_mean_fs-1_fmin-0_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [174] Adding SPI .statistics.spectral.WeightedPhaseLagIndex(x,y,{'fmin': 0, 'fmax': 0.25})
# Succesfully initialised SPI with identifier "wpli_multitaper_mean_fs-1_fmin-0_fmax-0-25" and labels ['unsigned', 'spectral', 'undirected']
# [175] Adding SPI .statistics.spectral.WeightedPhaseLagIndex(x,y,{'fmin': 0.25, 'fmax': 0.5})
# Succesfully initialised SPI with identifier "wpli_multitaper_mean_fs-1_fmin-0-25_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [176] Adding SPI .statistics.spectral.WeightedPhaseLagIndex(x,y,{'fs': 1, 'statistic': 'max'})
# Succesfully initialised SPI with identifier "wpli_multitaper_max_fs-1_fmin-0_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [177] Adding SPI .statistics.spectral.WeightedPhaseLagIndex(x,y,{'fmin': 0, 'fmax': 0.25, 'statistic': 'max'})
# Succesfully initialised SPI with identifier "wpli_multitaper_max_fs-1_fmin-0_fmax-0-25" and labels ['unsigned', 'spectral', 'undirected']
# [178] Adding SPI .statistics.spectral.WeightedPhaseLagIndex(x,y,{'fmin': 0.25, 'fmax': 0.5, 'statistic': 'max'})
# Succesfully initialised SPI with identifier "wpli_multitaper_max_fs-1_fmin-0-25_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [179] Adding SPI .statistics.spectral.DebiasedSquaredPhaseLagIndex(x,y,{'fs': 1})
# Succesfully initialised SPI with identifier "dspli_multitaper_mean_fs-1_fmin-0_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [180] Adding SPI .statistics.spectral.DebiasedSquaredPhaseLagIndex(x,y,{'fmin': 0, 'fmax': 0.25})
# Succesfully initialised SPI with identifier "dspli_multitaper_mean_fs-1_fmin-0_fmax-0-25" and labels ['unsigned', 'spectral', 'undirected']
# [181] Adding SPI .statistics.spectral.DebiasedSquaredPhaseLagIndex(x,y,{'fmin': 0.25, 'fmax': 0.5})
# Succesfully initialised SPI with identifier "dspli_multitaper_mean_fs-1_fmin-0-25_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [182] Adding SPI .statistics.spectral.DebiasedSquaredPhaseLagIndex(x,y,{'fs': 1, 'statistic': 'max'})
# Succesfully initialised SPI with identifier "dspli_multitaper_max_fs-1_fmin-0_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [183] Adding SPI .statistics.spectral.DebiasedSquaredPhaseLagIndex(x,y,{'fmin': 0, 'fmax': 0.25, 'statistic': 'max'})
# Succesfully initialised SPI with identifier "dspli_multitaper_max_fs-1_fmin-0_fmax-0-25" and labels ['unsigned', 'spectral', 'undirected']
# [184] Adding SPI .statistics.spectral.DebiasedSquaredPhaseLagIndex(x,y,{'fmin': 0.25, 'fmax': 0.5, 'statistic': 'max'})
# Succesfully initialised SPI with identifier "dspli_multitaper_max_fs-1_fmin-0-25_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [185] Adding SPI .statistics.spectral.DebiasedSquaredWeightedPhaseLagIndex(x,y,{'fs': 1})
# Succesfully initialised SPI with identifier "dswpli_multitaper_mean_fs-1_fmin-0_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [186] Adding SPI .statistics.spectral.DebiasedSquaredWeightedPhaseLagIndex(x,y,{'fmin': 0, 'fmax': 0.25})
# Succesfully initialised SPI with identifier "dswpli_multitaper_mean_fs-1_fmin-0_fmax-0-25" and labels ['unsigned', 'spectral', 'undirected']
# [187] Adding SPI .statistics.spectral.DebiasedSquaredWeightedPhaseLagIndex(x,y,{'fmin': 0.25, 'fmax': 0.5})
# Succesfully initialised SPI with identifier "dswpli_multitaper_mean_fs-1_fmin-0-25_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [188] Adding SPI .statistics.spectral.DebiasedSquaredWeightedPhaseLagIndex(x,y,{'fs': 1, 'statistic': 'max'})
# Succesfully initialised SPI with identifier "dswpli_multitaper_max_fs-1_fmin-0_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [189] Adding SPI .statistics.spectral.DebiasedSquaredWeightedPhaseLagIndex(x,y,{'fmin': 0, 'fmax': 0.25, 'statistic': 'max'})
# Succesfully initialised SPI with identifier "dswpli_multitaper_max_fs-1_fmin-0_fmax-0-25" and labels ['unsigned', 'spectral', 'undirected']
# [190] Adding SPI .statistics.spectral.DebiasedSquaredWeightedPhaseLagIndex(x,y,{'fmin': 0.25, 'fmax': 0.5, 'statistic': 'max'})
# Succesfully initialised SPI with identifier "dswpli_multitaper_max_fs-1_fmin-0-25_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [191] Adding SPI .statistics.spectral.PairwisePhaseConsistency(x,y,{'fs': 1})
# Succesfully initialised SPI with identifier "ppc_multitaper_mean_fs-1_fmin-0_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [192] Adding SPI .statistics.spectral.PairwisePhaseConsistency(x,y,{'fmin': 0, 'fmax': 0.25})
# Succesfully initialised SPI with identifier "ppc_multitaper_mean_fs-1_fmin-0_fmax-0-25" and labels ['unsigned', 'spectral', 'undirected']
# [193] Adding SPI .statistics.spectral.PairwisePhaseConsistency(x,y,{'fmin': 0.25, 'fmax': 0.5})
# Succesfully initialised SPI with identifier "ppc_multitaper_mean_fs-1_fmin-0-25_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [194] Adding SPI .statistics.spectral.PairwisePhaseConsistency(x,y,{'fs': 1, 'statistic': 'max'})
# Succesfully initialised SPI with identifier "ppc_multitaper_max_fs-1_fmin-0_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [195] Adding SPI .statistics.spectral.PairwisePhaseConsistency(x,y,{'fmin': 0, 'fmax': 0.25, 'statistic': 'max'})
# Succesfully initialised SPI with identifier "ppc_multitaper_max_fs-1_fmin-0_fmax-0-25" and labels ['unsigned', 'spectral', 'undirected']
# [196] Adding SPI .statistics.spectral.PairwisePhaseConsistency(x,y,{'fmin': 0.25, 'fmax': 0.5, 'statistic': 'max'})
# Succesfully initialised SPI with identifier "ppc_multitaper_max_fs-1_fmin-0-25_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [197] Adding SPI .statistics.spectral.DirectedTransferFunction(x,y,{'fs': 1})
# Succesfully initialised SPI with identifier "dtf_multitaper_mean_fs-1_fmin-0_fmax-0-5" and labels ['unsigned', 'spectral', 'directed', 'lagged']
# [198] Adding SPI .statistics.spectral.DirectedTransferFunction(x,y,{'fmin': 0, 'fmax': 0.25})
# Succesfully initialised SPI with identifier "dtf_multitaper_mean_fs-1_fmin-0_fmax-0-25" and labels ['unsigned', 'spectral', 'directed', 'lagged']
# [199] Adding SPI .statistics.spectral.DirectedTransferFunction(x,y,{'fmin': 0.25, 'fmax': 0.5})
# Succesfully initialised SPI with identifier "dtf_multitaper_mean_fs-1_fmin-0-25_fmax-0-5" and labels ['unsigned', 'spectral', 'directed', 'lagged']
# [200] Adding SPI .statistics.spectral.DirectedTransferFunction(x,y,{'fs': 1, 'statistic': 'max'})
# Succesfully initialised SPI with identifier "dtf_multitaper_max_fs-1_fmin-0_fmax-0-5" and labels ['unsigned', 'spectral', 'directed', 'lagged']
# [201] Adding SPI .statistics.spectral.DirectedTransferFunction(x,y,{'fmin': 0, 'fmax': 0.25, 'statistic': 'max'})
# Succesfully initialised SPI with identifier "dtf_multitaper_max_fs-1_fmin-0_fmax-0-25" and labels ['unsigned', 'spectral', 'directed', 'lagged']
# [202] Adding SPI .statistics.spectral.DirectedTransferFunction(x,y,{'fmin': 0.25, 'fmax': 0.5, 'statistic': 'max'})
# ...
# [244] Adding SPI .statistics.spectral.SpectralGrangerCausality(x,y,{'fmin': 0.25, 'fmax': 0.5, 'order': 20, 'method': 'parametric', 'statistic': 'mean'})
# Succesfully initialised SPI with identifier "sgc_parametric_mean_fs-1_fmin-0-25_fmax-0-5_order-20" and labels ['unsigned', 'embedding', 'spectral', 'directed', 'lagged']
# [245] Adding SPI .statistics.spectral.SpectralGrangerCausality(x,y,{'fs': 1, 'method': 'parametric', 'statistic': 'max'})
# Succesfully initialised SPI with identifier "sgc_parametric_max_fs-1_fmin-1e-05_fmax-0-5_order-None" and labels ['unsigned', 'embedding', 'spectral', 'directed', 'lagged']
# [246] Adding SPI .statistics.spectral.SpectralGrangerCausality(x,y,{'fmin': 0, 'fmax': 0.25, 'method': 'parametric', 'statistic': 'max'})
# Succesfully initialised SPI with identifier "sgc_parametric_max_fs-1_fmin-0_fmax-0-25_order-None" and labels ['unsigned', 'embedding', 'spectral', 'directed', 'lagged']
# [247] Adding SPI .statistics.spectral.SpectralGrangerCausality(x,y,{'fmin': 0.25, 'fmax': 0.5, 'method': 'parametric', 'statistic': 'max'})
# Succesfully initialised SPI with identifier "sgc_parametric_max_fs-1_fmin-0-25_fmax-0-5_order-None" and labels ['unsigned', 'embedding', 'spectral', 'directed', 'lagged']
# [248] Adding SPI .statistics.spectral.SpectralGrangerCausality(x,y,{'fs': 1, 'order': 1, 'method': 'parametric', 'statistic': 'max'})
# Succesfully initialised SPI with identifier "sgc_parametric_max_fs-1_fmin-1e-05_fmax-0-5_order-1" and labels ['unsigned', 'embedding', 'spectral', 'directed', 'lagged']
# [249] Adding SPI .statistics.spectral.SpectralGrangerCausality(x,y,{'fmin': 0, 'fmax': 0.25, 'order': 1, 'method': 'parametric', 'statistic': 'max'})
# Succesfully initialised SPI with identifier "sgc_parametric_max_fs-1_fmin-0_fmax-0-25_order-1" and labels ['unsigned', 'embedding', 'spectral', 'directed', 'lagged']
# [250] Adding SPI .statistics.spectral.SpectralGrangerCausality(x,y,{'fmin': 0.25, 'fmax': 0.5, 'order': 1, 'method': 'parametric', 'statistic': 'max'})
# Succesfully initialised SPI with identifier "sgc_parametric_max_fs-1_fmin-0-25_fmax-0-5_order-1" and labels ['unsigned', 'embedding', 'spectral', 'directed', 'lagged']
# [251] Adding SPI .statistics.spectral.SpectralGrangerCausality(x,y,{'fs': 1, 'order': 20, 'method': 'parametric', 'statistic': 'max'})
# Succesfully initialised SPI with identifier "sgc_parametric_max_fs-1_fmin-1e-05_fmax-0-5_order-20" and labels ['unsigned', 'embedding', 'spectral', 'directed', 'lagged']
# [252] Adding SPI .statistics.spectral.SpectralGrangerCausality(x,y,{'fmin': 0, 'fmax': 0.25, 'order': 20, 'method': 'parametric', 'statistic': 'max'})
# Succesfully initialised SPI with identifier "sgc_parametric_max_fs-1_fmin-0_fmax-0-25_order-20" and labels ['unsigned', 'embedding', 'spectral', 'directed', 'lagged']
# [253] Adding SPI .statistics.spectral.SpectralGrangerCausality(x,y,{'fmin': 0.25, 'fmax': 0.5, 'order': 20, 'method': 'parametric', 'statistic': 'max'})
# Succesfully initialised SPI with identifier "sgc_parametric_max_fs-1_fmin-0-25_fmax-0-5_order-20" and labels ['unsigned', 'embedding', 'spectral', 'directed', 'lagged']
# *** Importing module .statistics.wavelet
# [254] Adding SPI .statistics.wavelet.PhaseSlopeIndex(x,y,{'fs': 1})
# Succesfully initialised SPI with identifier "psi_wavelet_mean_fs-1_fmin-0_fmax-0-5_mean" and labels ['unsigned', 'wavelet', 'undirected']
# [255] Adding SPI .statistics.wavelet.PhaseSlopeIndex(x,y,{'fmin': 0, 'fmax': 0.25})
# Succesfully initialised SPI with identifier "psi_wavelet_mean_fs-1_fmin-0_fmax-0-25_mean" and labels ['unsigned', 'wavelet', 'undirected']
# [256] Adding SPI .statistics.wavelet.PhaseSlopeIndex(x,y,{'fmin': 0.25, 'fmax': 0.5})
# Succesfully initialised SPI with identifier "psi_wavelet_mean_fs-1_fmin-0-25_fmax-0-5_mean" and labels ['unsigned', 'wavelet', 'undirected']
# [257] Adding SPI .statistics.wavelet.PhaseSlopeIndex(x,y,{'fmin': 0, 'fmax': 0.5, 'statistic': 'max'})
# Succesfully initialised SPI with identifier "psi_wavelet_max_fs-1_fmin-0_fmax-0-5_max" and labels ['unsigned', 'wavelet', 'undirected']
# [258] Adding SPI .statistics.wavelet.PhaseSlopeIndex(x,y,{'fmin': 0, 'fmax': 0.25, 'statistic': 'max'})
# Succesfully initialised SPI with identifier "psi_wavelet_max_fs-1_fmin-0_fmax-0-25_max" and labels ['unsigned', 'wavelet', 'undirected']
# [259] Adding SPI .statistics.wavelet.PhaseSlopeIndex(x,y,{'fmin': 0.25, 'fmax': 0.5, 'statistic': 'max'})
# Succesfully initialised SPI with identifier "psi_wavelet_max_fs-1_fmin-0-25_fmax-0-5_max" and labels ['unsigned', 'wavelet', 'undirected']
# *** Importing module .statistics.misc
# [260] Adding SPI .statistics.misc.LinearModel(x,y,{'model': 'Ridge'})
# Succesfully initialised SPI with identifier "lmfit_Ridge" and labels ['misc', 'unsigned', 'unordered', 'normal', 'linear', 'directed']
# [261] Adding SPI .statistics.misc.LinearModel(x,y,{'model': 'Lasso'})
# Succesfully initialised SPI with identifier "lmfit_Lasso" and labels ['misc', 'unsigned', 'unordered', 'normal', 'linear', 'directed']
# [262] Adding SPI .statistics.misc.LinearModel(x,y,{'model': 'SGDRegressor'})
# Succesfully initialised SPI with identifier "lmfit_SGDRegressor" and labels ['misc', 'unsigned', 'unordered', 'normal', 'linear', 'directed']
# [263] Adding SPI .statistics.misc.LinearModel(x,y,{'model': 'ElasticNet'})
# Succesfully initialised SPI with identifier "lmfit_ElasticNet" and labels ['misc', 'unsigned', 'unordered', 'normal', 'linear', 'directed']
# [264] Adding SPI .statistics.misc.LinearModel(x,y,{'model': 'BayesianRidge'})
# Succesfully initialised SPI with identifier "lmfit_BayesianRidge" and labels ['misc', 'unsigned', 'unordered', 'normal', 'linear', 'directed']
# [265] Adding SPI .statistics.misc.GPModel(x,y,{'kernel': 'DotProduct'})
# Succesfully initialised SPI with identifier "gpfit_DotProduct" and labels ['misc', 'unsigned', 'unordered', 'normal', 'nonlinear', 'directed']
# [266] Adding SPI .statistics.misc.GPModel(x,y,{'kernel': 'RBF'})
# Succesfully initialised SPI with identifier "gpfit_RBF" and labels ['misc', 'unsigned', 'unordered', 'normal', 'nonlinear', 'directed']
# [267] Adding SPI .statistics.misc.Cointegration(x,y,{'method': 'johansen', 'statistic': 'max_eig_stat', 'det_order': 0, 'k_ar_diff': 10})
# Succesfully initialised SPI with identifier "coint_johansen_max_eig_stat_order-0_ardiff-10" and labels ['misc', 'unsigned', 'temporal', 'undirected', 'nonlinear']
# [268] Adding SPI .statistics.misc.Cointegration(x,y,{'method': 'johansen', 'statistic': 'trace_stat', 'det_order': 0, 'k_ar_diff': 10})
# Succesfully initialised SPI with identifier "coint_johansen_trace_stat_order-0_ardiff-10" and labels ['misc', 'unsigned', 'temporal', 'undirected', 'nonlinear']
# [269] Adding SPI .statistics.misc.Cointegration(x,y,{'method': 'johansen', 'statistic': 'max_eig_stat', 'det_order': 0, 'k_ar_diff': 1})
# Succesfully initialised SPI with identifier "coint_johansen_max_eig_stat_order-0_ardiff-1" and labels ['misc', 'unsigned', 'temporal', 'undirected', 'nonlinear']
# [270] Adding SPI .statistics.misc.Cointegration(x,y,{'method': 'johansen', 'statistic': 'trace_stat', 'det_order': 0, 'k_ar_diff': 1})
# Succesfully initialised SPI with identifier "coint_johansen_trace_stat_order-0_ardiff-1" and labels ['misc', 'unsigned', 'temporal', 'undirected', 'nonlinear']
# [271] Adding SPI .statistics.misc.Cointegration(x,y,{'method': 'johansen', 'statistic': 'max_eig_stat', 'det_order': 1, 'k_ar_diff': 10})
# Succesfully initialised SPI with identifier "coint_johansen_max_eig_stat_order-1_ardiff-10" and labels ['misc', 'unsigned', 'temporal', 'undirected', 'nonlinear']
# [272] Adding SPI .statistics.misc.Cointegration(x,y,{'method': 'johansen', 'statistic': 'trace_stat', 'det_order': 1, 'k_ar_diff': 10})
# Succesfully initialised SPI with identifier "coint_johansen_trace_stat_order-1_ardiff-10" and labels ['misc', 'unsigned', 'temporal', 'undirected', 'nonlinear']
# [273] Adding SPI .statistics.misc.Cointegration(x,y,{'method': 'johansen', 'statistic': 'max_eig_stat', 'det_order': 1, 'k_ar_diff': 1})
# Succesfully initialised SPI with identifier "coint_johansen_max_eig_stat_order-1_ardiff-1" and labels ['misc', 'unsigned', 'temporal', 'undirected', 'nonlinear']
# [274] Adding SPI .statistics.misc.Cointegration(x,y,{'method': 'johansen', 'statistic': 'trace_stat', 'det_order': 1, 'k_ar_diff': 1})
# Succesfully initialised SPI with identifier "coint_johansen_trace_stat_order-1_ardiff-1" and labels ['misc', 'unsigned', 'temporal', 'undirected', 'nonlinear']
# [275] Adding SPI .statistics.misc.Cointegration(x,y,{'method': 'aeg', 'statistic': 'tstat', 'autolag': 'aic', 'maxlag': 10, 'trend': 'c'})
# Succesfully initialised SPI with identifier "coint_aeg_tstat_trend-c_autolag-aic_maxlag-10" and labels ['misc', 'unsigned', 'temporal', 'undirected', 'nonlinear']
# [276] Adding SPI .statistics.misc.Cointegration(x,y,{'method': 'aeg', 'statistic': 'tstat', 'autolag': 'aic', 'maxlag': 10, 'trend': 'ct'})
# Succesfully initialised SPI with identifier "coint_aeg_tstat_trend-ct_autolag-aic_maxlag-10" and labels ['misc', 'unsigned', 'temporal', 'undirected', 'nonlinear']
# [277] Adding SPI .statistics.misc.Cointegration(x,y,{'method': 'aeg', 'statistic': 'tstat', 'autolag': 'bic', 'maxlag': 10, 'trend': 'ct'})
# Succesfully initialised SPI with identifier "coint_aeg_tstat_trend-ct_autolag-bic_maxlag-10" and labels ['misc', 'unsigned', 'temporal', 'undirected', 'nonlinear']
# [278] Adding SPI .statistics.misc.PowerEnvelopeCorrelation(x,y,{'orth': False, 'log': False, 'absolute': False})
# Succesfully initialised SPI with identifier "pec" and labels ['unsigned', 'misc', 'undirected']
# [279] Adding SPI .statistics.misc.PowerEnvelopeCorrelation(x,y,{'orth': True, 'log': False, 'absolute': False})
# Succesfully initialised SPI with identifier "pec_orth" and labels ['unsigned', 'misc', 'undirected']
# [280] Adding SPI .statistics.misc.PowerEnvelopeCorrelation(x,y,{'orth': False, 'log': True, 'absolute': False})
# Succesfully initialised SPI with identifier "pec_log" and labels ['unsigned', 'misc', 'undirected']
# [281] Adding SPI .statistics.misc.PowerEnvelopeCorrelation(x,y,{'orth': True, 'log': True, 'absolute': False})
# Succesfully initialised SPI with identifier "pec_orth_log" and labels ['unsigned', 'misc', 'undirected']
# [282] Adding SPI .statistics.misc.PowerEnvelopeCorrelation(x,y,{'orth': True, 'log': False, 'absolute': True})
# Succesfully initialised SPI with identifier "pec_orth_abs" and labels ['unsigned', 'misc', 'undirected']
# [283] Adding SPI .statistics.misc.PowerEnvelopeCorrelation(x,y,{'orth': True, 'log': True, 'absolute': True})
# Succesfully initialised SPI with identifier "pec_orth_log_abs" and labels ['unsigned', 'misc', 'undirected']
# ====================================================================================================
# Number of SPIs: 284
#
# Normalising the dataset...
# Processing [None: bary_sgddtw_mean]:  23%|██▎       | 66/284 [00:21<01:20,  2.72it/s]              DBA loss is increasing while it should not be. Stopping optimization.
# Processing [None: ccm_E-None_mean]:  30%|██▉       | 85/284 [00:45<00:40,  4.95it/s]       IOStream.flush timed out
# Processing [None: cce_gaussian]:  33%|███▎      | 95/284 [03:31<28:37,  9.09s/it]   Caught <java class 'infodynamics.utils.NonPositiveDefiniteMatrixException'> for SPI "cce_gaussian": infodynamics.utils.NonPositiveDefiniteMatrixException: CholeskyDecomposition is only performed on positive-definite matrices. Some reasons for non-positive-definite matrix are listed at http://www2.gsu.edu/~mkteer/npdmatri.html - note: a correlation matrix is non-positive-definite if you have more variables than observations. Failed row is 3
# Processing [None: xme_gaussian_k10]:  38%|███▊      | 108/284 [03:31<11:35,  3.95s/it]   Caught <java class 'infodynamics.utils.NonPositiveDefiniteMatrixException'> for SPI "xme_gaussian_k10": infodynamics.utils.NonPositiveDefiniteMatrixException: CholeskyDecomposition is only performed on positive-definite matrices. Some reasons for non-positive-definite matrix are listed at http://www2.gsu.edu/~mkteer/npdmatri.html - note: a correlation matrix is non-positive-definite if you have more variables than observations. Failed row is 3
# Processing [None: di_gaussian]:  39%|███▉      | 112/284 [03:32<08:34,  2.99s/it]         Caught <java class 'infodynamics.utils.NonPositiveDefiniteMatrixException'> for SPI "di_gaussian": infodynamics.utils.NonPositiveDefiniteMatrixException: CholeskyDecomposition is only performed on positive-definite matrices. Some reasons for non-positive-definite matrix are listed at http://www2.gsu.edu/~mkteer/npdmatri.html - note: a correlation matrix is non-positive-definite if you have more variables than observations. Failed row is 3
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  49%|████▉     | 139/284 [03:44<01:33,  1.55it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  50%|████▉     | 141/284 [03:44<01:42,  1.39it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  78%|███████▊  | 222/284 [03:53<00:15,  4.10it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  81%|████████▏ | 231/284 [03:53<00:09,  5.87it/s]    All-NaN slice encountered
# Processing [None: sgc_parametric_mean_fs-1_fmin-0_fmax-0-5_order-None]:  81%|████████▏ | 231/284 [03:53<00:09,  5.87it/s]Caught <class 'TypeError'> for SPI "sgc_parametric_mean_fs-1_fmin-0_fmax-0-5_order-None": expected string or bytes-like object
# Processing [None: sgc_parametric_mean_fs-1_fmin-0_fmax-0-25_order-None]:  83%|████████▎ | 237/284 [03:54<00:06,  7.19it/s]Caught <class 'TypeError'> for SPI "sgc_parametric_mean_fs-1_fmin-0_fmax-0-25_order-None": expected string or bytes-like object
# Processing [None: sgc_parametric_mean_fs-1_fmin-0-25_fmax-0-5_order-None]:  83%|████████▎ | 237/284 [03:54<00:06,  7.19it/s]Caught <class 'TypeError'> for SPI "sgc_parametric_mean_fs-1_fmin-0-25_fmax-0-5_order-None": expected string or bytes-like object
# Processing [None: sgc_parametric_max_fs-1_fmin-1e-05_fmax-0-5_order-None]:  85%|████████▍ | 240/284 [03:54<00:06,  6.97it/s]Caught <class 'TypeError'> for SPI "sgc_parametric_max_fs-1_fmin-1e-05_fmax-0-5_order-None": expected string or bytes-like object
# Processing [None: sgc_parametric_max_fs-1_fmin-0_fmax-0-25_order-None]:  87%|████████▋ | 246/284 [03:54<00:04,  8.81it/s]   Caught <class 'TypeError'> for SPI "sgc_parametric_max_fs-1_fmin-0_fmax-0-25_order-None": expected string or bytes-like object
# Processing [None: sgc_parametric_max_fs-1_fmin-0-25_fmax-0-5_order-None]:  87%|████████▋ | 246/284 [03:55<00:04,  8.81it/s]Caught <class 'TypeError'> for SPI "sgc_parametric_max_fs-1_fmin-0-25_fmax-0-5_order-None": expected string or bytes-like object
# Processing [None: pec_orth_log_abs]: 100%|██████████| 284/284 [04:08<00:00,  1.14it/s]
# Calculation complete. Time taken: 248.8387s
#
# SPI Computation Results Summary
# ============================================================
#
# Total number of SPIs attempted: 284
# Number of SPIs successfully computed: 275 (96.83%)
# ------------------------------------------------------------
# Category       | Count | Percentage
# ------------------------------------------------------------
# Successful     |   275 |  96.83%
# NaNs           |     9 |   3.17%
# Partial NaNs   |     0 |   0.00%
# ------------------------------------------------------------
#
# [9] SPI(s) produced NaN outputs:
# ------------------------------------------------------------
# 1. cce_gaussian
# 2. xme_gaussian_k10
# 3. di_gaussian
# 4. sgc_parametric_mean_fs-1_fmin-0_fmax-0-5_order-None
# 5. sgc_parametric_mean_fs-1_fmin-0_fmax-0-25_order-None
# 6. sgc_parametric_mean_fs-1_fmin-0-25_fmax-0-5_order-None
# 7. sgc_parametric_max_fs-1_fmin-1e-05_fmax-0-5_order-None
# 8. sgc_parametric_max_fs-1_fmin-0_fmax-0-25_order-None
# 9. sgc_parametric_max_fs-1_fmin-0-25_fmax-0-5_order-None
# ------------------------------------------------------------

# %%
example_res = deepcopy(calc.table)

# Iterate over each SPI
example_res.columns = example_res.columns.to_flat_index()

example_res = example_res.rename(columns='__'.join).assign(meta_ROI_from = lambda x: x.index)

example_res_long = example_res.melt(id_vars='meta_ROI_from', var_name='SPI__meta_ROI_to', value_name='value')

example_res_long["SPI"] = example_res_long["SPI__meta_ROI_to"].str.split("__").str[0]
example_res_long["meta_ROI_to"] = example_res_long["SPI__meta_ROI_to"].str.split("__").str[1]

# %%
# Iterate over each SPI
example_res.columns = example_res.columns.to_flat_index()

# Rename index as first brain region
# example_res = example_res.rename(columns={"index": "meta_ROI_from"})

example_res.columns = ["_".join(a) for a in example_res.columns.to_flat_index()]
example_res.columns

# %%
# Convert index to column
example_res.reset_index(level=0, inplace=True)

# Rename index as first brain region
example_res = example_res.rename(columns={"index": "meta_ROI_from"})

example_res.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_19737/3115733331.py in ?()
#       1 # Convert index to column
# ----> 2 example_res.reset_index(level=0, inplace=True)
#       3
#       4 # Rename index as first brain region
#       5 example_res = example_res.rename(columns={"index": "meta_ROI_from"})
#
# ~/.conda/envs/pyspi_new/lib/python3.10/site-packages/pandas/core/frame.py in ?(self, level, drop, inplace, col_level, col_fill, allow_duplicates, names)
#    6468                     level_values = algorithms.take(
#    6469                         level_values, lab, allow_fill=True, fill_value=lev._na_value
#    6470                     )
#    6471
# -> 6472                 new_obj.insert(
#    6473                     0,
#    6474                     name,
#    6475                     level_values,
#
# ~/.conda/envs/pyspi_new/lib/python3.10/site-packages/pandas/core/frame.py in ?(self, loc, column, value, allow_duplicates)
#    5154                 "'self.flags.allows_duplicate_labels' is False."
#    5155             )
#    5156         if not allow_duplicates and column in self.columns:
#    5157             # Should this be a different kind of error??
# -> 5158             raise ValueError(f"cannot insert {column}, already exists")
#    5159         if not is_integer(loc):
#    5160             raise TypeError("loc must be int")
#    5161         # convert non stdlib ints to satisfy typing checks
#
# ValueError: cannot insert level_0, already exists

# %%
# Pivot data from wide to long
example_res_long = pd.melt(example_res, id_vars="meta_ROI_from")

# %%
# Pivot data from wide to long
example_res_long = pd.melt(example_res, id_vars="meta_ROI_from")
example_res_long['SPI'], example_res_long['meta_ROI_to'] = example_res_long.variable.str

# Remove variable column
example_res_long = example_res_long.drop("variable", 1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 3
#       1 # Pivot data from wide to long
#       2 example_res_long = pd.melt(example_res, id_vars="meta_ROI_from")
# ----> 3 example_res_long['SPI'], example_res_long['meta_ROI_to'] = example_res_long.variable.str
#       5 # Remove variable column
#       6 example_res_long = example_res_long.drop("variable", 1)
#
# File ~/.conda/envs/pyspi_new/lib/python3.10/site-packages/pandas/core/strings/accessor.py:253, in StringMethods.__iter__(self)
#     252 def __iter__(self) -> Iterator:
# --> 253     raise TypeError(f"'{type(self).__name__}' object is not iterable")
#
# TypeError: 'StringMethods' object is not iterable
