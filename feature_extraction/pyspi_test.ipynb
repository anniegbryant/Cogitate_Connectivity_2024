# %%
import pandas as pd
import numpy as np
import pyspi
from pyspi.calculator import Calculator
import os
from copy import deepcopy
import glob
import mne_connectivity
import mne

# %%
# Initialise a base calculator
calc = Calculator(subset='fast')

ROI_lookup = {"proc-0": "Category_Selective",
              "proc-1": "GNWT",
              "proc-2": "IIT"}
# Out:
# Loading configuration file: /Users/abry4213/anaconda3/envs/annie_env/lib/python3.9/site-packages/pyspi/fast_config.yaml
# *** Importing module .statistics.basic
# [0] Adding SPI .statistics.basic.Covariance(x,y,{'estimator': 'EmpiricalCovariance'})...
# Succesfully initialised SPI with identifier "cov_EmpiricalCovariance" and labels ['basic', 'unordered', 'linear', 'undirected', 'signed']
# [1] Adding SPI .statistics.basic.Covariance(x,y,{'estimator': 'GraphicalLasso'})...
# Succesfully initialised SPI with identifier "cov_GraphicalLasso" and labels ['basic', 'unordered', 'linear', 'undirected', 'signed']
# [2] Adding SPI .statistics.basic.Covariance(x,y,{'estimator': 'GraphicalLassoCV'})...
# Succesfully initialised SPI with identifier "cov_GraphicalLassoCV" and labels ['basic', 'unordered', 'linear', 'undirected', 'signed']
# [3] Adding SPI .statistics.basic.Covariance(x,y,{'estimator': 'LedoitWolf'})...
# Succesfully initialised SPI with identifier "cov_LedoitWolf" and labels ['basic', 'unordered', 'linear', 'undirected', 'signed']
# [4] Adding SPI .statistics.basic.Covariance(x,y,{'estimator': 'OAS'})...
# Succesfully initialised SPI with identifier "cov_OAS" and labels ['basic', 'unordered', 'linear', 'undirected', 'signed']
# [5] Adding SPI .statistics.basic.Covariance(x,y,{'estimator': 'ShrunkCovariance'})...
# Succesfully initialised SPI with identifier "cov_ShrunkCovariance" and labels ['basic', 'unordered', 'linear', 'undirected', 'signed']
# [6] Adding SPI .statistics.basic.Covariance(x,y,{'estimator': 'EmpiricalCovariance', 'squared': True})...
# Succesfully initialised SPI with identifier "cov-sq_EmpiricalCovariance" and labels ['basic', 'unordered', 'linear', 'undirected', 'unsigned']
# [7] Adding SPI .statistics.basic.Covariance(x,y,{'estimator': 'GraphicalLasso', 'squared': True})...
# Succesfully initialised SPI with identifier "cov-sq_GraphicalLasso" and labels ['basic', 'unordered', 'linear', 'undirected', 'unsigned']
# [8] Adding SPI .statistics.basic.Covariance(x,y,{'estimator': 'LedoitWolf', 'squared': True})...
# Succesfully initialised SPI with identifier "cov-sq_LedoitWolf" and labels ['basic', 'unordered', 'linear', 'undirected', 'unsigned']
# [9] Adding SPI .statistics.basic.Covariance(x,y,{'estimator': 'OAS', 'squared': True})...
# Succesfully initialised SPI with identifier "cov-sq_OAS" and labels ['basic', 'unordered', 'linear', 'undirected', 'unsigned']
# [10] Adding SPI .statistics.basic.Covariance(x,y,{'estimator': 'ShrunkCovariance', 'squared': True})...
# Succesfully initialised SPI with identifier "cov-sq_ShrunkCovariance" and labels ['basic', 'unordered', 'linear', 'undirected', 'unsigned']
# [11] Adding SPI .statistics.basic.Precision(x,y,{'estimator': 'EmpiricalCovariance'})...
# Succesfully initialised SPI with identifier "prec_EmpiricalCovariance" and labels ['basic', 'unordered', 'linear', 'undirected', 'signed']
# [12] Adding SPI .statistics.basic.Precision(x,y,{'estimator': 'GraphicalLasso'})...
# Succesfully initialised SPI with identifier "prec_GraphicalLasso" and labels ['basic', 'unordered', 'linear', 'undirected', 'signed']
# [13] Adding SPI .statistics.basic.Precision(x,y,{'estimator': 'LedoitWolf'})...
# Succesfully initialised SPI with identifier "prec_LedoitWolf" and labels ['basic', 'unordered', 'linear', 'undirected', 'signed']
# [14] Adding SPI .statistics.basic.Precision(x,y,{'estimator': 'OAS'})...
# Succesfully initialised SPI with identifier "prec_OAS" and labels ['basic', 'unordered', 'linear', 'undirected', 'signed']
# [15] Adding SPI .statistics.basic.Precision(x,y,{'estimator': 'ShrunkCovariance'})...
# Succesfully initialised SPI with identifier "prec_ShrunkCovariance" and labels ['basic', 'unordered', 'linear', 'undirected', 'signed']
# [16] Adding SPI .statistics.basic.Precision(x,y,{'estimator': 'EmpiricalCovariance', 'squared': True})...
# Succesfully initialised SPI with identifier "prec-sq_EmpiricalCovariance" and labels ['basic', 'unordered', 'linear', 'undirected', 'unsigned']
# [17] Adding SPI .statistics.basic.Precision(x,y,{'estimator': 'GraphicalLasso', 'squared': True})...
# Succesfully initialised SPI with identifier "prec-sq_GraphicalLasso" and labels ['basic', 'unordered', 'linear', 'undirected', 'unsigned']
# [18] Adding SPI .statistics.basic.Precision(x,y,{'estimator': 'LedoitWolf', 'squared': True})...
# Succesfully initialised SPI with identifier "prec-sq_LedoitWolf" and labels ['basic', 'unordered', 'linear', 'undirected', 'unsigned']
# [19] Adding SPI .statistics.basic.Precision(x,y,{'estimator': 'OAS', 'squared': True})...
# Succesfully initialised SPI with identifier "prec-sq_OAS" and labels ['basic', 'unordered', 'linear', 'undirected', 'unsigned']
# [20] Adding SPI .statistics.basic.Precision(x,y,{'estimator': 'ShrunkCovariance', 'squared': True})...
# Succesfully initialised SPI with identifier "prec-sq_ShrunkCovariance" and labels ['basic', 'unordered', 'linear', 'undirected', 'unsigned']
# [21] Adding SPI .statistics.basic.SpearmanR(x,y,{'squared': True})...
# Succesfully initialised SPI with identifier "spearmanr-sq" and labels ['basic', 'unordered', 'rank', 'linear', 'undirected', 'unsigned', 'signed', 'unsigned']
# [22] Adding SPI .statistics.basic.SpearmanR(x,y,{'squared': False})...
# Succesfully initialised SPI with identifier "spearmanr" and labels ['basic', 'unordered', 'rank', 'linear', 'undirected', 'unsigned', 'signed', 'unsigned', 'signed']
# [23] Adding SPI .statistics.basic.KendallTau(x,y,{'squared': True})...
# Succesfully initialised SPI with identifier "kendalltau-sq" and labels ['basic', 'unordered', 'rank', 'linear', 'undirected', 'unsigned', 'signed', 'unsigned']
# [24] Adding SPI .statistics.basic.KendallTau(x,y,{'squared': False})...
# Succesfully initialised SPI with identifier "kendalltau" and labels ['basic', 'unordered', 'rank', 'linear', 'undirected', 'unsigned', 'signed', 'unsigned', 'signed']
# [25] Adding SPI .statistics.basic.CrossCorrelation(x,y,{'statistic': 'max'})...
# Succesfully initialised SPI with identifier "xcorr_max_sig-True" and labels ['basic', 'linear', 'undirected', 'temporal', 'signed']
# [26] Adding SPI .statistics.basic.CrossCorrelation(x,y,{'statistic': 'max', 'squared': True})...
# Succesfully initialised SPI with identifier "xcorr-sq_max_sig-True" and labels ['basic', 'linear', 'undirected', 'temporal', 'unsigned']
# [27] Adding SPI .statistics.basic.CrossCorrelation(x,y,{'statistic': 'mean'})...
# Succesfully initialised SPI with identifier "xcorr_mean_sig-True" and labels ['basic', 'linear', 'undirected', 'temporal', 'signed']
# [28] Adding SPI .statistics.basic.CrossCorrelation(x,y,{'statistic': 'mean', 'squared': True})...
# Succesfully initialised SPI with identifier "xcorr-sq_mean_sig-True" and labels ['basic', 'linear', 'undirected', 'temporal', 'unsigned']
# [29] Adding SPI .statistics.basic.CrossCorrelation(x,y,{'statistic': 'mean', 'sigonly': False})...
# Succesfully initialised SPI with identifier "xcorr_mean_sig-False" and labels ['basic', 'linear', 'undirected', 'temporal', 'signed']
# [30] Adding SPI .statistics.basic.CrossCorrelation(x,y,{'statistic': 'mean', 'squared': True, 'sigonly': False})...
# Succesfully initialised SPI with identifier "xcorr-sq_mean_sig-False" and labels ['basic', 'linear', 'undirected', 'temporal', 'unsigned']
# *** Importing module .statistics.distance
# [31] Adding SPI .statistics.distance.PairwiseDistance(x,y,{'metric': 'euclidean'})...
# Succesfully initialised SPI with identifier "pdist_euclidean" and labels ['unsigned', 'distance', 'unordered', 'nonlinear', 'undirected']
# [32] Adding SPI .statistics.distance.PairwiseDistance(x,y,{'metric': 'cityblock'})...
# Succesfully initialised SPI with identifier "pdist_cityblock" and labels ['unsigned', 'distance', 'unordered', 'nonlinear', 'undirected']
# [33] Adding SPI .statistics.distance.PairwiseDistance(x,y,{'metric': 'cosine'})...
# Succesfully initialised SPI with identifier "pdist_cosine" and labels ['unsigned', 'distance', 'unordered', 'nonlinear', 'undirected']
# [34] Adding SPI .statistics.distance.PairwiseDistance(x,y,{'metric': 'chebyshev'})...
# Succesfully initialised SPI with identifier "pdist_chebyshev" and labels ['unsigned', 'distance', 'unordered', 'nonlinear', 'undirected']
# [35] Adding SPI .statistics.distance.PairwiseDistance(x,y,{'metric': 'canberra'})...
# Succesfully initialised SPI with identifier "pdist_canberra" and labels ['unsigned', 'distance', 'unordered', 'nonlinear', 'undirected']
# [36] Adding SPI .statistics.distance.PairwiseDistance(x,y,{'metric': 'braycurtis'})...
# Succesfully initialised SPI with identifier "pdist_braycurtis" and labels ['unsigned', 'distance', 'unordered', 'nonlinear', 'undirected']
# [37] Adding SPI .statistics.distance.DistanceCorrelation(x,y,{'biased': False})...
# Succesfully initialised SPI with identifier "dcorr" and labels ['unsigned', 'distance', 'unordered', 'nonlinear', 'undirected']
# [38] Adding SPI .statistics.distance.DistanceCorrelation(x,y,{'biased': True})...
# Succesfully initialised SPI with identifier "dcorr_biased" and labels ['unsigned', 'distance', 'unordered', 'nonlinear', 'undirected']
# [39] Adding SPI .statistics.distance.HilbertSchmidtIndependenceCriterion(x,y,{'biased': False})...
# Succesfully initialised SPI with identifier "hsic" and labels ['unsigned', 'distance', 'unordered', 'nonlinear', 'undirected']
# [40] Adding SPI .statistics.distance.HilbertSchmidtIndependenceCriterion(x,y,{'biased': True})...
# Succesfully initialised SPI with identifier "hsic_biased" and labels ['unsigned', 'distance', 'unordered', 'nonlinear', 'undirected']
# [41] Adding SPI .statistics.distance.Barycenter(x,y,{'mode': 'euclidean', 'statistic': 'mean'})...
# Succesfully initialised SPI with identifier "bary_euclidean_mean" and labels ['distance', 'signed', 'undirected', 'temporal', 'nonlinear']
# [42] Adding SPI .statistics.distance.Barycenter(x,y,{'mode': 'euclidean', 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "bary_euclidean_max" and labels ['distance', 'signed', 'undirected', 'temporal', 'nonlinear']
# [43] Adding SPI .statistics.distance.Barycenter(x,y,{'mode': 'euclidean', 'statistic': 'mean', 'squared': True})...
# Succesfully initialised SPI with identifier "bary-sq_euclidean_mean" and labels ['distance', 'signed', 'undirected', 'temporal', 'nonlinear']
# [44] Adding SPI .statistics.distance.Barycenter(x,y,{'mode': 'euclidean', 'statistic': 'max', 'squared': True})...
# Succesfully initialised SPI with identifier "bary-sq_euclidean_max" and labels ['distance', 'signed', 'undirected', 'temporal', 'nonlinear']
# *** Importing module .statistics.causal
# [45] Adding SPI .statistics.causal.AdditiveNoiseModel(x,y)...
# Succesfully initialised SPI with identifier "anm" and labels ['unsigned', 'causal', 'unordered', 'linear', 'directed']
# [46] Adding SPI .statistics.causal.ConditionalDistributionSimilarity(x,y)...
# Succesfully initialised SPI with identifier "cds" and labels ['unsigned', 'causal', 'unordered', 'nonlinear', 'directed']
# [47] Adding SPI .statistics.causal.RegressionErrorCausalInference(x,y)...
# Succesfully initialised SPI with identifier "reci" and labels ['unsigned', 'causal', 'unordered', 'nonlinear', 'directed']
# [48] Adding SPI .statistics.causal.InformationGeometricConditionalIndependence(x,y)...
# Succesfully initialised SPI with identifier "igci" and labels ['causal', 'directed', 'nonlinear', 'unsigned', 'unordered']
# *** Importing module .statistics.infotheory
# [49] Adding SPI .statistics.infotheory.JointEntropy(x,y,{'estimator': 'gaussian'})...
# Succesfully initialised SPI with identifier "je_gaussian" and labels ['unsigned', 'infotheory', 'unordered', 'undirected', 'linear']
# [50] Adding SPI .statistics.infotheory.JointEntropy(x,y,{'estimator': 'kozachenko'})...
# Succesfully initialised SPI with identifier "je_kozachenko" and labels ['unsigned', 'infotheory', 'unordered', 'undirected', 'linear']
# [51] Adding SPI .statistics.infotheory.JointEntropy(x,y,{'estimator': 'kernel'})...
# Succesfully initialised SPI with identifier "je_kernel_W-0.5" and labels ['unsigned', 'infotheory', 'unordered', 'undirected', 'nonlinear']
# [52] Adding SPI .statistics.infotheory.ConditionalEntropy(x,y,{'estimator': 'gaussian'})...
# Succesfully initialised SPI with identifier "ce_gaussian" and labels ['unsigned', 'infotheory', 'unordered', 'directed', 'linear']
# [53] Adding SPI .statistics.infotheory.ConditionalEntropy(x,y,{'estimator': 'kernel'})...
# Succesfully initialised SPI with identifier "ce_kernel_W-0.5" and labels ['unsigned', 'infotheory', 'unordered', 'directed', 'nonlinear']
# [54] Adding SPI .statistics.infotheory.CrossmapEntropy(x,y,{'estimator': 'gaussian', 'history_length': 1})...
# Succesfully initialised SPI with identifier "xme_gaussian_k1" and labels ['unsigned', 'infotheory', 'temporal', 'directed', 'linear']
# [55] Adding SPI .statistics.infotheory.CrossmapEntropy(x,y,{'estimator': 'kozachenko', 'history_length': 1})...
# Succesfully initialised SPI with identifier "xme_kozachenko_k1" and labels ['unsigned', 'infotheory', 'temporal', 'directed', 'linear']
# [56] Adding SPI .statistics.infotheory.CrossmapEntropy(x,y,{'estimator': 'kernel', 'history_length': 1})...
# Succesfully initialised SPI with identifier "xme_kernel_W-0.5_k1" and labels ['unsigned', 'infotheory', 'temporal', 'directed', 'nonlinear']
# [57] Adding SPI .statistics.infotheory.CrossmapEntropy(x,y,{'estimator': 'gaussian', 'history_length': 10})...
# Succesfully initialised SPI with identifier "xme_gaussian_k10" and labels ['unsigned', 'infotheory', 'temporal', 'directed', 'linear']
# [58] Adding SPI .statistics.infotheory.CrossmapEntropy(x,y,{'estimator': 'kozachenko', 'history_length': 10})...
# Succesfully initialised SPI with identifier "xme_kozachenko_k10" and labels ['unsigned', 'infotheory', 'temporal', 'directed', 'linear']
# [59] Adding SPI .statistics.infotheory.CrossmapEntropy(x,y,{'estimator': 'kernel', 'history_length': 10})...
# Succesfully initialised SPI with identifier "xme_kernel_W-0.5_k10" and labels ['unsigned', 'infotheory', 'temporal', 'directed', 'nonlinear']
# [60] Adding SPI .statistics.infotheory.StochasticInteraction(x,y,{'estimator': 'gaussian'})...
# Succesfully initialised SPI with identifier "si_gaussian_k-1" and labels ['unsigned', 'infotheory', 'temporal', 'undirected', 'linear']
# [61] Adding SPI .statistics.infotheory.StochasticInteraction(x,y,{'estimator': 'kozachenko'})...
# Succesfully initialised SPI with identifier "si_kozachenko_k-1" and labels ['unsigned', 'infotheory', 'temporal', 'undirected', 'linear']
# [62] Adding SPI .statistics.infotheory.StochasticInteraction(x,y,{'estimator': 'kernel'})...
# Succesfully initialised SPI with identifier "si_kernel_W-0.5_k-1" and labels ['unsigned', 'infotheory', 'temporal', 'undirected', 'nonlinear']
# [63] Adding SPI .statistics.infotheory.MutualInfo(x,y,{'estimator': 'gaussian'})...
# Succesfully initialised SPI with identifier "mi_gaussian" and labels ['unsigned', 'infotheory', 'unordered', 'undirected', 'linear']
# [64] Adding SPI .statistics.infotheory.MutualInfo(x,y,{'estimator': 'kraskov', 'prop_k': 4})...
# Succesfully initialised SPI with identifier "mi_kraskov_NN-4" and labels ['unsigned', 'infotheory', 'unordered', 'undirected', 'nonlinear']
# [65] Adding SPI .statistics.infotheory.MutualInfo(x,y,{'estimator': 'kraskov', 'prop_k': 4, 'dyn_corr_excl': 'AUTO'})...
# Succesfully initialised SPI with identifier "mi_kraskov_NN-4_DCE" and labels ['unsigned', 'infotheory', 'unordered', 'undirected', 'nonlinear']
# [66] Adding SPI .statistics.infotheory.MutualInfo(x,y,{'estimator': 'kernel', 'kernel_width': 0.25})...
# Succesfully initialised SPI with identifier "mi_kernel_W-0.25" and labels ['unsigned', 'infotheory', 'unordered', 'undirected', 'nonlinear']
# [67] Adding SPI .statistics.infotheory.TimeLaggedMutualInfo(x,y,{'estimator': 'gaussian'})...
# Succesfully initialised SPI with identifier "tlmi_gaussian" and labels ['unsigned', 'infotheory', 'temporal', 'undirected', 'linear']
# [68] Adding SPI .statistics.infotheory.TimeLaggedMutualInfo(x,y,{'estimator': 'kraskov', 'prop_k': 4})...
# Succesfully initialised SPI with identifier "tlmi_kraskov_NN-4" and labels ['unsigned', 'infotheory', 'temporal', 'undirected', 'nonlinear']
# [69] Adding SPI .statistics.infotheory.TimeLaggedMutualInfo(x,y,{'estimator': 'kraskov', 'prop_k': 4, 'dyn_corr_excl': 'AUTO'})...
# Succesfully initialised SPI with identifier "tlmi_kraskov_NN-4_DCE" and labels ['unsigned', 'infotheory', 'temporal', 'undirected', 'nonlinear']
# [70] Adding SPI .statistics.infotheory.TimeLaggedMutualInfo(x,y,{'estimator': 'kernel', 'kernel_width': 0.25})...
# Succesfully initialised SPI with identifier "tlmi_kernel_W-0.25" and labels ['unsigned', 'infotheory', 'temporal', 'undirected', 'nonlinear']
# [71] Adding SPI .statistics.infotheory.TransferEntropy(x,y,{'estimator': 'kraskov', 'prop_k': 4, 'k_history': 1, 'l_history': 1, 'dyn_corr_excl': 'AUTO'})...
# Succesfully initialised SPI with identifier "te_kraskov_NN-4_DCE_k-1_kt-1_l-1_lt-1" and labels ['unsigned', 'embedding', 'infotheory', 'temporal', 'directed', 'nonlinear']
# [72] Adding SPI .statistics.infotheory.TransferEntropy(x,y,{'estimator': 'gaussian', 'k_history': 1, 'l_history': 1})...
# Succesfully initialised SPI with identifier "gc_gaussian_k-1_kt-1_l-1_lt-1" and labels ['unsigned', 'embedding', 'infotheory', 'temporal', 'directed', 'linear']
# *** Importing module .statistics.spectral
# [73] Adding SPI .statistics.spectral.CoherencePhase(x,y,{'fs': 1})...
# Succesfully initialised SPI with identifier "phase_multitaper_mean_fs-1_fmin-0_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [74] Adding SPI .statistics.spectral.CoherencePhase(x,y,{'fmin': 0, 'fmax': 0.25})...
# Succesfully initialised SPI with identifier "phase_multitaper_mean_fs-1_fmin-0_fmax-0-25" and labels ['unsigned', 'spectral', 'undirected']
# [75] Adding SPI .statistics.spectral.CoherencePhase(x,y,{'fmin': 0.25, 'fmax': 0.5})...
# Succesfully initialised SPI with identifier "phase_multitaper_mean_fs-1_fmin-0-25_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [76] Adding SPI .statistics.spectral.CoherencePhase(x,y,{'fs': 1, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "phase_multitaper_max_fs-1_fmin-0_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [77] Adding SPI .statistics.spectral.CoherencePhase(x,y,{'fmin': 0, 'fmax': 0.25, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "phase_multitaper_max_fs-1_fmin-0_fmax-0-25" and labels ['unsigned', 'spectral', 'undirected']
# [78] Adding SPI .statistics.spectral.CoherencePhase(x,y,{'fmin': 0.25, 'fmax': 0.5, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "phase_multitaper_max_fs-1_fmin-0-25_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [79] Adding SPI .statistics.spectral.CoherenceMagnitude(x,y,{'fs': 1})...
# Succesfully initialised SPI with identifier "cohmag_multitaper_mean_fs-1_fmin-0_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [80] Adding SPI .statistics.spectral.CoherenceMagnitude(x,y,{'fmin': 0, 'fmax': 0.25})...
# Succesfully initialised SPI with identifier "cohmag_multitaper_mean_fs-1_fmin-0_fmax-0-25" and labels ['unsigned', 'spectral', 'undirected']
# [81] Adding SPI .statistics.spectral.CoherenceMagnitude(x,y,{'fmin': 0.25, 'fmax': 0.5})...
# Succesfully initialised SPI with identifier "cohmag_multitaper_mean_fs-1_fmin-0-25_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [82] Adding SPI .statistics.spectral.CoherenceMagnitude(x,y,{'fs': 1, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "cohmag_multitaper_max_fs-1_fmin-0_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [83] Adding SPI .statistics.spectral.CoherenceMagnitude(x,y,{'fmin': 0, 'fmax': 0.25, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "cohmag_multitaper_max_fs-1_fmin-0_fmax-0-25" and labels ['unsigned', 'spectral', 'undirected']
# [84] Adding SPI .statistics.spectral.CoherenceMagnitude(x,y,{'fmin': 0.25, 'fmax': 0.5, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "cohmag_multitaper_max_fs-1_fmin-0-25_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [85] Adding SPI .statistics.spectral.ImaginaryCoherence(x,y,{'fs': 1})...
# Succesfully initialised SPI with identifier "icoh_multitaper_mean_fs-1_fmin-0_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [86] Adding SPI .statistics.spectral.ImaginaryCoherence(x,y,{'fmin': 0, 'fmax': 0.25})...
# Succesfully initialised SPI with identifier "icoh_multitaper_mean_fs-1_fmin-0_fmax-0-25" and labels ['unsigned', 'spectral', 'undirected']
# [87] Adding SPI .statistics.spectral.ImaginaryCoherence(x,y,{'fmin': 0.25, 'fmax': 0.5})...
# Succesfully initialised SPI with identifier "icoh_multitaper_mean_fs-1_fmin-0-25_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [88] Adding SPI .statistics.spectral.ImaginaryCoherence(x,y,{'fs': 1, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "icoh_multitaper_max_fs-1_fmin-0_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [89] Adding SPI .statistics.spectral.ImaginaryCoherence(x,y,{'fmin': 0, 'fmax': 0.25, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "icoh_multitaper_max_fs-1_fmin-0_fmax-0-25" and labels ['unsigned', 'spectral', 'undirected']
# [90] Adding SPI .statistics.spectral.ImaginaryCoherence(x,y,{'fmin': 0.25, 'fmax': 0.5, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "icoh_multitaper_max_fs-1_fmin-0-25_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [91] Adding SPI .statistics.spectral.PhaseSlopeIndex(x,y,{'fmin': 0, 'fmax': 0.5})...
# Succesfully initialised SPI with identifier "psi_multitaper_mean_fs-1_fmin-0_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [92] Adding SPI .statistics.spectral.PhaseSlopeIndex(x,y,{'fmin': 0, 'fmax': 0.25})...
# Succesfully initialised SPI with identifier "psi_multitaper_mean_fs-1_fmin-0_fmax-0-25" and labels ['unsigned', 'spectral', 'undirected']
# [93] Adding SPI .statistics.spectral.PhaseSlopeIndex(x,y,{'fmin': 0.25, 'fmax': 0.5})...
# Succesfully initialised SPI with identifier "psi_multitaper_mean_fs-1_fmin-0-25_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [94] Adding SPI .statistics.spectral.PhaseLockingValue(x,y,{'fs': 1})...
# Succesfully initialised SPI with identifier "plv_multitaper_mean_fs-1_fmin-0_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [95] Adding SPI .statistics.spectral.PhaseLockingValue(x,y,{'fmin': 0, 'fmax': 0.25})...
# Succesfully initialised SPI with identifier "plv_multitaper_mean_fs-1_fmin-0_fmax-0-25" and labels ['unsigned', 'spectral', 'undirected']
# [96] Adding SPI .statistics.spectral.PhaseLockingValue(x,y,{'fmin': 0.25, 'fmax': 0.5})...
# Succesfully initialised SPI with identifier "plv_multitaper_mean_fs-1_fmin-0-25_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [97] Adding SPI .statistics.spectral.PhaseLockingValue(x,y,{'fs': 1, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "plv_multitaper_max_fs-1_fmin-0_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [98] Adding SPI .statistics.spectral.PhaseLockingValue(x,y,{'fmin': 0, 'fmax': 0.25, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "plv_multitaper_max_fs-1_fmin-0_fmax-0-25" and labels ['unsigned', 'spectral', 'undirected']
# [99] Adding SPI .statistics.spectral.PhaseLockingValue(x,y,{'fmin': 0.25, 'fmax': 0.5, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "plv_multitaper_max_fs-1_fmin-0-25_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [100] Adding SPI .statistics.spectral.PhaseLagIndex(x,y,{'fs': 1})...
# Succesfully initialised SPI with identifier "pli_multitaper_mean_fs-1_fmin-0_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [101] Adding SPI .statistics.spectral.PhaseLagIndex(x,y,{'fmin': 0, 'fmax': 0.25})...
# Succesfully initialised SPI with identifier "pli_multitaper_mean_fs-1_fmin-0_fmax-0-25" and labels ['unsigned', 'spectral', 'undirected']
# [102] Adding SPI .statistics.spectral.PhaseLagIndex(x,y,{'fmin': 0.25, 'fmax': 0.5})...
# Succesfully initialised SPI with identifier "pli_multitaper_mean_fs-1_fmin-0-25_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [103] Adding SPI .statistics.spectral.PhaseLagIndex(x,y,{'fs': 1, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "pli_multitaper_max_fs-1_fmin-0_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [104] Adding SPI .statistics.spectral.PhaseLagIndex(x,y,{'fmin': 0, 'fmax': 0.25, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "pli_multitaper_max_fs-1_fmin-0_fmax-0-25" and labels ['unsigned', 'spectral', 'undirected']
# [105] Adding SPI .statistics.spectral.PhaseLagIndex(x,y,{'fmin': 0.25, 'fmax': 0.5, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "pli_multitaper_max_fs-1_fmin-0-25_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [106] Adding SPI .statistics.spectral.WeightedPhaseLagIndex(x,y,{'fs': 1})...
# Succesfully initialised SPI with identifier "wpli_multitaper_mean_fs-1_fmin-0_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [107] Adding SPI .statistics.spectral.WeightedPhaseLagIndex(x,y,{'fmin': 0, 'fmax': 0.25})...
# Succesfully initialised SPI with identifier "wpli_multitaper_mean_fs-1_fmin-0_fmax-0-25" and labels ['unsigned', 'spectral', 'undirected']
# [108] Adding SPI .statistics.spectral.WeightedPhaseLagIndex(x,y,{'fmin': 0.25, 'fmax': 0.5})...
# Succesfully initialised SPI with identifier "wpli_multitaper_mean_fs-1_fmin-0-25_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [109] Adding SPI .statistics.spectral.WeightedPhaseLagIndex(x,y,{'fs': 1, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "wpli_multitaper_max_fs-1_fmin-0_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [110] Adding SPI .statistics.spectral.WeightedPhaseLagIndex(x,y,{'fmin': 0, 'fmax': 0.25, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "wpli_multitaper_max_fs-1_fmin-0_fmax-0-25" and labels ['unsigned', 'spectral', 'undirected']
# [111] Adding SPI .statistics.spectral.WeightedPhaseLagIndex(x,y,{'fmin': 0.25, 'fmax': 0.5, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "wpli_multitaper_max_fs-1_fmin-0-25_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [112] Adding SPI .statistics.spectral.DebiasedSquaredPhaseLagIndex(x,y,{'fs': 1})...
# Succesfully initialised SPI with identifier "dspli_multitaper_mean_fs-1_fmin-0_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [113] Adding SPI .statistics.spectral.DebiasedSquaredPhaseLagIndex(x,y,{'fmin': 0, 'fmax': 0.25})...
# Succesfully initialised SPI with identifier "dspli_multitaper_mean_fs-1_fmin-0_fmax-0-25" and labels ['unsigned', 'spectral', 'undirected']
# [114] Adding SPI .statistics.spectral.DebiasedSquaredPhaseLagIndex(x,y,{'fmin': 0.25, 'fmax': 0.5})...
# Succesfully initialised SPI with identifier "dspli_multitaper_mean_fs-1_fmin-0-25_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [115] Adding SPI .statistics.spectral.DebiasedSquaredPhaseLagIndex(x,y,{'fs': 1, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "dspli_multitaper_max_fs-1_fmin-0_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [116] Adding SPI .statistics.spectral.DebiasedSquaredPhaseLagIndex(x,y,{'fmin': 0, 'fmax': 0.25, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "dspli_multitaper_max_fs-1_fmin-0_fmax-0-25" and labels ['unsigned', 'spectral', 'undirected']
# [117] Adding SPI .statistics.spectral.DebiasedSquaredPhaseLagIndex(x,y,{'fmin': 0.25, 'fmax': 0.5, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "dspli_multitaper_max_fs-1_fmin-0-25_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [118] Adding SPI .statistics.spectral.DebiasedSquaredWeightedPhaseLagIndex(x,y,{'fs': 1})...
# Succesfully initialised SPI with identifier "dswpli_multitaper_mean_fs-1_fmin-0_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [119] Adding SPI .statistics.spectral.DebiasedSquaredWeightedPhaseLagIndex(x,y,{'fmin': 0, 'fmax': 0.25})...
# Succesfully initialised SPI with identifier "dswpli_multitaper_mean_fs-1_fmin-0_fmax-0-25" and labels ['unsigned', 'spectral', 'undirected']
# [120] Adding SPI .statistics.spectral.DebiasedSquaredWeightedPhaseLagIndex(x,y,{'fmin': 0.25, 'fmax': 0.5})...
# Succesfully initialised SPI with identifier "dswpli_multitaper_mean_fs-1_fmin-0-25_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [121] Adding SPI .statistics.spectral.DebiasedSquaredWeightedPhaseLagIndex(x,y,{'fs': 1, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "dswpli_multitaper_max_fs-1_fmin-0_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [122] Adding SPI .statistics.spectral.DebiasedSquaredWeightedPhaseLagIndex(x,y,{'fmin': 0, 'fmax': 0.25, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "dswpli_multitaper_max_fs-1_fmin-0_fmax-0-25" and labels ['unsigned', 'spectral', 'undirected']
# [123] Adding SPI .statistics.spectral.DebiasedSquaredWeightedPhaseLagIndex(x,y,{'fmin': 0.25, 'fmax': 0.5, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "dswpli_multitaper_max_fs-1_fmin-0-25_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [124] Adding SPI .statistics.spectral.PairwisePhaseConsistency(x,y,{'fs': 1})...
# Succesfully initialised SPI with identifier "ppc_multitaper_mean_fs-1_fmin-0_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [125] Adding SPI .statistics.spectral.PairwisePhaseConsistency(x,y,{'fmin': 0, 'fmax': 0.25})...
# Succesfully initialised SPI with identifier "ppc_multitaper_mean_fs-1_fmin-0_fmax-0-25" and labels ['unsigned', 'spectral', 'undirected']
# [126] Adding SPI .statistics.spectral.PairwisePhaseConsistency(x,y,{'fmin': 0.25, 'fmax': 0.5})...
# Succesfully initialised SPI with identifier "ppc_multitaper_mean_fs-1_fmin-0-25_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [127] Adding SPI .statistics.spectral.PairwisePhaseConsistency(x,y,{'fs': 1, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "ppc_multitaper_max_fs-1_fmin-0_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [128] Adding SPI .statistics.spectral.PairwisePhaseConsistency(x,y,{'fmin': 0, 'fmax': 0.25, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "ppc_multitaper_max_fs-1_fmin-0_fmax-0-25" and labels ['unsigned', 'spectral', 'undirected']
# [129] Adding SPI .statistics.spectral.PairwisePhaseConsistency(x,y,{'fmin': 0.25, 'fmax': 0.5, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "ppc_multitaper_max_fs-1_fmin-0-25_fmax-0-5" and labels ['unsigned', 'spectral', 'undirected']
# [130] Adding SPI .statistics.spectral.DirectedTransferFunction(x,y,{'fs': 1})...
# Succesfully initialised SPI with identifier "dtf_multitaper_mean_fs-1_fmin-0_fmax-0-5" and labels ['unsigned', 'spectral', 'directed', 'lagged']
# [131] Adding SPI .statistics.spectral.DirectedTransferFunction(x,y,{'fmin': 0, 'fmax': 0.25})...
# Succesfully initialised SPI with identifier "dtf_multitaper_mean_fs-1_fmin-0_fmax-0-25" and labels ['unsigned', 'spectral', 'directed', 'lagged']
# [132] Adding SPI .statistics.spectral.DirectedTransferFunction(x,y,{'fmin': 0.25, 'fmax': 0.5})...
# Succesfully initialised SPI with identifier "dtf_multitaper_mean_fs-1_fmin-0-25_fmax-0-5" and labels ['unsigned', 'spectral', 'directed', 'lagged']
# [133] Adding SPI .statistics.spectral.DirectedTransferFunction(x,y,{'fs': 1, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "dtf_multitaper_max_fs-1_fmin-0_fmax-0-5" and labels ['unsigned', 'spectral', 'directed', 'lagged']
# [134] Adding SPI .statistics.spectral.DirectedTransferFunction(x,y,{'fmin': 0, 'fmax': 0.25, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "dtf_multitaper_max_fs-1_fmin-0_fmax-0-25" and labels ['unsigned', 'spectral', 'directed', 'lagged']
# [135] Adding SPI .statistics.spectral.DirectedTransferFunction(x,y,{'fmin': 0.25, 'fmax': 0.5, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "dtf_multitaper_max_fs-1_fmin-0-25_fmax-0-5" and labels ['unsigned', 'spectral', 'directed', 'lagged']
# [136] Adding SPI .statistics.spectral.DirectedCoherence(x,y,{'fs': 1})...
# Succesfully initialised SPI with identifier "dcoh_multitaper_mean_fs-1_fmin-0_fmax-0-5" and labels ['unsigned', 'spectral', 'directed']
# [137] Adding SPI .statistics.spectral.DirectedCoherence(x,y,{'fmin': 0, 'fmax': 0.25})...
# Succesfully initialised SPI with identifier "dcoh_multitaper_mean_fs-1_fmin-0_fmax-0-25" and labels ['unsigned', 'spectral', 'directed']
# [138] Adding SPI .statistics.spectral.DirectedCoherence(x,y,{'fmin': 0.25, 'fmax': 0.5})...
# Succesfully initialised SPI with identifier "dcoh_multitaper_mean_fs-1_fmin-0-25_fmax-0-5" and labels ['unsigned', 'spectral', 'directed']
# [139] Adding SPI .statistics.spectral.DirectedCoherence(x,y,{'fs': 1, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "dcoh_multitaper_max_fs-1_fmin-0_fmax-0-5" and labels ['unsigned', 'spectral', 'directed']
# [140] Adding SPI .statistics.spectral.DirectedCoherence(x,y,{'fmin': 0, 'fmax': 0.25, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "dcoh_multitaper_max_fs-1_fmin-0_fmax-0-25" and labels ['unsigned', 'spectral', 'directed']
# [141] Adding SPI .statistics.spectral.DirectedCoherence(x,y,{'fmin': 0.25, 'fmax': 0.5, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "dcoh_multitaper_max_fs-1_fmin-0-25_fmax-0-5" and labels ['unsigned', 'spectral', 'directed']
# [142] Adding SPI .statistics.spectral.PartialDirectedCoherence(x,y,{'fs': 1})...
# Succesfully initialised SPI with identifier "pdcoh_multitaper_mean_fs-1_fmin-0_fmax-0-5" and labels ['unsigned', 'spectral', 'directed']
# [143] Adding SPI .statistics.spectral.PartialDirectedCoherence(x,y,{'fmin': 0, 'fmax': 0.25})...
# Succesfully initialised SPI with identifier "pdcoh_multitaper_mean_fs-1_fmin-0_fmax-0-25" and labels ['unsigned', 'spectral', 'directed']
# [144] Adding SPI .statistics.spectral.PartialDirectedCoherence(x,y,{'fmin': 0.25, 'fmax': 0.5})...
# Succesfully initialised SPI with identifier "pdcoh_multitaper_mean_fs-1_fmin-0-25_fmax-0-5" and labels ['unsigned', 'spectral', 'directed']
# [145] Adding SPI .statistics.spectral.PartialDirectedCoherence(x,y,{'fs': 1, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "pdcoh_multitaper_max_fs-1_fmin-0_fmax-0-5" and labels ['unsigned', 'spectral', 'directed']
# [146] Adding SPI .statistics.spectral.PartialDirectedCoherence(x,y,{'fmin': 0, 'fmax': 0.25, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "pdcoh_multitaper_max_fs-1_fmin-0_fmax-0-25" and labels ['unsigned', 'spectral', 'directed']
# [147] Adding SPI .statistics.spectral.PartialDirectedCoherence(x,y,{'fmin': 0.25, 'fmax': 0.5, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "pdcoh_multitaper_max_fs-1_fmin-0-25_fmax-0-5" and labels ['unsigned', 'spectral', 'directed']
# [148] Adding SPI .statistics.spectral.GeneralizedPartialDirectedCoherence(x,y,{'fs': 1})...
# Succesfully initialised SPI with identifier "gpdcoh_multitaper_mean_fs-1_fmin-0_fmax-0-5" and labels ['unsigned', 'spectral', 'directed']
# [149] Adding SPI .statistics.spectral.GeneralizedPartialDirectedCoherence(x,y,{'fmin': 0, 'fmax': 0.25})...
# Succesfully initialised SPI with identifier "gpdcoh_multitaper_mean_fs-1_fmin-0_fmax-0-25" and labels ['unsigned', 'spectral', 'directed']
# [150] Adding SPI .statistics.spectral.GeneralizedPartialDirectedCoherence(x,y,{'fmin': 0.25, 'fmax': 0.5})...
# Succesfully initialised SPI with identifier "gpdcoh_multitaper_mean_fs-1_fmin-0-25_fmax-0-5" and labels ['unsigned', 'spectral', 'directed']
# [151] Adding SPI .statistics.spectral.GeneralizedPartialDirectedCoherence(x,y,{'fs': 1, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "gpdcoh_multitaper_max_fs-1_fmin-0_fmax-0-5" and labels ['unsigned', 'spectral', 'directed']
# [152] Adding SPI .statistics.spectral.GeneralizedPartialDirectedCoherence(x,y,{'fmin': 0, 'fmax': 0.25, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "gpdcoh_multitaper_max_fs-1_fmin-0_fmax-0-25" and labels ['unsigned', 'spectral', 'directed']
# [153] Adding SPI .statistics.spectral.GeneralizedPartialDirectedCoherence(x,y,{'fmin': 0.25, 'fmax': 0.5, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "gpdcoh_multitaper_max_fs-1_fmin-0-25_fmax-0-5" and labels ['unsigned', 'spectral', 'directed']
# [154] Adding SPI .statistics.spectral.DirectDirectedTransferFunction(x,y,{'fs': 1})...
# Succesfully initialised SPI with identifier "ddtf_multitaper_mean_fs-1_fmin-0_fmax-0-5" and labels ['unsigned', 'spectral', 'directed', 'lagged']
# [155] Adding SPI .statistics.spectral.DirectDirectedTransferFunction(x,y,{'fmin': 0, 'fmax': 0.25})...
# Succesfully initialised SPI with identifier "ddtf_multitaper_mean_fs-1_fmin-0_fmax-0-25" and labels ['unsigned', 'spectral', 'directed', 'lagged']
# [156] Adding SPI .statistics.spectral.DirectDirectedTransferFunction(x,y,{'fmin': 0.25, 'fmax': 0.5})...
# Succesfully initialised SPI with identifier "ddtf_multitaper_mean_fs-1_fmin-0-25_fmax-0-5" and labels ['unsigned', 'spectral', 'directed', 'lagged']
# [157] Adding SPI .statistics.spectral.DirectDirectedTransferFunction(x,y,{'fs': 1, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "ddtf_multitaper_max_fs-1_fmin-0_fmax-0-5" and labels ['unsigned', 'spectral', 'directed', 'lagged']
# [158] Adding SPI .statistics.spectral.DirectDirectedTransferFunction(x,y,{'fmin': 0, 'fmax': 0.25, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "ddtf_multitaper_max_fs-1_fmin-0_fmax-0-25" and labels ['unsigned', 'spectral', 'directed', 'lagged']
# [159] Adding SPI .statistics.spectral.DirectDirectedTransferFunction(x,y,{'fmin': 0.25, 'fmax': 0.5, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "ddtf_multitaper_max_fs-1_fmin-0-25_fmax-0-5" and labels ['unsigned', 'spectral', 'directed', 'lagged']
# [160] Adding SPI .statistics.spectral.GroupDelay(x,y,{'fmin': 0, 'fmax': 0.5, 'statistic': 'delay'})...
# Succesfully initialised SPI with identifier "gd_multitaper_delay_fs-1_fmin-0_fmax-0-5" and labels ['unsigned', 'spectral', 'directed', 'lagged']
# [161] Adding SPI .statistics.spectral.GroupDelay(x,y,{'fmin': 0, 'fmax': 0.25, 'statistic': 'delay'})...
# Succesfully initialised SPI with identifier "gd_multitaper_delay_fs-1_fmin-0_fmax-0-25" and labels ['unsigned', 'spectral', 'directed', 'lagged']
# [162] Adding SPI .statistics.spectral.GroupDelay(x,y,{'fmin': 0.25, 'fmax': 0.5, 'statistic': 'delay'})...
# Succesfully initialised SPI with identifier "gd_multitaper_delay_fs-1_fmin-0-25_fmax-0-5" and labels ['unsigned', 'spectral', 'directed', 'lagged']
# [163] Adding SPI .statistics.spectral.SpectralGrangerCausality(x,y,{'method': 'nonparametric', 'fmin': 0, 'fmax': 0.5, 'statistic': 'mean'})...
# Succesfully initialised SPI with identifier "sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5" and labels ['unsigned', 'embedding', 'spectral', 'directed', 'lagged']
# [164] Adding SPI .statistics.spectral.SpectralGrangerCausality(x,y,{'method': 'nonparametric', 'fmin': 0, 'fmax': 0.25, 'statistic': 'mean'})...
# Succesfully initialised SPI with identifier "sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-25" and labels ['unsigned', 'embedding', 'spectral', 'directed', 'lagged']
# [165] Adding SPI .statistics.spectral.SpectralGrangerCausality(x,y,{'method': 'nonparametric', 'fmin': 0.25, 'fmax': 0.5, 'statistic': 'mean'})...
# Succesfully initialised SPI with identifier "sgc_nonparametric_mean_fs-1_fmin-0-25_fmax-0-5" and labels ['unsigned', 'embedding', 'spectral', 'directed', 'lagged']
# [166] Adding SPI .statistics.spectral.SpectralGrangerCausality(x,y,{'method': 'nonparametric', 'fmin': 0, 'fmax': 0.5, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5" and labels ['unsigned', 'embedding', 'spectral', 'directed', 'lagged']
# [167] Adding SPI .statistics.spectral.SpectralGrangerCausality(x,y,{'method': 'nonparametric', 'fmin': 0, 'fmax': 0.25, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "sgc_nonparametric_max_fs-1_fmin-0_fmax-0-25" and labels ['unsigned', 'embedding', 'spectral', 'directed', 'lagged']
# [168] Adding SPI .statistics.spectral.SpectralGrangerCausality(x,y,{'method': 'nonparametric', 'fmin': 0.25, 'fmax': 0.5, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "sgc_nonparametric_max_fs-1_fmin-0-25_fmax-0-5" and labels ['unsigned', 'embedding', 'spectral', 'directed', 'lagged']
# [169] Adding SPI .statistics.spectral.SpectralGrangerCausality(x,y,{'method': 'parametric', 'fmin': 0, 'fmax': 0.5, 'statistic': 'mean'})...
# Succesfully initialised SPI with identifier "sgc_parametric_mean_fs-1_fmin-0_fmax-0-5_order-None" and labels ['unsigned', 'embedding', 'spectral', 'directed', 'lagged']
# [170] Adding SPI .statistics.spectral.SpectralGrangerCausality(x,y,{'method': 'parametric', 'fmin': 0, 'fmax': 0.25, 'statistic': 'mean'})...
# Succesfully initialised SPI with identifier "sgc_parametric_mean_fs-1_fmin-0_fmax-0-25_order-None" and labels ['unsigned', 'embedding', 'spectral', 'directed', 'lagged']
# [171] Adding SPI .statistics.spectral.SpectralGrangerCausality(x,y,{'fmin': 0.25, 'fmax': 0.5, 'method': 'parametric', 'statistic': 'mean'})...
# Succesfully initialised SPI with identifier "sgc_parametric_mean_fs-1_fmin-0-25_fmax-0-5_order-None" and labels ['unsigned', 'embedding', 'spectral', 'directed', 'lagged']
# [172] Adding SPI .statistics.spectral.SpectralGrangerCausality(x,y,{'fs': 1, 'order': 1, 'method': 'parametric', 'statistic': 'mean'})...
# Succesfully initialised SPI with identifier "sgc_parametric_mean_fs-1_fmin-1e-05_fmax-0-5_order-1" and labels ['unsigned', 'embedding', 'spectral', 'directed', 'lagged']
# [173] Adding SPI .statistics.spectral.SpectralGrangerCausality(x,y,{'fmin': 0, 'fmax': 0.25, 'order': 1, 'method': 'parametric', 'statistic': 'mean'})...
# Succesfully initialised SPI with identifier "sgc_parametric_mean_fs-1_fmin-0_fmax-0-25_order-1" and labels ['unsigned', 'embedding', 'spectral', 'directed', 'lagged']
# [174] Adding SPI .statistics.spectral.SpectralGrangerCausality(x,y,{'fmin': 0.25, 'fmax': 0.5, 'order': 1, 'method': 'parametric', 'statistic': 'mean'})...
# Succesfully initialised SPI with identifier "sgc_parametric_mean_fs-1_fmin-0-25_fmax-0-5_order-1" and labels ['unsigned', 'embedding', 'spectral', 'directed', 'lagged']
# [175] Adding SPI .statistics.spectral.SpectralGrangerCausality(x,y,{'fs': 1, 'order': 20, 'method': 'parametric', 'statistic': 'mean'})...
# Succesfully initialised SPI with identifier "sgc_parametric_mean_fs-1_fmin-1e-05_fmax-0-5_order-20" and labels ['unsigned', 'embedding', 'spectral', 'directed', 'lagged']
# [176] Adding SPI .statistics.spectral.SpectralGrangerCausality(x,y,{'fmin': 0, 'fmax': 0.25, 'order': 20, 'method': 'parametric', 'statistic': 'mean'})...
# Succesfully initialised SPI with identifier "sgc_parametric_mean_fs-1_fmin-0_fmax-0-25_order-20" and labels ['unsigned', 'embedding', 'spectral', 'directed', 'lagged']
# [177] Adding SPI .statistics.spectral.SpectralGrangerCausality(x,y,{'fmin': 0.25, 'fmax': 0.5, 'order': 20, 'method': 'parametric', 'statistic': 'mean'})...
# Succesfully initialised SPI with identifier "sgc_parametric_mean_fs-1_fmin-0-25_fmax-0-5_order-20" and labels ['unsigned', 'embedding', 'spectral', 'directed', 'lagged']
# [178] Adding SPI .statistics.spectral.SpectralGrangerCausality(x,y,{'fs': 1, 'method': 'parametric', 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "sgc_parametric_max_fs-1_fmin-1e-05_fmax-0-5_order-None" and labels ['unsigned', 'embedding', 'spectral', 'directed', 'lagged']
# [179] Adding SPI .statistics.spectral.SpectralGrangerCausality(x,y,{'fmin': 0, 'fmax': 0.25, 'method': 'parametric', 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "sgc_parametric_max_fs-1_fmin-0_fmax-0-25_order-None" and labels ['unsigned', 'embedding', 'spectral', 'directed', 'lagged']
# [180] Adding SPI .statistics.spectral.SpectralGrangerCausality(x,y,{'fmin': 0.25, 'fmax': 0.5, 'method': 'parametric', 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "sgc_parametric_max_fs-1_fmin-0-25_fmax-0-5_order-None" and labels ['unsigned', 'embedding', 'spectral', 'directed', 'lagged']
# [181] Adding SPI .statistics.spectral.SpectralGrangerCausality(x,y,{'fs': 1, 'order': 1, 'method': 'parametric', 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "sgc_parametric_max_fs-1_fmin-1e-05_fmax-0-5_order-1" and labels ['unsigned', 'embedding', 'spectral', 'directed', 'lagged']
# [182] Adding SPI .statistics.spectral.SpectralGrangerCausality(x,y,{'fmin': 0, 'fmax': 0.25, 'order': 1, 'method': 'parametric', 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "sgc_parametric_max_fs-1_fmin-0_fmax-0-25_order-1" and labels ['unsigned', 'embedding', 'spectral', 'directed', 'lagged']
# [183] Adding SPI .statistics.spectral.SpectralGrangerCausality(x,y,{'fmin': 0.25, 'fmax': 0.5, 'order': 1, 'method': 'parametric', 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "sgc_parametric_max_fs-1_fmin-0-25_fmax-0-5_order-1" and labels ['unsigned', 'embedding', 'spectral', 'directed', 'lagged']
# [184] Adding SPI .statistics.spectral.SpectralGrangerCausality(x,y,{'fs': 1, 'order': 20, 'method': 'parametric', 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "sgc_parametric_max_fs-1_fmin-1e-05_fmax-0-5_order-20" and labels ['unsigned', 'embedding', 'spectral', 'directed', 'lagged']
# [185] Adding SPI .statistics.spectral.SpectralGrangerCausality(x,y,{'fmin': 0, 'fmax': 0.25, 'order': 20, 'method': 'parametric', 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "sgc_parametric_max_fs-1_fmin-0_fmax-0-25_order-20" and labels ['unsigned', 'embedding', 'spectral', 'directed', 'lagged']
# [186] Adding SPI .statistics.spectral.SpectralGrangerCausality(x,y,{'fmin': 0.25, 'fmax': 0.5, 'order': 20, 'method': 'parametric', 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "sgc_parametric_max_fs-1_fmin-0-25_fmax-0-5_order-20" and labels ['unsigned', 'embedding', 'spectral', 'directed', 'lagged']
# *** Importing module .statistics.wavelet
# [187] Adding SPI .statistics.wavelet.PhaseSlopeIndex(x,y,{'fs': 1})...
# Succesfully initialised SPI with identifier "psi_wavelet_mean_fs-1_fmin-0_fmax-0-5_mean" and labels ['unsigned', 'wavelet', 'undirected']
# [188] Adding SPI .statistics.wavelet.PhaseSlopeIndex(x,y,{'fmin': 0, 'fmax': 0.25})...
# Succesfully initialised SPI with identifier "psi_wavelet_mean_fs-1_fmin-0_fmax-0-25_mean" and labels ['unsigned', 'wavelet', 'undirected']
# [189] Adding SPI .statistics.wavelet.PhaseSlopeIndex(x,y,{'fmin': 0.25, 'fmax': 0.5})...
# Succesfully initialised SPI with identifier "psi_wavelet_mean_fs-1_fmin-0-25_fmax-0-5_mean" and labels ['unsigned', 'wavelet', 'undirected']
# [190] Adding SPI .statistics.wavelet.PhaseSlopeIndex(x,y,{'fmin': 0, 'fmax': 0.5, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "psi_wavelet_max_fs-1_fmin-0_fmax-0-5_max" and labels ['unsigned', 'wavelet', 'undirected']
# [191] Adding SPI .statistics.wavelet.PhaseSlopeIndex(x,y,{'fmin': 0, 'fmax': 0.25, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "psi_wavelet_max_fs-1_fmin-0_fmax-0-25_max" and labels ['unsigned', 'wavelet', 'undirected']
# [192] Adding SPI .statistics.wavelet.PhaseSlopeIndex(x,y,{'fmin': 0.25, 'fmax': 0.5, 'statistic': 'max'})...
# Succesfully initialised SPI with identifier "psi_wavelet_max_fs-1_fmin-0-25_fmax-0-5_max" and labels ['unsigned', 'wavelet', 'undirected']
# *** Importing module .statistics.misc
# [193] Adding SPI .statistics.misc.LinearModel(x,y,{'model': 'Ridge'})...
# Succesfully initialised SPI with identifier "lmfit_Ridge" and labels ['misc', 'unsigned', 'unordered', 'normal', 'linear', 'directed']
# [194] Adding SPI .statistics.misc.LinearModel(x,y,{'model': 'Lasso'})...
# Succesfully initialised SPI with identifier "lmfit_Lasso" and labels ['misc', 'unsigned', 'unordered', 'normal', 'linear', 'directed']
# [195] Adding SPI .statistics.misc.LinearModel(x,y,{'model': 'SGDRegressor'})...
# Succesfully initialised SPI with identifier "lmfit_SGDRegressor" and labels ['misc', 'unsigned', 'unordered', 'normal', 'linear', 'directed']
# [196] Adding SPI .statistics.misc.LinearModel(x,y,{'model': 'ElasticNet'})...
# Succesfully initialised SPI with identifier "lmfit_ElasticNet" and labels ['misc', 'unsigned', 'unordered', 'normal', 'linear', 'directed']
# [197] Adding SPI .statistics.misc.LinearModel(x,y,{'model': 'BayesianRidge'})...
# Succesfully initialised SPI with identifier "lmfit_BayesianRidge" and labels ['misc', 'unsigned', 'unordered', 'normal', 'linear', 'directed']
# [198] Adding SPI .statistics.misc.Cointegration(x,y,{'method': 'johansen', 'statistic': 'max_eig_stat', 'det_order': 0, 'k_ar_diff': 10})...
# Succesfully initialised SPI with identifier "coint_johansen_max_eig_stat_order-0_ardiff-10" and labels ['misc', 'unsigned', 'temporal', 'undirected', 'nonlinear']
# [199] Adding SPI .statistics.misc.Cointegration(x,y,{'method': 'johansen', 'statistic': 'trace_stat', 'det_order': 0, 'k_ar_diff': 10})...
# Succesfully initialised SPI with identifier "coint_johansen_trace_stat_order-0_ardiff-10" and labels ['misc', 'unsigned', 'temporal', 'undirected', 'nonlinear']
# [200] Adding SPI .statistics.misc.Cointegration(x,y,{'method': 'johansen', 'statistic': 'max_eig_stat', 'det_order': 0, 'k_ar_diff': 1})...
# Succesfully initialised SPI with identifier "coint_johansen_max_eig_stat_order-0_ardiff-1" and labels ['misc', 'unsigned', 'temporal', 'undirected', 'nonlinear']
# [201] Adding SPI .statistics.misc.Cointegration(x,y,{'method': 'johansen', 'statistic': 'trace_stat', 'det_order': 0, 'k_ar_diff': 1})...
# Succesfully initialised SPI with identifier "coint_johansen_trace_stat_order-0_ardiff-1" and labels ['misc', 'unsigned', 'temporal', 'undirected', 'nonlinear']
# [202] Adding SPI .statistics.misc.Cointegration(x,y,{'method': 'johansen', 'statistic': 'max_eig_stat', 'det_order': 1, 'k_ar_diff': 10})...
# Succesfully initialised SPI with identifier "coint_johansen_max_eig_stat_order-1_ardiff-10" and labels ['misc', 'unsigned', 'temporal', 'undirected', 'nonlinear']
# [203] Adding SPI .statistics.misc.Cointegration(x,y,{'method': 'johansen', 'statistic': 'trace_stat', 'det_order': 1, 'k_ar_diff': 10})...
# Succesfully initialised SPI with identifier "coint_johansen_trace_stat_order-1_ardiff-10" and labels ['misc', 'unsigned', 'temporal', 'undirected', 'nonlinear']
# [204] Adding SPI .statistics.misc.Cointegration(x,y,{'method': 'johansen', 'statistic': 'max_eig_stat', 'det_order': 1, 'k_ar_diff': 1})...
# Succesfully initialised SPI with identifier "coint_johansen_max_eig_stat_order-1_ardiff-1" and labels ['misc', 'unsigned', 'temporal', 'undirected', 'nonlinear']
# [205] Adding SPI .statistics.misc.Cointegration(x,y,{'method': 'johansen', 'statistic': 'trace_stat', 'det_order': 1, 'k_ar_diff': 1})...
# Succesfully initialised SPI with identifier "coint_johansen_trace_stat_order-1_ardiff-1" and labels ['misc', 'unsigned', 'temporal', 'undirected', 'nonlinear']
# [206] Adding SPI .statistics.misc.Cointegration(x,y,{'method': 'aeg', 'statistic': 'tstat', 'autolag': 'aic', 'maxlag': 10, 'trend': 'c'})...
# Succesfully initialised SPI with identifier "coint_aeg_tstat_trend-c_autolag-aic_maxlag-10" and labels ['misc', 'unsigned', 'temporal', 'undirected', 'nonlinear']
# [207] Adding SPI .statistics.misc.Cointegration(x,y,{'method': 'aeg', 'statistic': 'tstat', 'autolag': 'aic', 'maxlag': 10, 'trend': 'ct'})...
# Succesfully initialised SPI with identifier "coint_aeg_tstat_trend-ct_autolag-aic_maxlag-10" and labels ['misc', 'unsigned', 'temporal', 'undirected', 'nonlinear']
# [208] Adding SPI .statistics.misc.Cointegration(x,y,{'method': 'aeg', 'statistic': 'tstat', 'autolag': 'bic', 'maxlag': 10, 'trend': 'ct'})...
# Succesfully initialised SPI with identifier "coint_aeg_tstat_trend-ct_autolag-bic_maxlag-10" and labels ['misc', 'unsigned', 'temporal', 'undirected', 'nonlinear']
# [209] Adding SPI .statistics.misc.PowerEnvelopeCorrelation(x,y,{'orth': False, 'log': False, 'absolute': False})...
# Succesfully initialised SPI with identifier "pec" and labels ['unsigned', 'misc', 'undirected']
# [210] Adding SPI .statistics.misc.PowerEnvelopeCorrelation(x,y,{'orth': True, 'log': False, 'absolute': False})...
# Succesfully initialised SPI with identifier "pec_orth" and labels ['unsigned', 'misc', 'undirected']
# [211] Adding SPI .statistics.misc.PowerEnvelopeCorrelation(x,y,{'orth': False, 'log': True, 'absolute': False})...
# Succesfully initialised SPI with identifier "pec_log" and labels ['unsigned', 'misc', 'undirected']
# [212] Adding SPI .statistics.misc.PowerEnvelopeCorrelation(x,y,{'orth': True, 'log': True, 'absolute': False})...
# Succesfully initialised SPI with identifier "pec_orth_log" and labels ['unsigned', 'misc', 'undirected']
# [213] Adding SPI .statistics.misc.PowerEnvelopeCorrelation(x,y,{'orth': True, 'log': False, 'absolute': True})...
# Succesfully initialised SPI with identifier "pec_orth_abs" and labels ['unsigned', 'misc', 'undirected']
# [214] Adding SPI .statistics.misc.PowerEnvelopeCorrelation(x,y,{'orth': True, 'log': True, 'absolute': True})...
# Succesfully initialised SPI with identifier "pec_orth_log_abs" and labels ['unsigned', 'misc', 'undirected']
# Number of SPIs: 215
# Frequency minimum set to 0; overriding to 1e-5.

# %%
data_path="/Users/abry4213/data/Cogitate_MEG_challenge/derivatives/MEG_time_series/sub-CA103_ses-1_epochs"
face_relevant_non_target_epoch_1_IIT_meta_ROI_time_series = pd.read_csv(f"{data_path}/face_Relevant-non-target_1000ms_epoch1_IIT_meta_ROI.csv")
face_relevant_non_target_epoch_1_GNWT_meta_ROI_time_series = pd.read_csv(f"{data_path}/face_Relevant-non-target_1000ms_epoch1_GNWT_meta_ROI.csv")
face_relevant_non_target_epoch_1_CS_meta_ROI_time_series = pd.read_csv(f"{data_path}/face_Relevant-non-target_1000ms_epoch1_Category_Selective_meta_ROI.csv")

face_relevant_non_target_epoch_1_all_time_series = pd.concat([face_relevant_non_target_epoch_1_IIT_meta_ROI_time_series, face_relevant_non_target_epoch_1_GNWT_meta_ROI_time_series, face_relevant_non_target_epoch_1_CS_meta_ROI_time_series], axis=0)
subject_id = "sub-CA103"

face_relevant_non_target_epoch_1_all_time_series['duration'] = face_relevant_non_target_epoch_1_all_time_series['duration'].str.replace('ms', '').astype(int)
face_relevant_non_target_epoch_1_all_time_series['times'] = np.round(face_relevant_non_target_epoch_1_all_time_series['times']*1000)
face_relevant_non_target_epoch_1_all_time_series['times'] = face_relevant_non_target_epoch_1_all_time_series['times'].astype(int)

# Filter times >= 0
face_relevant_non_target_epoch_1_all_time_series = face_relevant_non_target_epoch_1_all_time_series.query('times >= 0')

# Assign stimulus as on if times < duration and off if times >= duration
face_relevant_non_target_epoch_1_all_time_series['stimulus'] = np.where(face_relevant_non_target_epoch_1_all_time_series['times'] < face_relevant_non_target_epoch_1_all_time_series['duration'], 'on', 'off')

# %%
all_epoch_files = [f for f in os.listdir(data_path) if "GNWT" in f]
meta_ROI_list = ["IIT", "GNWT", "Category_Selective"]

all_pyspi_results_for_this_subject_list = []

for csv_file in all_epoch_files:
    stimulus_type, relevance, duration, epoch_number = csv_file.split("_")[0:4]

    results_across_ROIs_list = []

    # Combine results across IIT, GNWT, and Category-Selective meta-ROIs
    for meta_ROI in meta_ROI_list:
        this_ROI_data = pd.read_csv(f"{data_path}/{stimulus_type}_{relevance}_{duration}_{epoch_number}_{meta_ROI}_meta_ROI.csv")
        this_ROI_data['duration'] = this_ROI_data['duration'].str.replace('ms', '').astype(int)
        this_ROI_data['times'] = np.round(this_ROI_data['times']*1000)
        this_ROI_data['times'] = this_ROI_data['times'].astype(int)

        # Filter times >= 0
        this_ROI_data = this_ROI_data.query('times >= 0')

        # Assign stimulus as on if times < duration and off if times >= duration
        this_ROI_data['stimulus'] = np.where(this_ROI_data['times'] < this_ROI_data['duration'], 'on', 'off')

        # Append to list
        results_across_ROIs_list.append(this_ROI_data)

    results_across_ROIs = pd.concat(results_across_ROIs_list, axis=0).reset_index()

    # Iterate over onset vs. offset
    for stimulus_presentation in ['on', 'off']:
        results_across_ROIs_with_this_stim = results_across_ROIs.query("stimulus==@stimulus_presentation")

        # Pivot so that the columns are meta_ROI and the rows are data
        df_wide = (results_across_ROIs_with_this_stim.filter(items=['times', 'meta_ROI', 'data'])
                        .reset_index()
                        .pivot(index='meta_ROI', columns='times', values='data'))

        # Make deepcopy of calc 
        calc_copy = deepcopy(calc)

        # Convert to numpy array
        TS_array = df_wide.to_numpy()

        # Load data 
        calc_copy.load_dataset(TS_array)
        calc_copy.compute()

        SPI_res = deepcopy(calc_copy.table)

        # Iterate over each SPI
        SPI_res.columns = SPI_res.columns.to_flat_index()

        SPI_res = SPI_res.rename(columns='__'.join).assign(meta_ROI_from = lambda x: x.index)
        SPI_res_long = SPI_res.melt(id_vars='meta_ROI_from', var_name='SPI__meta_ROI_to', value_name='value')

        SPI_res_long["SPI"] = SPI_res_long["SPI__meta_ROI_to"].str.split("__").str[0]
        SPI_res_long["meta_ROI_to"] = SPI_res_long["SPI__meta_ROI_to"].str.split("__").str[1]

        SPI_res_long = (SPI_res_long
                        .drop(columns='SPI__meta_ROI_to')
                        .query('meta_ROI_from != meta_ROI_to')
                        .assign(meta_ROI_from = lambda x: x['meta_ROI_from'].map(ROI_lookup),
                                meta_ROI_to = lambda x: x['meta_ROI_to'].map(ROI_lookup))
                        .filter(items=['SPI', 'meta_ROI_from', 'meta_ROI_to', 'value'])
                        .assign(stimulus_type = stimulus_type,
                                stimulus_presentation = stimulus_presentation,
                                relevance_type = relevance,
                                duration = duration,
                                epoch_number = epoch_number,
                                subject_ID = subject_id)
        )

        all_pyspi_results_for_this_subject_list.append(SPI_res_long)

all_pyspi_results_for_this_subject = pd.concat(all_pyspi_results_for_this_subject_list, axis=0).reset_index()

all_pyspi_results_for_this_subject.to_csv(f"{data_path}/pyspi_all_epochs_sub-CA103.csv", index=False)
# Out:
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 72/215 [00:11<01:10,  2.03it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 72/215 [00:11<01:10,  2.03it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  73%|███████▎  | 158/215 [00:12<00:04, 12.05it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:13<00:03, 14.12it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:13<00:00, 15.90it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 70/215 [00:11<00:48,  3.00it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 70/215 [00:11<00:48,  3.00it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  72%|███████▏  | 155/215 [00:13<00:03, 15.31it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:13<00:02, 18.67it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:13<00:00, 15.50it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 72/215 [00:13<01:16,  1.88it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 72/215 [00:13<01:16,  1.88it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  73%|███████▎  | 158/215 [00:15<00:04, 11.46it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:15<00:03, 14.23it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:15<00:00, 13.81it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 72/215 [00:13<00:58,  2.45it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 72/215 [00:13<00:58,  2.45it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  73%|███████▎  | 158/215 [00:15<00:04, 12.96it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:15<00:03, 15.76it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:15<00:00, 13.58it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 72/215 [00:12<01:15,  1.88it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 72/215 [00:12<01:15,  1.88it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  72%|███████▏  | 155/215 [00:14<00:06,  9.56it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:15<00:04, 12.54it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:15<00:00, 13.92it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 72/215 [00:13<01:29,  1.60it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 72/215 [00:13<01:29,  1.60it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  72%|███████▏  | 155/215 [00:15<00:06,  9.98it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:15<00:03, 13.09it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:15<00:00, 13.49it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  31%|███       | 67/215 [00:12<01:51,  1.32it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  34%|███▍      | 74/215 [00:12<01:15,  1.87it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  72%|███████▏  | 155/215 [00:14<00:05, 10.93it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:14<00:03, 14.21it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:14<00:00, 14.64it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 70/215 [00:10<01:38,  1.48it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  35%|███▍      | 75/215 [00:10<01:07,  2.08it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  73%|███████▎  | 157/215 [00:12<00:04, 11.75it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:12<00:03, 14.64it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:13<00:00, 16.31it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 72/215 [00:13<01:18,  1.82it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 72/215 [00:13<01:18,  1.82it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  74%|███████▍  | 159/215 [00:15<00:05, 11.11it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:16<00:03, 13.30it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:16<00:00, 13.12it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 72/215 [00:08<00:47,  2.99it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 72/215 [00:08<00:47,  2.99it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  73%|███████▎  | 158/215 [00:10<00:04, 13.08it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:10<00:03, 15.75it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:10<00:00, 19.95it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 70/215 [00:12<01:21,  1.77it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 70/215 [00:12<01:21,  1.77it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  72%|███████▏  | 155/215 [00:14<00:06,  9.65it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:15<00:04, 12.07it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:15<00:00, 13.72it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 72/215 [00:08<00:39,  3.63it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 72/215 [00:08<00:39,  3.63it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  72%|███████▏  | 155/215 [00:11<00:06,  9.20it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:11<00:04, 12.06it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:12<00:00, 17.61it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 70/215 [00:13<01:36,  1.51it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 70/215 [00:13<01:36,  1.51it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  73%|███████▎  | 158/215 [00:15<00:05, 10.62it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:16<00:03, 12.93it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:16<00:00, 13.03it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 70/215 [00:12<01:19,  1.82it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 70/215 [00:12<01:19,  1.82it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  72%|███████▏  | 155/215 [00:14<00:06,  9.95it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:14<00:03, 13.00it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:14<00:00, 14.61it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 71/215 [00:13<01:33,  1.54it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 71/215 [00:13<01:33,  1.54it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  73%|███████▎  | 157/215 [00:15<00:06,  9.13it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:15<00:04, 11.71it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:15<00:00, 13.54it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 70/215 [00:06<00:27,  5.24it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 70/215 [00:06<00:27,  5.24it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  72%|███████▏  | 155/215 [00:08<00:04, 14.42it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:08<00:02, 18.23it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:09<00:00, 23.33it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 72/215 [00:09<00:44,  3.20it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 72/215 [00:09<00:44,  3.20it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  73%|███████▎  | 158/215 [00:11<00:04, 13.53it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:11<00:03, 16.27it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:12<00:00, 17.54it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 71/215 [00:05<00:29,  4.87it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 71/215 [00:05<00:29,  4.87it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  73%|███████▎  | 158/215 [00:07<00:03, 15.68it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:07<00:02, 18.38it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:08<00:00, 25.91it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  32%|███▏      | 69/215 [00:04<00:38,  3.84it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  35%|███▍      | 75/215 [00:04<00:26,  5.32it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  72%|███████▏  | 155/215 [00:07<00:03, 15.48it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:07<00:02, 19.18it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:07<00:00, 28.27it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 70/215 [00:10<01:29,  1.61it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 70/215 [00:10<01:29,  1.61it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  72%|███████▏  | 155/215 [00:12<00:04, 12.09it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:12<00:03, 15.42it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:13<00:00, 16.12it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 70/215 [00:12<01:09,  2.09it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 70/215 [00:12<01:09,  2.09it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  73%|███████▎  | 158/215 [00:14<00:05, 11.14it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  77%|███████▋  | 165/215 [00:14<00:03, 13.91it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:14<00:00, 14.53it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 71/215 [00:07<01:02,  2.29it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 71/215 [00:07<01:02,  2.29it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  72%|███████▏  | 155/215 [00:09<00:04, 13.54it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:09<00:03, 16.99it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:09<00:00, 22.03it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 70/215 [00:10<01:04,  2.25it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  34%|███▍      | 74/215 [00:10<00:48,  2.91it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  73%|███████▎  | 156/215 [00:12<00:04, 12.26it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:12<00:03, 15.44it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:13<00:00, 16.52it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 70/215 [00:13<01:38,  1.48it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 70/215 [00:13<01:38,  1.48it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  73%|███████▎  | 156/215 [00:15<00:08,  6.76it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:16<00:05,  9.01it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:16<00:00, 13.07it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 70/215 [00:11<01:22,  1.76it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 70/215 [00:12<01:22,  1.76it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  72%|███████▏  | 155/215 [00:14<00:04, 12.12it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:14<00:03, 14.87it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:14<00:00, 14.60it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 72/215 [00:12<01:26,  1.66it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 72/215 [00:12<01:26,  1.66it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  72%|███████▏  | 155/215 [00:15<00:05, 10.49it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:15<00:03, 13.64it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:15<00:00, 13.80it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 70/215 [00:06<00:36,  3.94it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 70/215 [00:06<00:36,  3.94it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  72%|███████▏  | 155/215 [00:08<00:03, 15.70it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:08<00:02, 19.59it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:08<00:00, 23.99it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 70/215 [00:06<00:26,  5.43it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 70/215 [00:06<00:26,  5.43it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  72%|███████▏  | 155/215 [00:08<00:03, 15.15it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:08<00:02, 19.00it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:08<00:00, 24.66it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  34%|███▍      | 73/215 [00:06<00:24,  5.89it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  34%|███▍      | 73/215 [00:06<00:24,  5.89it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  73%|███████▎  | 158/215 [00:08<00:03, 16.49it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:08<00:02, 19.27it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:08<00:00, 24.88it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 70/215 [00:12<01:02,  2.34it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 70/215 [00:12<01:02,  2.34it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  72%|███████▏  | 155/215 [00:14<00:05, 11.25it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:14<00:03, 14.51it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:15<00:00, 14.21it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 71/215 [00:07<00:41,  3.47it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 71/215 [00:07<00:41,  3.47it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  72%|███████▏  | 155/215 [00:09<00:04, 14.16it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:09<00:02, 17.90it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:09<00:00, 21.64it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 72/215 [00:12<01:04,  2.22it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 72/215 [00:12<01:04,  2.22it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  72%|███████▏  | 155/215 [00:15<00:05, 10.55it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:15<00:03, 13.52it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:15<00:00, 13.72it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  32%|███▏      | 69/215 [00:12<01:20,  1.81it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  34%|███▍      | 74/215 [00:12<00:55,  2.55it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  74%|███████▍  | 159/215 [00:14<00:04, 13.56it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:14<00:03, 15.46it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:15<00:00, 14.22it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  32%|███▏      | 69/215 [00:12<01:50,  1.32it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  34%|███▍      | 74/215 [00:12<01:15,  1.86it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  74%|███████▍  | 159/215 [00:15<00:04, 11.74it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:15<00:03, 13.91it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:15<00:00, 13.85it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 72/215 [00:13<01:10,  2.02it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 72/215 [00:13<01:10,  2.02it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  72%|███████▏  | 155/215 [00:15<00:05, 10.52it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:15<00:03, 13.62it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:16<00:00, 13.23it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  31%|███       | 67/215 [00:12<01:57,  1.26it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  34%|███▍      | 74/215 [00:12<01:18,  1.79it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  73%|███████▎  | 158/215 [00:15<00:04, 11.56it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:15<00:03, 13.63it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:15<00:00, 13.62it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 72/215 [00:13<01:25,  1.68it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 72/215 [00:13<01:25,  1.68it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  74%|███████▍  | 159/215 [00:15<00:05, 10.48it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:15<00:04, 12.62it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:16<00:00, 13.40it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 70/215 [00:11<01:06,  2.18it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  35%|███▌      | 76/215 [00:11<00:45,  3.06it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  72%|███████▏  | 155/215 [00:13<00:04, 13.17it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:13<00:03, 16.25it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:14<00:00, 14.95it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 72/215 [00:12<01:02,  2.30it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 72/215 [00:12<01:02,  2.30it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  72%|███████▏  | 155/215 [00:14<00:05, 11.30it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:14<00:03, 14.42it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:14<00:00, 14.40it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 70/215 [00:08<00:35,  4.11it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 70/215 [00:09<00:35,  4.11it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  73%|███████▎  | 158/215 [00:11<00:03, 16.12it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:11<00:02, 17.89it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:11<00:00, 18.18it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  34%|███▍      | 73/215 [00:09<00:28,  4.99it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  34%|███▍      | 73/215 [00:09<00:28,  4.99it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  72%|███████▏  | 155/215 [00:12<00:04, 14.48it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:12<00:02, 18.14it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:12<00:00, 17.11it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  34%|███▍      | 73/215 [00:11<00:54,  2.58it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  34%|███▍      | 73/215 [00:11<00:54,  2.58it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  73%|███████▎  | 158/215 [00:13<00:04, 12.16it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:13<00:03, 14.75it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:14<00:00, 14.96it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  34%|███▍      | 73/215 [00:06<00:34,  4.10it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  34%|███▍      | 73/215 [00:06<00:34,  4.10it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  73%|███████▎  | 157/215 [00:09<00:04, 13.61it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:09<00:03, 16.35it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:09<00:00, 22.30it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  31%|███       | 67/215 [00:11<01:47,  1.37it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  34%|███▍      | 74/215 [00:11<01:12,  1.94it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  72%|███████▏  | 155/215 [00:14<00:05, 10.57it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:14<00:03, 13.52it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:14<00:00, 14.60it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 70/215 [00:12<01:53,  1.28it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 70/215 [00:12<01:53,  1.28it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  72%|███████▏  | 155/215 [00:14<00:05, 10.25it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:14<00:03, 13.14it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:15<00:00, 14.03it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  34%|███▍      | 73/215 [00:12<00:33,  4.26it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  34%|███▍      | 73/215 [00:12<00:33,  4.26it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  72%|███████▏  | 155/215 [00:15<00:04, 13.86it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:15<00:02, 17.36it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:15<00:00, 13.73it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 70/215 [00:11<00:58,  2.48it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 70/215 [00:11<00:58,  2.48it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  72%|███████▏  | 155/215 [00:14<00:04, 12.75it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:14<00:03, 15.34it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:14<00:00, 14.43it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 72/215 [00:13<01:57,  1.22it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 72/215 [00:13<01:57,  1.22it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  73%|███████▎  | 158/215 [00:15<00:06,  8.25it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:15<00:04, 10.50it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:16<00:00, 13.42it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 72/215 [00:06<00:39,  3.65it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 72/215 [00:06<00:39,  3.65it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  72%|███████▏  | 155/215 [00:08<00:04, 12.78it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:08<00:03, 16.33it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:08<00:00, 24.44it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  34%|███▍      | 73/215 [00:05<00:25,  5.57it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  34%|███▍      | 73/215 [00:05<00:25,  5.57it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  73%|███████▎  | 156/215 [00:07<00:04, 14.49it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:08<00:02, 17.51it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:08<00:00, 25.46it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 70/215 [00:09<01:00,  2.39it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 70/215 [00:09<01:00,  2.39it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  73%|███████▎  | 158/215 [00:11<00:04, 14.19it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:11<00:03, 16.73it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:12<00:00, 17.69it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 72/215 [00:13<01:25,  1.67it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 72/215 [00:13<01:25,  1.67it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  73%|███████▎  | 158/215 [00:15<00:05, 10.86it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:15<00:03, 13.63it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:16<00:00, 13.34it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 72/215 [00:11<01:15,  1.90it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 72/215 [00:11<01:15,  1.90it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  73%|███████▎  | 158/215 [00:13<00:05, 11.10it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:13<00:03, 13.50it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:14<00:00, 15.11it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 70/215 [00:10<01:16,  1.91it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 70/215 [00:10<01:16,  1.91it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  72%|███████▏  | 155/215 [00:12<00:04, 12.51it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:12<00:03, 16.10it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:12<00:00, 16.87it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 71/215 [00:06<00:32,  4.42it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 71/215 [00:06<00:32,  4.42it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  73%|███████▎  | 158/215 [00:08<00:03, 16.56it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:08<00:02, 19.53it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:09<00:00, 23.25it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 72/215 [00:05<00:31,  4.54it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 72/215 [00:05<00:31,  4.54it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  72%|███████▏  | 155/215 [00:07<00:04, 14.50it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:07<00:02, 18.37it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:08<00:00, 25.99it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 72/215 [00:04<00:23,  6.12it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 72/215 [00:05<00:23,  6.12it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  73%|███████▎  | 158/215 [00:06<00:03, 18.49it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:07<00:02, 21.31it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:07<00:00, 29.04it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  34%|███▍      | 73/215 [00:12<01:10,  2.03it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  34%|███▍      | 73/215 [00:12<01:10,  2.03it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  73%|███████▎  | 158/215 [00:14<00:04, 12.41it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:14<00:03, 15.17it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:14<00:00, 14.84it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 70/215 [00:13<01:55,  1.26it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 70/215 [00:13<01:55,  1.26it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  72%|███████▏  | 155/215 [00:15<00:08,  7.36it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:15<00:05,  9.89it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:15<00:00, 13.83it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 72/215 [00:07<00:42,  3.34it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 72/215 [00:07<00:42,  3.34it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  73%|███████▎  | 158/215 [00:09<00:03, 15.16it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:09<00:02, 18.08it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:10<00:00, 20.99it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 70/215 [00:12<01:20,  1.80it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 70/215 [00:12<01:20,  1.80it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  73%|███████▎  | 157/215 [00:14<00:05, 10.15it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:14<00:03, 13.01it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:15<00:00, 14.30it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 72/215 [00:06<00:27,  5.24it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 72/215 [00:06<00:27,  5.24it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  73%|███████▎  | 158/215 [00:08<00:03, 16.81it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:08<00:02, 19.67it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:09<00:00, 23.81it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 70/215 [00:05<00:29,  4.86it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 70/215 [00:05<00:29,  4.86it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  73%|███████▎  | 156/215 [00:07<00:03, 16.11it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:07<00:02, 18.72it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:08<00:00, 26.08it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 71/215 [00:11<01:20,  1.79it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  35%|███▍      | 75/215 [00:11<00:58,  2.40it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  73%|███████▎  | 156/215 [00:13<00:06,  9.20it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:13<00:04, 12.08it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:14<00:00, 15.28it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 72/215 [00:13<00:53,  2.68it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 72/215 [00:13<00:53,  2.68it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  73%|███████▎  | 157/215 [00:15<00:04, 13.75it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:15<00:02, 17.00it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:15<00:00, 13.83it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  34%|███▍      | 73/215 [00:10<00:42,  3.32it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  34%|███▍      | 73/215 [00:10<00:42,  3.32it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  73%|███████▎  | 158/215 [00:12<00:03, 14.67it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:12<00:02, 17.68it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:13<00:00, 16.31it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 72/215 [00:09<00:58,  2.45it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 72/215 [00:09<00:58,  2.45it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  73%|███████▎  | 157/215 [00:12<00:07,  7.89it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:12<00:05,  9.70it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:13<00:00, 16.02it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 70/215 [00:07<00:57,  2.52it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  34%|███▍      | 74/215 [00:07<00:40,  3.50it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  72%|███████▏  | 155/215 [00:10<00:04, 13.34it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:10<00:03, 16.42it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:10<00:00, 19.80it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 70/215 [00:09<00:45,  3.17it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  35%|███▍      | 75/215 [00:09<00:31,  4.40it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  72%|███████▏  | 155/215 [00:11<00:04, 14.85it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:11<00:02, 18.61it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:12<00:00, 17.46it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  32%|███▏      | 69/215 [00:11<01:16,  1.91it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  32%|███▏      | 69/215 [00:11<01:16,  1.91it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  74%|███████▍  | 159/215 [00:13<00:03, 14.25it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:13<00:03, 16.74it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:13<00:00, 15.68it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 70/215 [00:12<01:15,  1.91it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 70/215 [00:12<01:15,  1.91it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  73%|███████▎  | 158/215 [00:14<00:05, 10.79it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  77%|███████▋  | 165/215 [00:14<00:03, 13.54it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:14<00:00, 14.70it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 72/215 [00:10<00:35,  4.01it/s]Mean of empty slice
# ...
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  74%|███████▍  | 159/215 [00:16<00:04, 13.54it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:16<00:03, 16.02it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:17<00:00, 12.43it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 70/215 [00:12<01:55,  1.26it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  35%|███▍      | 75/215 [00:12<01:18,  1.77it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  73%|███████▎  | 158/215 [00:14<00:05, 10.78it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:14<00:03, 13.43it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:15<00:00, 14.24it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 70/215 [00:11<01:43,  1.40it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  35%|███▌      | 76/215 [00:11<01:10,  1.98it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  72%|███████▏  | 155/215 [00:13<00:05, 11.46it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:13<00:03, 14.69it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:13<00:00, 15.43it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 71/215 [00:11<00:40,  3.53it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 71/215 [00:11<00:40,  3.53it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  73%|███████▎  | 157/215 [00:14<00:03, 16.00it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:14<00:02, 19.42it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:14<00:00, 14.79it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  34%|███▍      | 73/215 [00:13<01:01,  2.30it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  34%|███▍      | 73/215 [00:13<01:01,  2.30it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  72%|███████▏  | 155/215 [00:15<00:05, 11.93it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:15<00:03, 15.40it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:15<00:00, 13.76it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 70/215 [00:12<01:54,  1.27it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  35%|███▍      | 75/215 [00:12<01:17,  1.80it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  73%|███████▎  | 158/215 [00:14<00:05, 10.90it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:14<00:03, 13.57it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:15<00:00, 14.29it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 70/215 [00:06<00:34,  4.24it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  35%|███▍      | 75/215 [00:06<00:24,  5.83it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  72%|███████▏  | 155/215 [00:08<00:03, 16.82it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:08<00:02, 20.77it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:08<00:00, 24.83it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 72/215 [00:12<00:52,  2.70it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 72/215 [00:12<00:52,  2.70it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  72%|███████▏  | 155/215 [00:14<00:04, 12.82it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:14<00:03, 16.45it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:14<00:00, 14.37it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 72/215 [00:12<00:36,  3.97it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 72/215 [00:12<00:36,  3.97it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  73%|███████▎  | 158/215 [00:14<00:03, 15.81it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:14<00:02, 18.27it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:14<00:00, 14.66it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 72/215 [00:05<00:31,  4.54it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 72/215 [00:05<00:31,  4.54it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  72%|███████▏  | 155/215 [00:07<00:03, 15.34it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:07<00:02, 19.12it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:08<00:00, 26.42it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 72/215 [00:09<00:55,  2.56it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 72/215 [00:09<00:55,  2.56it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  74%|███████▍  | 159/215 [00:11<00:04, 13.95it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:11<00:03, 15.91it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:12<00:00, 17.60it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  32%|███▏      | 69/215 [00:11<01:03,  2.30it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  35%|███▌      | 76/215 [00:11<00:42,  3.23it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  73%|███████▎  | 158/215 [00:13<00:03, 14.72it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:14<00:02, 17.58it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:14<00:00, 14.86it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 70/215 [00:06<00:34,  4.23it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  35%|███▍      | 75/215 [00:06<00:24,  5.81it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  73%|███████▎  | 158/215 [00:08<00:03, 17.30it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:08<00:02, 20.22it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:08<00:00, 24.32it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 70/215 [00:05<00:33,  4.27it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 70/215 [00:05<00:33,  4.27it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  72%|███████▏  | 155/215 [00:07<00:04, 14.76it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:07<00:02, 18.63it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:08<00:00, 26.00it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  32%|███▏      | 69/215 [00:11<01:48,  1.35it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  35%|███▍      | 75/215 [00:11<01:13,  1.91it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  73%|███████▎  | 157/215 [00:13<00:05, 10.76it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:14<00:03, 13.65it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:14<00:00, 14.83it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 71/215 [00:11<00:52,  2.76it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 71/215 [00:11<00:52,  2.76it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  73%|███████▎  | 156/215 [00:13<00:04, 13.80it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:13<00:02, 17.38it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:14<00:00, 15.09it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 70/215 [00:12<01:27,  1.65it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 70/215 [00:12<01:27,  1.65it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  72%|███████▏  | 155/215 [00:14<00:05, 10.86it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:14<00:03, 14.09it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:15<00:00, 14.19it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 72/215 [00:12<00:57,  2.47it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 72/215 [00:12<00:57,  2.47it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  72%|███████▏  | 155/215 [00:14<00:04, 12.66it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:14<00:03, 16.19it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:15<00:00, 14.24it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  31%|███       | 67/215 [00:11<01:41,  1.46it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  34%|███▍      | 74/215 [00:11<01:08,  2.06it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  72%|███████▏  | 155/215 [00:13<00:05, 11.11it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:13<00:03, 14.12it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:14<00:00, 15.20it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 71/215 [00:12<01:14,  1.94it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 71/215 [00:12<01:14,  1.94it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  73%|███████▎  | 156/215 [00:14<00:04, 12.00it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:14<00:03, 15.31it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:14<00:00, 14.59it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  32%|███▏      | 69/215 [00:06<00:30,  4.81it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  34%|███▍      | 74/215 [00:06<00:21,  6.58it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  74%|███████▍  | 159/215 [00:08<00:03, 17.92it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:08<00:02, 20.02it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:08<00:00, 25.05it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  32%|███▏      | 69/215 [00:10<01:06,  2.18it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  35%|███▍      | 75/215 [00:10<00:45,  3.06it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  72%|███████▏  | 155/215 [00:12<00:04, 13.57it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:12<00:02, 17.26it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:13<00:00, 16.13it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 70/215 [00:12<01:24,  1.71it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  33%|███▎      | 70/215 [00:12<01:24,  1.71it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  72%|███████▏  | 155/215 [00:14<00:04, 12.66it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:14<00:03, 16.25it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:15<00:00, 14.21it/s]
# Processing [None: phase_multitaper_mean_fs-1_fmin-0_fmax-0-5]:  32%|███▏      | 69/215 [00:14<01:39,  1.47it/s]Mean of empty slice
# Processing [None: phase_multitaper_max_fs-1_fmin-0_fmax-0-5]:  35%|███▍      | 75/215 [00:14<01:07,  2.07it/s]    All-NaN slice encountered
# Processing [None: sgc_nonparametric_mean_fs-1_fmin-0_fmax-0-5]:  72%|███████▏  | 155/215 [00:16<00:05, 11.39it/s]   Mean of empty slice
# Processing [None: sgc_nonparametric_max_fs-1_fmin-0_fmax-0-5]:  76%|███████▋  | 164/215 [00:16<00:03, 14.78it/s]    All-NaN slice encountered
# Processing [None: pec_orth_log_abs]: 100%|██████████| 215/215 [00:16<00:00, 12.89it/s]
# Processing [None: si_kozachenko_k-1]:  27%|██▋       | 59/215 [00:06<00:49,  3.15it/s]
